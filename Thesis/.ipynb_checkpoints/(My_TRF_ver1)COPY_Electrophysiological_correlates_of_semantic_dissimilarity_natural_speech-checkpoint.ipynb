# %% [markdown]
# ## install packages

# %%
# Paper: https://doi.org/10.1016/j.cub.2018.01.080
# https://datadryad.org/stash/dataset/doi:10.5061/dryad.070jc
# !pip install mne
# !pip install eelbrain
# !pip install keyring
# !pip install colormath
# !pip3 install scipy==1.7.1  #in order to compare with the eelbrain, the version of scipy needs to be older one.
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mne
#   Downloading mne-1.1.1-py3-none-any.whl (7.5 MB)
#      |████████████████████████████████| 7.5 MB 5.0 MB/s
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from mne) (1.21.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from mne) (2.11.3)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from mne) (1.7.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from mne) (21.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from mne) (4.64.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from mne) (3.2.2)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.7/dist-packages (from mne) (1.6.0)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.5->mne) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.5->mne) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->mne) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->mne) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->mne) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->mne) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->mne) (0.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib->mne) (4.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->matplotlib->mne) (1.15.0)
# Installing collected packages: mne
# Successfully installed mne-1.1.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting eelbrain
#   Downloading eelbrain-0.34.1.tar.gz (1.5 MB)
#      |████████████████████████████████| 1.5 MB 5.4 MB/s
# Building wheels for collected packages: eelbrain
#   Building wheel for eelbrain (setup.py) ... done
#   Created wheel for eelbrain: filename=eelbrain-0.34.1-cp37-cp37m-linux_x86_64.whl size=2370317 sha256=bc013637602b4d4996af371144ce3f51e28256cb8c8d81f4e2f980d6af646afe
#   Stored in directory: /root/.cache/pip/wheels/9a/29/05/ab95c10411d2661330dd88582ff9a4e96f640a0e31ff3205ae
# Successfully built eelbrain
# Installing collected packages: eelbrain
# Successfully installed eelbrain-0.34.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keyring
#   Downloading keyring-23.9.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.7/dist-packages (from keyring) (4.12.0)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 4.6 MB/s
# Collecting jaraco.classes
#   Downloading jaraco.classes-3.2.2-py3-none-any.whl (6.0 kB)
# Collecting SecretStorage>=3.2
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6->keyring) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6->keyring) (3.8.1)
# Collecting cryptography>=2.0
#   Downloading cryptography-37.0.4-cp36-abi3-manylinux_2_24_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 32.1 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring) (2.21)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from jaraco.classes->keyring) (8.14.0)
# Installing collected packages: jeepney, cryptography, SecretStorage, jaraco.classes, keyring
# Successfully installed SecretStorage-3.3.3 cryptography-37.0.4 jaraco.classes-3.2.2 jeepney-0.8.0 keyring-23.9.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting colormath
#   Downloading colormath-3.0.0.tar.gz (39 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from colormath) (1.21.6)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from colormath) (2.6.3)
# Building wheels for collected packages: colormath
#   Building wheel for colormath (setup.py) ... done
#   Created wheel for colormath: filename=colormath-3.0.0-py3-none-any.whl size=39408 sha256=dde74a1c64ecb7c5a5e0c279793a2fac3d9ae3ceecd04b295c46131cb57cfb28
#   Stored in directory: /root/.cache/pip/wheels/1a/d7/a7/458a4632ccc8bfe436f5e9db9fef1aa84e5d243a1b4b4c7b59
# Successfully built colormath
# Installing collected packages: colormath
# Successfully installed colormath-3.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scipy==1.7.1
#   Downloading scipy-1.7.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.5 MB)
#      |████████████████████████████████| 28.5 MB 42.6 MB/s
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from scipy==1.7.1) (1.21.6)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
# Successfully installed scipy-1.7.1

# %%
# %matplotlib inline

# %% [markdown]
# ## Download files

# %%
# !wget -O natural_reading_eeg.zip https://datadryad.org/stash/downloads/file_stream/222587
# Out:
# --2022-09-05 02:44:45--  https://datadryad.org/stash/downloads/file_stream/222587
# Resolving datadryad.org (datadryad.org)... 54.148.40.29, 35.160.108.242
# Connecting to datadryad.org (datadryad.org)|54.148.40.29|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dryad-assetstore-merritt-west.s3.us-west-2.amazonaws.com/ark%3A/13030/m5c87bqr%7C1%7Cproducer/Natural%20Speech.zip?response-content-type=application%2Fzip&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEEIaCXVzLXdlc3QtMiJIMEYCIQCqWJ9Yr%2BstEMfKsrJCBrXJiuOC%2Ba6cCA%2BMHK%2BCMqFJnQIhANr1TRKKE1cIj%2BuQXXJ8cf3pDh0VGfmoOPWQJEESjikGKtUECMv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEQABoMNDUxODI2OTE0MTU3IgzAChz7nDQLqQJmQTcqqQQI290fmyq3ysfQJ5UtKJpshuXhpBITvYumg%2F6VudG4rZY%2BA%2FGmqyNBDChnG5TWFyBJJXIXleV%2FUdL0UHPG3741Pg4FQ8DUSi8G7W1dq8o95lV1eRlp3WjTACTvR0%2BIOgdjqxUWBYD0R6Sm%2FjqCTBGXp7v9WfkPJRPUXAg2pPovrURMUAG8ccvHFgKRSIswN1hAuKhXoeXa8krbipbjVnxvxvXPpGsO3cWYBL19X4WY865Lj4NbC1uMQmLvptcVzNdEk3awHoR7OzGPnWFy5YEc%2F72VbuM2OH%2FDQX89Izhpj8Vz3owuJcw445HVRFPnTUNlJnrG3XQnyEYRXCinPS4zhufIkYctRJACqswtw81w0nRIqZHGOznHlqUcP9HEFOElHOaw3q%2BunNKSCf%2Fpn%2FuiLRUPAok4GxJiGaKPkvTblXRHW1ncj1E68MYGWsRMT853WvUNugpD9W0fcyq%2F6dYof8pzZ%2BB87EDZYDJHJM90cK1VnHsDvtsRG1iWHpDBXqFuyLGEPdSmxBqTt7kZePDKBVhjScovZdWiR7NGfzRPEWSaQ3XLlSsd8JX6J3eC%2FyS3seueByqxNNSTA5Eq5MJEs%2BhiXgcedyZZ2L%2Blmbe0LIvjIg0s5G55V0n17kRwfvSn60IIGrCaIra80DWkhLkUMxJ%2FBJq70Bu7fL%2BjMqF%2FD3emohVKqII9OXj550sMD2QNG9A%2B%2FZ7Ds8z5g04IUJjBR9HdesxudUJ3MKu01ZgGOqgB10VogBjDjbIKdFAbICStkVV65Nas2CO%2BOLK%2BSTh6HEENgXCDFTIjFcRDZJNTG7xIVmihK6RmbJt03fBftjtbBS%2B2KYQJQ3CRSNHiYl4dDDDrmWVXQgQ%2Fx%2Br%2FAhV26HrkIYQ%2Bzvai%2FOPx5f905qvQ8QdeF471RXa2rfP3HMPc0kAhqt8OtPGA2BOlQPuophuw41MM9XrNNFWp0AURZYl3r85l9vixKYxT&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20220905T024446Z&X-Amz-SignedHeaders=host&X-Amz-Expires=14400&X-Amz-Credential=ASIAWSMX3SNWZGARL46V%2F20220905%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=d076c5addfdab9a754a8991edca3296638c20617b5750cf33e9e09a1cec1122a [following]
# --2022-09-05 02:44:46--  https://dryad-assetstore-merritt-west.s3.us-west-2.amazonaws.com/ark%3A/13030/m5c87bqr%7C1%7Cproducer/Natural%20Speech.zip?response-content-type=application%2Fzip&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEEIaCXVzLXdlc3QtMiJIMEYCIQCqWJ9Yr%2BstEMfKsrJCBrXJiuOC%2Ba6cCA%2BMHK%2BCMqFJnQIhANr1TRKKE1cIj%2BuQXXJ8cf3pDh0VGfmoOPWQJEESjikGKtUECMv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEQABoMNDUxODI2OTE0MTU3IgzAChz7nDQLqQJmQTcqqQQI290fmyq3ysfQJ5UtKJpshuXhpBITvYumg%2F6VudG4rZY%2BA%2FGmqyNBDChnG5TWFyBJJXIXleV%2FUdL0UHPG3741Pg4FQ8DUSi8G7W1dq8o95lV1eRlp3WjTACTvR0%2BIOgdjqxUWBYD0R6Sm%2FjqCTBGXp7v9WfkPJRPUXAg2pPovrURMUAG8ccvHFgKRSIswN1hAuKhXoeXa8krbipbjVnxvxvXPpGsO3cWYBL19X4WY865Lj4NbC1uMQmLvptcVzNdEk3awHoR7OzGPnWFy5YEc%2F72VbuM2OH%2FDQX89Izhpj8Vz3owuJcw445HVRFPnTUNlJnrG3XQnyEYRXCinPS4zhufIkYctRJACqswtw81w0nRIqZHGOznHlqUcP9HEFOElHOaw3q%2BunNKSCf%2Fpn%2FuiLRUPAok4GxJiGaKPkvTblXRHW1ncj1E68MYGWsRMT853WvUNugpD9W0fcyq%2F6dYof8pzZ%2BB87EDZYDJHJM90cK1VnHsDvtsRG1iWHpDBXqFuyLGEPdSmxBqTt7kZePDKBVhjScovZdWiR7NGfzRPEWSaQ3XLlSsd8JX6J3eC%2FyS3seueByqxNNSTA5Eq5MJEs%2BhiXgcedyZZ2L%2Blmbe0LIvjIg0s5G55V0n17kRwfvSn60IIGrCaIra80DWkhLkUMxJ%2FBJq70Bu7fL%2BjMqF%2FD3emohVKqII9OXj550sMD2QNG9A%2B%2FZ7Ds8z5g04IUJjBR9HdesxudUJ3MKu01ZgGOqgB10VogBjDjbIKdFAbICStkVV65Nas2CO%2BOLK%2BSTh6HEENgXCDFTIjFcRDZJNTG7xIVmihK6RmbJt03fBftjtbBS%2B2KYQJQ3CRSNHiYl4dDDDrmWVXQgQ%2Fx%2Br%2FAhV26HrkIYQ%2Bzvai%2FOPx5f905qvQ8QdeF471RXa2rfP3HMPc0kAhqt8OtPGA2BOlQPuophuw41MM9XrNNFWp0AURZYl3r85l9vixKYxT&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20220905T024446Z&X-Amz-SignedHeaders=host&X-Amz-Expires=14400&X-Amz-Credential=ASIAWSMX3SNWZGARL46V%2F20220905%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=d076c5addfdab9a754a8991edca3296638c20617b5750cf33e9e09a1cec1122a
# Resolving dryad-assetstore-merritt-west.s3.us-west-2.amazonaws.com (dryad-assetstore-merritt-west.s3.us-west-2.amazonaws.com)... 52.92.210.234
# Connecting to dryad-assetstore-merritt-west.s3.us-west-2.amazonaws.com (dryad-assetstore-merritt-west.s3.us-west-2.amazonaws.com)|52.92.210.234|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3461482755 (3.2G) [application/zip]
# Saving to: ‘natural_reading_eeg.zip’
#
# natural_reading_eeg 100%[===================>]   3.22G  33.0MB/s    in 1m 44s
#
# 2022-09-05 02:46:30 (31.9 MB/s) - ‘natural_reading_eeg.zip’ saved [3461482755/3461482755]

# %%
"""
# Things that need to be prepared to do TRF
1. wordVec: the list of the content word in the text.
2. onset time of the word
3. offset time of the word
4. Sentence boundaries >> this one need to be calculate by myself >> the info is in the csv file.
CPS (closure positive shift), happened when the boundary started. 

the parameters of the envolope of the audio files need to be collect, then to downsample to 128 Hz.
** Alice's audio need to be downsample and calculate the envelope

mastoid channels >> use the soft bone behind both ears as the references (M1 / M2)

DC mode> without high pass filter >> add it on in the later analysis

EEG needs to match with the envelope data
"""
# Out:
#   File "<ipython-input-6-a886955a5046>", line 1
#     """#
#         ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %% [markdown]
# ## Retrieve file

# %%
## Channel layout
# https://github.com/mne-tools/mne-python/blob/main/mne/channels/data/montages/biosemi128.txt
# https://www.biosemi.com/pics/cap_128_layout_medium.jpg
# !unzip -q natural_reading_eeg.zip
# !mv "Natural Speech" data # rename folder "Natural Speech" as "data"
# !ls data/EEG
# Out:
# Readme.txt  Subject11  Subject14  Subject17  Subject2  Subject5  Subject8
# Subject1    Subject12  Subject15  Subject18  Subject3  Subject6  Subject9
# Subject10   Subject13  Subject16  Subject19  Subject4  Subject7

# %% [markdown]
# ## import packages

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import scipy.io as sio
from scipy import stats
import numpy as np
import mne
import eelbrain
from itertools import islice

# %% [markdown]
# ## prepare functions

# %%
def get_raw_EEG(Sid, runid):
  """
  Turn the EEG data from matlab .mat form into eelbrain tolerable form
  """
  # sio in scipy>> named by oneself
  # Because the file in here is from matlab, therefore , use sio to load .mat
  audio = sio.loadmat("data/Stimuli/Envelopes/audio%d_128Hz.mat"%runid)
  text = sio.loadmat("data/Stimuli/Text/Run%d.mat"%runid)
  EEG = sio.loadmat("data/EEG/Subject%d/Subject%d_Run%d.mat"%(Sid,Sid,runid))
  eeg_scalp = EEG["eegData"] # time by channels
  eeg_mas = EEG["mastoids"]

  # time by channels >> channels by times
  eeg_scalp = np.transpose( eeg_scalp, (1, 0)) 
  eeg_mas = np.transpose( eeg_mas, (1, 0)) 
  
  # combine the eeg_scalp & eeg_mas together
  eeg_ = np.concatenate((eeg_scalp, eeg_mas), axis = 0) #axis = 0 >> use the first axis to combine (axis x)
  audio = audio["env"]
  # use the shorter data as the main shape of the final data
  if eeg_.shape[1] > audio.shape[0]:
      eeg_ = eeg_[:, :audio.shape[0]]
  
  if eeg_.shape[1] < audio.shape[0]:
      audio = audio[:eeg_.shape[1]]

  tstep = 1. / 128 # 1. >>use the "." to help calculate the decimal #tstep = 點跟點之間停留多長 = sampling rate's 倒數
  n_times = audio.shape[0]
  time = eelbrain.UTS(0, tstep, n_times)
  # the 3 commands above are required to form the following thing >> envelope
  envelope = eelbrain.NDVar(audio.ravel(), (time,), name='envelope')
#####
  temp = mne.channels.make_standard_montage("biosemi128")
  ch_names = temp.ch_names
  ch_names.append("M1")
  ch_names.append("M2")
  ch_types = ['eeg'] * 130 # create 130 EEG channels
  info = mne.create_info(ch_names, ch_types=ch_types, sfreq=128)

  raw = mne.io.RawArray(eeg_ * 1e-6, info) # the original unit of EEG is volt >> we turned it into micro volt >> *1e-6
  raw.set_eeg_reference(["M1", "M2"]).pick('all', exclude=["M1", "M2"]).set_montage('biosemi128')
  print(raw)

  return raw, envelope, time

def raw2NDvar(raw, time):
  """
  Turn the raw data into NDVar objects
  """
  montage_x = eelbrain.load.fiff.sensor_dim(raw.info)
  temp_data = raw.get_data().T *1e+6
  eegNDVar = eelbrain.NDVar(temp_data, (time, montage_x), name='EEG', info={'unit': 'µV'}) #'µV'(micro volt) >> 'V' (volt)
  return eegNDVar

def word_onsets_NDVar(runid, time):
  text = sio.loadmat("data/Stimuli/Text/Run%d.mat"%runid)
  words = [x[0][0] for x in text["wordVec"]]
  onsets = [x[0] for x in text["onset_time"]]

  onset_word = eelbrain.NDVar(np.zeros(len(time)), time, name='Word_on')
  for x in onsets:
      onset_word[x] = 1
      pass
  return onset_word

# %% [markdown]
# ## EEG Data

# %%
#eeg_data = sio.loadmat("data/EEG/Subject1/Subject1_Run1.mat")
#eeg = eeg_data["eegData"] # time by channels
#mastoids = eeg_data["mastoids"]
#print(eeg.shape)

raw, envelope, time = get_raw_EEG(1, 1)
eegNDVar = raw2NDvar(raw, time)
raw.plot()
# Out:
# Creating RawArray with float64 data, n_channels=130, n_times=22729
#     Range : 0 ... 22728 =      0.000 ...   177.562 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying a custom ('EEG',) reference.
# <RawArray | 128 x 22729 (177.6 s), ~22.4 MB, data loaded>
# Using matplotlib as 2D backend.
# /usr/local/lib/python3.7/dist-packages/matplotlib/colors.py:263: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   c = np.array(c)
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
# preprocess the EEG data
raw.filter(1, 20) # filter the raw data from 1 to 20 Hz
raw.plot()
eegNDVar = raw2NDvar(raw, time)
p = eelbrain.plot.TopoButterfly(eegNDVar, xlim=5, w=7, h=2)
p.set_time(1.300)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# - Filter length: 423 samples (3.305 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 128 out of 128 | elapsed:    0.4s finished
# /usr/local/lib/python3.7/dist-packages/matplotlib/colors.py:263: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   c = np.array(c)
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
ica = mne.preprocessing.ICA(n_components=15, max_iter='auto', random_state=97)
ica.fit(raw)
ica.plot_sources(raw, show_scrollbars=False)
ica.plot_components()
# Out:
# Fitting ICA to data using 128 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.6s.
# Creating RawArray with float64 data, n_channels=15, n_times=22729
#     Range : 0 ... 22728 =      0.000 ...   177.562 secs
# Ready.
# /usr/local/lib/python3.7/dist-packages/matplotlib/colors.py:263: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   c = np.array(c)
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEFigure size 702x526.68 with 15 Axes>
# [<MNEFigure size 702x526.68 with 15 Axes>]

# %%
ica.plot_overlay(raw, exclude=[0, 1], picks='eeg')
# Out:
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 2 ICA components
#     Projecting back using 128 PCA components

# %%
ica.plot_properties(raw, picks=[0, 1, 4, 9])
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 88 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# Not setting metadata
# 88 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# Not setting metadata
# 88 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# Not setting metadata
# 88 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# [<Figure size 504x432 with 6 Axes>,
#  <Figure size 504x432 with 6 Axes>,
#  <Figure size 504x432 with 6 Axes>,
#  <Figure size 504x432 with 6 Axes>]

# %%
ica.exclude = [0, 1]
ica.apply(raw)
eegNDVar = raw2NDvar(raw, time)
p = eelbrain.plot.TopoButterfly(eegNDVar, xlim=5, w=7, h=2)
p.set_time(1.300)
# Out:
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 2 ICA components
#     Projecting back using 128 PCA components

# %%
#eelbrain.plot.UTS(envelope, w=6, h=2)
eelbrain.plot.UTS(envelope, xlim=20, w=12, h=2)

# %%
# Boosting is to create the TRF function
res = eelbrain.boosting(eegNDVar, envelope,  -0.100, 0.600, error='l1',
                        basis=0.050, partitions=5, test=1)
p = eelbrain.plot.TopoButterfly(res.h_scaled, w=10, h=4)
p.set_time(.180)

"""
2 ways of examine the TRF
1. average all TRFs
2. To see the correlations of TRFs between subjects
"""
# Out:
# Fitting models:   0%|          | 0/2560 [00:00<?, ?it/s]
# '\n2 ways of examine the TRF\n1. average all TRFs\n2. To see the correlations of TRFs between subjects\n'

# %%
p = eelbrain.plot.TopoButterfly(res.h_scaled, w=10, h=4)
p.set_time(.45)

# %%
raw2, envelope2, time2 = get_raw_EEG(1, 2)
raw2.filter(1, 20)
ica.apply(raw2) # exclude the same ICA component as the first round 
eegNDVar2 = raw2NDvar(raw2, time2)
p = eelbrain.plot.TopoButterfly(eegNDVar2, xlim=5, w=7, h=2)
p.set_time(1.300)
# Out:
# Creating RawArray with float64 data, n_channels=130, n_times=23130
#     Range : 0 ... 23129 =      0.000 ...   180.695 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying a custom ('EEG',) reference.
# <RawArray | 128 x 23130 (180.7 s), ~22.8 MB, data loaded>
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# - Filter length: 423 samples (3.305 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 2 ICA components
#     Projecting back using 128 PCA components
# [Parallel(n_jobs=1)]: Done 128 out of 128 | elapsed:    0.4s finished

# %%
# perform the same procedure on the same subject's different runs
raw3, envelope3, time3 = get_raw_EEG(1, 3)
raw3.filter(1, 20)
ica.apply(raw3)
eegNDVar3 = raw2NDvar(raw3, time3)

raw4, envelope4, time4 = get_raw_EEG(1, 4)
raw4.filter(1, 20)
ica.apply(raw4)
eegNDVar4 = raw2NDvar(raw4, time4)

raw5, envelope5, time5 = get_raw_EEG(1, 5)
raw5.filter(1, 20)
ica.apply(raw5)
eegNDVar5 = raw2NDvar(raw5, time5)

# combine 5 NDVar data that we just created
env_ = eelbrain.concatenate([envelope, envelope2, envelope3, envelope4, envelope5])
eegNDVar_ = eelbrain.concatenate([eegNDVar, eegNDVar2, eegNDVar3, eegNDVar4, eegNDVar5])
# Out:
# Creating RawArray with float64 data, n_channels=130, n_times=23050
#     Range : 0 ... 23049 =      0.000 ...   180.070 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying a custom ('EEG',) reference.
# <RawArray | 128 x 23050 (180.1 s), ~22.7 MB, data loaded>
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# - Filter length: 423 samples (3.305 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 2 ICA components
#     Projecting back using 128 PCA components
# [Parallel(n_jobs=1)]: Done 128 out of 128 | elapsed:    0.3s finished
# Creating RawArray with float64 data, n_channels=130, n_times=23213
#     Range : 0 ... 23212 =      0.000 ...   181.344 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying a custom ('EEG',) reference.
# <RawArray | 128 x 23213 (181.3 s), ~22.8 MB, data loaded>
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# - Filter length: 423 samples (3.305 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 2 ICA components
#     Projecting back using 128 PCA components
# [Parallel(n_jobs=1)]: Done 128 out of 128 | elapsed:    0.3s finished
# Creating RawArray with float64 data, n_channels=130, n_times=23082
#     Range : 0 ... 23081 =      0.000 ...   180.320 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying a custom ('EEG',) reference.
# <RawArray | 128 x 23082 (180.3 s), ~22.7 MB, data loaded>
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# - Filter length: 423 samples (3.305 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 2 ICA components
#     Projecting back using 128 PCA components
# [Parallel(n_jobs=1)]: Done 128 out of 128 | elapsed:    0.3s finished

# %%
print(eegNDVar_)
print(115204 / 128.)  # Divided by the sampling rate will get the length of the data

print(eegNDVar)
print(22729 / 128.)
# Out:
# <NDVar 'EEG': 115204 time, 128 sensor>
# 900.03125
# <NDVar 'EEG': 22729 time, 128 sensor>
# 177.5703125

# %%
p = eelbrain.plot.TopoButterfly(eegNDVar_, w=7, h=2)
p.set_time(1.300)

# %%
# partitions=5 >> divide the EEG data into 5 portions, so that the model could compare the training data with the testing data
res = eelbrain.boosting(eegNDVar_, env_, -0.100, 0.600, error='l1', basis=0.050, partitions=5, test=1)
p = eelbrain.plot.TopoButterfly(res.h_scaled, w=6, h=2)
p.set_time(.180)
# Out:
# Fitting models:   0%|          | 0/2560 [00:00<?, ?it/s]

# %%
p = eelbrain.plot.TopoButterfly(res.h_scaled, w=6, h=2)
p.set_time(.40)

# %%
p = eelbrain.plot.Topomap(res.proportion_explained, w=6, h=4)
p.set_vlim(-0.01, 0.01)
# proportion_explained: is the results of the highest TRF similarity of every channel
# remember to save the result of it for further examination of

# %%
Subj = 1
eelbrain.save.pickle(res, 'Subj%d_TRFs_envelop.pickle'%(Subj))

# %%
Subj = 1
res = eelbrain.load.unpickle('Subj%d_TRFs_envelop.pickle'%(Subj))
p = eelbrain.plot.TopoButterfly(res.h_scaled, w=10, h=4)
p.set_time(.180)

# %%
p = eelbrain.plot.TopoButterfly(res.h_scaled, w=10, h=4)
p.set_time(.40)

# %%
#Making the Word onset TRFs >> if onset = 1
onset_word = word_onsets_NDVar(1, time)
eelbrain.plot.UTS(onset_word, xlim=10, w=6, h=2)

# %%
# repeat the same procedure to get run1 to run5's 
onset_word2 = word_onsets_NDVar(2, time2)
onset_word3 = word_onsets_NDVar(3, time3)
onset_word4 = word_onsets_NDVar(4, time4)
onset_word5 = word_onsets_NDVar(5, time5)


w_on = eelbrain.concatenate([onset_word, onset_word2, onset_word3, onset_word4, onset_word5])
eelbrain.plot.UTS(w_on, xlim=100, w=10, h=4)

# %%
res_v2 = eelbrain.boosting(eegNDVar_, [env_, w_on],  -0.1, 0.6, error='l1',
                        basis=0.050, partitions=5, test=1, selective_stopping=True)
#[env_, w_on] >> 這裡放envelope & word onset 的 TRFs, if you want more, then add it into the list
Subj = 1
eelbrain.save.pickle(res_v2, 'Subj%d_TRFs_envelop_w_on.pickle'%(Subj))

p = eelbrain.plot.TopoButterfly(res_v2.h_scaled, w=6, h=2)
p.set_time(.180)
# Out:
# Fitting models:   0%|          | 0/2560 [00:00<?, ?it/s]

# %%
# 可嘗試的做法>>做6個受試者，然後做完每個runs
"""
raw, envelope, time = get_raw_EEG(1, 1)
raw.filter(1, 20)
eegNDVar3 = raw2NDvar(raw, time3)

'''
ica here

'''

raw2, envelope2, time2 = get_raw_EEG(1, 1)
raw2.filter(1, 20)
ica.apply(raw2)
eegNDVar3 = raw2NDvar(raw3, time3)

raw3, envelope3, time3 = get_raw_EEG(1, 3)
raw3.filter(1, 20)
ica.apply(raw3)
eegNDVar3 = raw2NDvar(raw3, time3)

raw4, envelope4, time4 = get_raw_EEG(1, 4)
raw4.filter(1, 20)
ica.apply(raw4)
eegNDVar4 = raw2NDvar(raw4, time4)

raw5, envelope5, time5 = get_raw_EEG(1, 5)
raw5.filter(1, 20)
ica.apply(raw5)
eegNDVar5 = raw2NDvar(raw5, time5)

env_ = eelbrain.concatenate([envelope, envelope2, envelope3, envelope4, envelope5])
eegNDVar_ = eelbrain.concatenate([eegNDVar, eegNDVar2, eegNDVar3, eegNDVar4, eegNDVar5])

onset_word = word_onsets_NDVar(1, time)
onset_word2 = word_onsets_NDVar(2, time2)
onset_word3 = word_onsets_NDVar(3, time3)
onset_word4 = word_onsets_NDVar(4, time4)
onset_word5 = word_onsets_NDVar(5, time5)

w_on = eelbrain.concatenate([onset_word, onset_word2, onset_word3, onset_word4, onset_word5])

res_v1 = eelbrain.boosting(eegNDVar_, env_,  -0.1, 0.6, error='l1',
                        basis=0.050, partitions=5, test=1, selective_stopping=True)

res_v2 = eelbrain.boosting(eegNDVar_, w_on,  -0.1, 0.6, error='l1',
                        basis=0.050, partitions=5, test=1, selective_stopping=True)

res_v3 = eelbrain.boosting(eegNDVar_, [env_, w_on],  -0.1, 0.6, error='l1',
                        basis=0.050, partitions=5, test=1, selective_stopping=True)

Subj = 1
eelbrain.save.pickle(res_v1, 'Subj%d_TRFs_envelop_w_on.pickle'%(Subj))
eelbrain.save.pickle(res_v2, 'Subj%d_TRFs_envelop_w_on.pickle'%(Subj))
eelbrain.save.pickle(res_v3, 'Subj%d_TRFs_envelop_w_on.pickle'%(Subj))
"""

# %%
Subj = 1
res_v2 = eelbrain.load.unpickle('Subj%d_TRFs_envelop_w_on.pickle'%(Subj))
p = eelbrain.plot.TopoButterfly(res_v2.h_scaled, w=10, h=4)
p.set_time(.180)

# %%
p = eelbrain.plot.Topomap(res_v2.proportion_explained, w=6, h=5)
p.set_vlim(-0.01, 0.01) #This one can adjust the color of the graph

# %%
eelbrain.plot.Topomap([res.r, res_v2.r], w=4, h=2, ncol=2, axtitle=['envelope', 'envelope + onset'])

# %%
p = eelbrain.plot.TopoButterfly(res_v2.h_scaled[0], vmin = -1, vmax = 1, w=10, h=4)
p.set_time(.40)

# %%
p = eelbrain.plot.TopoButterfly(res_v2.h_scaled[1], vmax = 0.5, vmin = -0.5, w=10, h=4)
p.set_time(.510)
