# %%
# %matplotlib inline

# %%
from pathlib import Path
import re
import matplotlib.pyplot as plt
from matplotlib import pyplot
import eelbrain
import mne
import trftools

from pprint import pprint
import numpy as np

# %%
## NATIVES ##

STIMULI = [str(i) for i in range(1, 13)]
DATA_ROOT = Path("/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results")  #Path("~").expanduser() / 'Data' / 'Alice'
PREDICTOR_audio_DIR = DATA_ROOT / 'TRFs_pridictors/audio_predictors'
PREDICTOR_word_DIR = DATA_ROOT / 'TRFs_pridictors/word_predictors'
EEG_DIR = DATA_ROOT / 'EEG_Natives' / 'Alice_natives_ICAed_fif'
Native_SUBJECTS = [path.name for path in EEG_DIR.iterdir() if re.match(r'S\d*', path.name)]
# Define a target directory for TRF estimates and make sure the directory is created
TRF_DIR = DATA_ROOT / 'TRFs_Natives'
TRF_DIR.mkdir(exist_ok=True)
print(Native_SUBJECTS)
print(len(Native_SUBJECTS))
# Out:
# ['S13_Alice-natives_sfreq-100_raw.fif', 'S14_Alice-natives_sfreq-100_raw.fif', 'S12_Alice-natives_sfreq-100_raw.fif', 'S15_Alice-natives_sfreq-100_raw.fif', 'S11_Alice-natives_sfreq-100_raw.fif', 'S16_Alice-natives_sfreq-100_raw.fif', 'S17_Alice-natives_sfreq-100_raw.fif', 'S18_Alice-natives_sfreq-100_raw.fif', 'S19_Alice-natives_sfreq-100_raw.fif', 'S20_Alice-natives_sfreq-100_raw.fif', 'S21_Alice-natives_sfreq-100_raw.fif', 'S01_Alice-natives_sfreq-100_raw.fif', 'S03_Alice-natives_sfreq-100_raw.fif', 'S04_Alice-natives_sfreq-100_raw.fif', 'S05_Alice-natives_sfreq-100_raw.fif', 'S06_Alice-natives_sfreq-100_raw.fif', 'S08_Alice-natives_sfreq-100_raw.fif', 'S10_Alice-natives_sfreq-100_raw.fif', 'S22_Alice-natives_sfreq-100_raw.fif', 'S25_Alice-natives_sfreq-100_raw.fif', 'S26_Alice-natives_sfreq-100_raw.fif', 'S34_Alice-natives_sfreq-100_raw.fif', 'S35_Alice-natives_sfreq-100_raw.fif', 'S36_Alice-natives_sfreq-100_raw.fif', 'S37_Alice-natives_sfreq-100_raw.fif', 'S38_Alice-natives_sfreq-100_raw.fif', 'S39_Alice-natives_sfreq-100_raw.fif', 'S40_Alice-natives_sfreq-100_raw.fif', 'S41_Alice-natives_sfreq-100_raw.fif', 'S42_Alice-natives_sfreq-100_raw.fif', 'S44_Alice-natives_sfreq-100_raw.fif', 'S45_Alice-natives_sfreq-100_raw.fif', 'S48_Alice-natives_sfreq-100_raw.fif']
# 33

# %%
## Codes here failed terriblely
modelsLIST = ['envelope', 'envelope+onset', 'acoustic', 'words', 'words+lexical', 'acoustic+words', 'acoustic+words+lexical']
"""
modelsDICT = {
    # Acoustic models
    'envelope': ["envelope"],
    'envelope+onset': ["envelope, onset_envelope"],
    'acoustic': ["gammatone, gammatone_onsets"],

    # Models with word-onsets and word-class
    'words': ["word_onsets"],
    'words+lexical': ["word_onsets, word_lexical, word_nlexical"],  # covariant model
    'acoustic+words': ["gammatone, gammatone_onsets, word_onsets"],
    'acoustic+words+lexical': ["gammatone, gammatone_onsets, word_onsets, word_lexical, word_nlexical"]
}
"""   
    
for subject in Native_SUBJECTS:
    subject_trf_dir = TRF_DIR / subject  # TRF_DIR / subject[4:8] == original path
    #subject_trf_dir.mkdir(exist_ok=True) # shut down for now
    # Generate all TRF paths so we can check whether any new TRFs need to be estimated
    trf_paths = {model: subject_trf_dir / f'{subject} {model}.pickle' for model in models}
    print(trf_paths)
    '''
    ## The explaination of the above command
    for model in models:
        trf_paths = {model: subject_trf_dir / f'{subject} {model}.pickle'}
        pprint(trf_paths)
        
    for model, predictors in modelsDICT.items():
        print(model)
        """ ## Return result ##
        envelope
        envelope+onset
        acoustic
        words
        words+lexical
        acoustic+words
        acoustic+words+lexical
        """
    '''
    for model in modelsLIST:
        path = trf_paths[model]
        #print(path)
        trf = eelbrain.load.unpickle(TRF_DIR / subject / f'{subject} {model}.pickle')
        print(trf)
        #print(trf[:3, ])
        eelbrain.save.pickle(trf[:3], path)
    #n_trf = 
    #eelbrain.save.pickle(trf, path)
# Out:
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S13_Alice-natives_sfreq-100_raw.fif/S13_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S13_Alice-natives_sfreq-100_raw.fif/S13_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S13_Alice-natives_sfreq-100_raw.fif/S13_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S13_Alice-natives_sfreq-100_raw.fif/S13_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S13_Alice-natives_sfreq-100_raw.fif/S13_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S13_Alice-natives_sfreq-100_raw.fif/S13_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S13_Alice-natives_sfreq-100_raw.fif/S13_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S13 envelope.pickle
# S13 envelope+onset.pickle
# S13 acoustic.pickle
# S13 words.pickle
# S13 words+lexical.pickle
# S13 acoustic+words.pickle
# S13 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S14_Alice-natives_sfreq-100_raw.fif/S14_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S14_Alice-natives_sfreq-100_raw.fif/S14_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S14_Alice-natives_sfreq-100_raw.fif/S14_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S14_Alice-natives_sfreq-100_raw.fif/S14_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S14_Alice-natives_sfreq-100_raw.fif/S14_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S14_Alice-natives_sfreq-100_raw.fif/S14_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S14_Alice-natives_sfreq-100_raw.fif/S14_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S14 envelope.pickle
# S14 envelope+onset.pickle
# S14 acoustic.pickle
# S14 words.pickle
# S14 words+lexical.pickle
# S14 acoustic+words.pickle
# S14 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S12_Alice-natives_sfreq-100_raw.fif/S12_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S12_Alice-natives_sfreq-100_raw.fif/S12_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S12_Alice-natives_sfreq-100_raw.fif/S12_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S12_Alice-natives_sfreq-100_raw.fif/S12_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S12_Alice-natives_sfreq-100_raw.fif/S12_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S12_Alice-natives_sfreq-100_raw.fif/S12_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S12_Alice-natives_sfreq-100_raw.fif/S12_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S12 envelope.pickle
# S12 envelope+onset.pickle
# S12 acoustic.pickle
# S12 words.pickle
# S12 words+lexical.pickle
# S12 acoustic+words.pickle
# S12 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S15_Alice-natives_sfreq-100_raw.fif/S15_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S15_Alice-natives_sfreq-100_raw.fif/S15_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S15_Alice-natives_sfreq-100_raw.fif/S15_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S15_Alice-natives_sfreq-100_raw.fif/S15_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S15_Alice-natives_sfreq-100_raw.fif/S15_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S15_Alice-natives_sfreq-100_raw.fif/S15_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S15_Alice-natives_sfreq-100_raw.fif/S15_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S15 envelope.pickle
# S15 envelope+onset.pickle
# S15 acoustic.pickle
# S15 words.pickle
# S15 words+lexical.pickle
# S15 acoustic+words.pickle
# S15 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S11_Alice-natives_sfreq-100_raw.fif/S11_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S11_Alice-natives_sfreq-100_raw.fif/S11_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S11_Alice-natives_sfreq-100_raw.fif/S11_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S11_Alice-natives_sfreq-100_raw.fif/S11_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S11_Alice-natives_sfreq-100_raw.fif/S11_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S11_Alice-natives_sfreq-100_raw.fif/S11_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S11_Alice-natives_sfreq-100_raw.fif/S11_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S11 envelope.pickle
# S11 envelope+onset.pickle
# S11 acoustic.pickle
# S11 words.pickle
# S11 words+lexical.pickle
# S11 acoustic+words.pickle
# S11 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S16_Alice-natives_sfreq-100_raw.fif/S16_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S16_Alice-natives_sfreq-100_raw.fif/S16_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S16_Alice-natives_sfreq-100_raw.fif/S16_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S16_Alice-natives_sfreq-100_raw.fif/S16_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S16_Alice-natives_sfreq-100_raw.fif/S16_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S16_Alice-natives_sfreq-100_raw.fif/S16_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S16_Alice-natives_sfreq-100_raw.fif/S16_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S16 envelope.pickle
# S16 envelope+onset.pickle
# S16 acoustic.pickle
# S16 words.pickle
# S16 words+lexical.pickle
# S16 acoustic+words.pickle
# S16 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S17_Alice-natives_sfreq-100_raw.fif/S17_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S17_Alice-natives_sfreq-100_raw.fif/S17_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S17_Alice-natives_sfreq-100_raw.fif/S17_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S17_Alice-natives_sfreq-100_raw.fif/S17_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S17_Alice-natives_sfreq-100_raw.fif/S17_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S17_Alice-natives_sfreq-100_raw.fif/S17_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S17_Alice-natives_sfreq-100_raw.fif/S17_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S17 envelope.pickle
# S17 envelope+onset.pickle
# S17 acoustic.pickle
# S17 words.pickle
# S17 words+lexical.pickle
# S17 acoustic+words.pickle
# S17 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S18_Alice-natives_sfreq-100_raw.fif/S18_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S18_Alice-natives_sfreq-100_raw.fif/S18_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S18_Alice-natives_sfreq-100_raw.fif/S18_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S18_Alice-natives_sfreq-100_raw.fif/S18_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S18_Alice-natives_sfreq-100_raw.fif/S18_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S18_Alice-natives_sfreq-100_raw.fif/S18_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S18_Alice-natives_sfreq-100_raw.fif/S18_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S18 envelope.pickle
# S18 envelope+onset.pickle
# S18 acoustic.pickle
# S18 words.pickle
# S18 words+lexical.pickle
# S18 acoustic+words.pickle
# S18 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S19_Alice-natives_sfreq-100_raw.fif/S19_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S19_Alice-natives_sfreq-100_raw.fif/S19_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S19_Alice-natives_sfreq-100_raw.fif/S19_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S19_Alice-natives_sfreq-100_raw.fif/S19_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S19_Alice-natives_sfreq-100_raw.fif/S19_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S19_Alice-natives_sfreq-100_raw.fif/S19_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S19_Alice-natives_sfreq-100_raw.fif/S19_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S19 envelope.pickle
# S19 envelope+onset.pickle
# S19 acoustic.pickle
# S19 words.pickle
# S19 words+lexical.pickle
# S19 acoustic+words.pickle
# S19 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S20_Alice-natives_sfreq-100_raw.fif/S20_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S20_Alice-natives_sfreq-100_raw.fif/S20_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S20_Alice-natives_sfreq-100_raw.fif/S20_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S20_Alice-natives_sfreq-100_raw.fif/S20_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S20_Alice-natives_sfreq-100_raw.fif/S20_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S20_Alice-natives_sfreq-100_raw.fif/S20_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S20_Alice-natives_sfreq-100_raw.fif/S20_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S20 envelope.pickle
# S20 envelope+onset.pickle
# S20 acoustic.pickle
# S20 words.pickle
# S20 words+lexical.pickle
# S20 acoustic+words.pickle
# S20 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S21_Alice-natives_sfreq-100_raw.fif/S21_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S21_Alice-natives_sfreq-100_raw.fif/S21_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S21_Alice-natives_sfreq-100_raw.fif/S21_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S21_Alice-natives_sfreq-100_raw.fif/S21_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S21_Alice-natives_sfreq-100_raw.fif/S21_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S21_Alice-natives_sfreq-100_raw.fif/S21_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S21_Alice-natives_sfreq-100_raw.fif/S21_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S21 envelope.pickle
# S21 envelope+onset.pickle
# S21 acoustic.pickle
# S21 words.pickle
# S21 words+lexical.pickle
# S21 acoustic+words.pickle
# S21 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S01_Alice-natives_sfreq-100_raw.fif/S01_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S01_Alice-natives_sfreq-100_raw.fif/S01_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S01_Alice-natives_sfreq-100_raw.fif/S01_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S01_Alice-natives_sfreq-100_raw.fif/S01_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S01_Alice-natives_sfreq-100_raw.fif/S01_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S01_Alice-natives_sfreq-100_raw.fif/S01_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S01_Alice-natives_sfreq-100_raw.fif/S01_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S01 envelope.pickle
# S01 envelope+onset.pickle
# S01 acoustic.pickle
# S01 words.pickle
# S01 words+lexical.pickle
# S01 acoustic+words.pickle
# S01 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S03_Alice-natives_sfreq-100_raw.fif/S03_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S03_Alice-natives_sfreq-100_raw.fif/S03_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S03_Alice-natives_sfreq-100_raw.fif/S03_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S03_Alice-natives_sfreq-100_raw.fif/S03_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S03_Alice-natives_sfreq-100_raw.fif/S03_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S03_Alice-natives_sfreq-100_raw.fif/S03_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S03_Alice-natives_sfreq-100_raw.fif/S03_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S03 envelope.pickle
# S03 envelope+onset.pickle
# S03 acoustic.pickle
# S03 words.pickle
# S03 words+lexical.pickle
# S03 acoustic+words.pickle
# S03 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S04_Alice-natives_sfreq-100_raw.fif/S04_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S04_Alice-natives_sfreq-100_raw.fif/S04_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S04_Alice-natives_sfreq-100_raw.fif/S04_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S04_Alice-natives_sfreq-100_raw.fif/S04_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S04_Alice-natives_sfreq-100_raw.fif/S04_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S04_Alice-natives_sfreq-100_raw.fif/S04_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S04_Alice-natives_sfreq-100_raw.fif/S04_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S04 envelope.pickle
# S04 envelope+onset.pickle
# S04 acoustic.pickle
# S04 words.pickle
# S04 words+lexical.pickle
# S04 acoustic+words.pickle
# S04 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S05_Alice-natives_sfreq-100_raw.fif/S05_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S05_Alice-natives_sfreq-100_raw.fif/S05_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S05_Alice-natives_sfreq-100_raw.fif/S05_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S05_Alice-natives_sfreq-100_raw.fif/S05_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S05_Alice-natives_sfreq-100_raw.fif/S05_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S05_Alice-natives_sfreq-100_raw.fif/S05_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S05_Alice-natives_sfreq-100_raw.fif/S05_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S05 envelope.pickle
# S05 envelope+onset.pickle
# S05 acoustic.pickle
# S05 words.pickle
# S05 words+lexical.pickle
# S05 acoustic+words.pickle
# S05 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S06_Alice-natives_sfreq-100_raw.fif/S06_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S06_Alice-natives_sfreq-100_raw.fif/S06_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S06_Alice-natives_sfreq-100_raw.fif/S06_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S06_Alice-natives_sfreq-100_raw.fif/S06_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S06_Alice-natives_sfreq-100_raw.fif/S06_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S06_Alice-natives_sfreq-100_raw.fif/S06_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S06_Alice-natives_sfreq-100_raw.fif/S06_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S06 envelope.pickle
# S06 envelope+onset.pickle
# S06 acoustic.pickle
# S06 words.pickle
# S06 words+lexical.pickle
# S06 acoustic+words.pickle
# S06 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S08_Alice-natives_sfreq-100_raw.fif/S08_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S08_Alice-natives_sfreq-100_raw.fif/S08_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S08_Alice-natives_sfreq-100_raw.fif/S08_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S08_Alice-natives_sfreq-100_raw.fif/S08_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S08_Alice-natives_sfreq-100_raw.fif/S08_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S08_Alice-natives_sfreq-100_raw.fif/S08_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S08_Alice-natives_sfreq-100_raw.fif/S08_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S08 envelope.pickle
# S08 envelope+onset.pickle
# S08 acoustic.pickle
# S08 words.pickle
# S08 words+lexical.pickle
# S08 acoustic+words.pickle
# S08 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S10_Alice-natives_sfreq-100_raw.fif/S10_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S10_Alice-natives_sfreq-100_raw.fif/S10_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S10_Alice-natives_sfreq-100_raw.fif/S10_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S10_Alice-natives_sfreq-100_raw.fif/S10_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S10_Alice-natives_sfreq-100_raw.fif/S10_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S10_Alice-natives_sfreq-100_raw.fif/S10_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S10_Alice-natives_sfreq-100_raw.fif/S10_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S10 envelope.pickle
# S10 envelope+onset.pickle
# S10 acoustic.pickle
# S10 words.pickle
# S10 words+lexical.pickle
# S10 acoustic+words.pickle
# S10 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S22_Alice-natives_sfreq-100_raw.fif/S22_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S22_Alice-natives_sfreq-100_raw.fif/S22_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S22_Alice-natives_sfreq-100_raw.fif/S22_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S22_Alice-natives_sfreq-100_raw.fif/S22_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S22_Alice-natives_sfreq-100_raw.fif/S22_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S22_Alice-natives_sfreq-100_raw.fif/S22_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S22_Alice-natives_sfreq-100_raw.fif/S22_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S22 envelope.pickle
# S22 envelope+onset.pickle
# S22 acoustic.pickle
# S22 words.pickle
# S22 words+lexical.pickle
# S22 acoustic+words.pickle
# S22 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S25_Alice-natives_sfreq-100_raw.fif/S25_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S25_Alice-natives_sfreq-100_raw.fif/S25_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S25_Alice-natives_sfreq-100_raw.fif/S25_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S25_Alice-natives_sfreq-100_raw.fif/S25_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S25_Alice-natives_sfreq-100_raw.fif/S25_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S25_Alice-natives_sfreq-100_raw.fif/S25_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S25_Alice-natives_sfreq-100_raw.fif/S25_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S25 envelope.pickle
# S25 envelope+onset.pickle
# S25 acoustic.pickle
# S25 words.pickle
# S25 words+lexical.pickle
# S25 acoustic+words.pickle
# S25 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S26_Alice-natives_sfreq-100_raw.fif/S26_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S26_Alice-natives_sfreq-100_raw.fif/S26_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S26_Alice-natives_sfreq-100_raw.fif/S26_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S26_Alice-natives_sfreq-100_raw.fif/S26_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S26_Alice-natives_sfreq-100_raw.fif/S26_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S26_Alice-natives_sfreq-100_raw.fif/S26_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S26_Alice-natives_sfreq-100_raw.fif/S26_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S26 envelope.pickle
# S26 envelope+onset.pickle
# S26 acoustic.pickle
# S26 words.pickle
# S26 words+lexical.pickle
# S26 acoustic+words.pickle
# S26 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S34_Alice-natives_sfreq-100_raw.fif/S34_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S34_Alice-natives_sfreq-100_raw.fif/S34_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S34_Alice-natives_sfreq-100_raw.fif/S34_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S34_Alice-natives_sfreq-100_raw.fif/S34_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S34_Alice-natives_sfreq-100_raw.fif/S34_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S34_Alice-natives_sfreq-100_raw.fif/S34_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S34_Alice-natives_sfreq-100_raw.fif/S34_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S34 envelope.pickle
# S34 envelope+onset.pickle
# S34 acoustic.pickle
# S34 words.pickle
# S34 words+lexical.pickle
# S34 acoustic+words.pickle
# S34 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S35_Alice-natives_sfreq-100_raw.fif/S35_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S35_Alice-natives_sfreq-100_raw.fif/S35_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S35_Alice-natives_sfreq-100_raw.fif/S35_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S35_Alice-natives_sfreq-100_raw.fif/S35_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S35_Alice-natives_sfreq-100_raw.fif/S35_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S35_Alice-natives_sfreq-100_raw.fif/S35_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S35_Alice-natives_sfreq-100_raw.fif/S35_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S35 envelope.pickle
# S35 envelope+onset.pickle
# S35 acoustic.pickle
# S35 words.pickle
# S35 words+lexical.pickle
# S35 acoustic+words.pickle
# S35 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S36_Alice-natives_sfreq-100_raw.fif/S36_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S36_Alice-natives_sfreq-100_raw.fif/S36_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S36_Alice-natives_sfreq-100_raw.fif/S36_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S36_Alice-natives_sfreq-100_raw.fif/S36_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S36_Alice-natives_sfreq-100_raw.fif/S36_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S36_Alice-natives_sfreq-100_raw.fif/S36_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S36_Alice-natives_sfreq-100_raw.fif/S36_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S36 envelope.pickle
# S36 envelope+onset.pickle
# S36 acoustic.pickle
# S36 words.pickle
# S36 words+lexical.pickle
# S36 acoustic+words.pickle
# S36 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S37_Alice-natives_sfreq-100_raw.fif/S37_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S37_Alice-natives_sfreq-100_raw.fif/S37_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S37_Alice-natives_sfreq-100_raw.fif/S37_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S37_Alice-natives_sfreq-100_raw.fif/S37_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S37_Alice-natives_sfreq-100_raw.fif/S37_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S37_Alice-natives_sfreq-100_raw.fif/S37_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S37_Alice-natives_sfreq-100_raw.fif/S37_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S37 envelope.pickle
# S37 envelope+onset.pickle
# S37 acoustic.pickle
# S37 words.pickle
# S37 words+lexical.pickle
# S37 acoustic+words.pickle
# S37 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S38_Alice-natives_sfreq-100_raw.fif/S38_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S38_Alice-natives_sfreq-100_raw.fif/S38_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S38_Alice-natives_sfreq-100_raw.fif/S38_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S38_Alice-natives_sfreq-100_raw.fif/S38_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S38_Alice-natives_sfreq-100_raw.fif/S38_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S38_Alice-natives_sfreq-100_raw.fif/S38_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S38_Alice-natives_sfreq-100_raw.fif/S38_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S38 envelope.pickle
# S38 envelope+onset.pickle
# S38 acoustic.pickle
# S38 words.pickle
# S38 words+lexical.pickle
# S38 acoustic+words.pickle
# S38 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S39_Alice-natives_sfreq-100_raw.fif/S39_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S39_Alice-natives_sfreq-100_raw.fif/S39_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S39_Alice-natives_sfreq-100_raw.fif/S39_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S39_Alice-natives_sfreq-100_raw.fif/S39_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S39_Alice-natives_sfreq-100_raw.fif/S39_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S39_Alice-natives_sfreq-100_raw.fif/S39_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S39_Alice-natives_sfreq-100_raw.fif/S39_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S39 envelope.pickle
# S39 envelope+onset.pickle
# S39 acoustic.pickle
# S39 words.pickle
# S39 words+lexical.pickle
# S39 acoustic+words.pickle
# S39 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S40_Alice-natives_sfreq-100_raw.fif/S40_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S40_Alice-natives_sfreq-100_raw.fif/S40_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S40_Alice-natives_sfreq-100_raw.fif/S40_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S40_Alice-natives_sfreq-100_raw.fif/S40_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S40_Alice-natives_sfreq-100_raw.fif/S40_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S40_Alice-natives_sfreq-100_raw.fif/S40_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S40_Alice-natives_sfreq-100_raw.fif/S40_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S40 envelope.pickle
# S40 envelope+onset.pickle
# S40 acoustic.pickle
# S40 words.pickle
# S40 words+lexical.pickle
# S40 acoustic+words.pickle
# S40 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S41_Alice-natives_sfreq-100_raw.fif/S41_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S41_Alice-natives_sfreq-100_raw.fif/S41_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S41_Alice-natives_sfreq-100_raw.fif/S41_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S41_Alice-natives_sfreq-100_raw.fif/S41_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S41_Alice-natives_sfreq-100_raw.fif/S41_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S41_Alice-natives_sfreq-100_raw.fif/S41_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S41_Alice-natives_sfreq-100_raw.fif/S41_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S41 envelope.pickle
# S41 envelope+onset.pickle
# S41 acoustic.pickle
# S41 words.pickle
# S41 words+lexical.pickle
# S41 acoustic+words.pickle
# S41 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S42_Alice-natives_sfreq-100_raw.fif/S42_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S42_Alice-natives_sfreq-100_raw.fif/S42_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S42_Alice-natives_sfreq-100_raw.fif/S42_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S42_Alice-natives_sfreq-100_raw.fif/S42_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S42_Alice-natives_sfreq-100_raw.fif/S42_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S42_Alice-natives_sfreq-100_raw.fif/S42_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S42_Alice-natives_sfreq-100_raw.fif/S42_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S42 envelope.pickle
# S42 envelope+onset.pickle
# S42 acoustic.pickle
# S42 words.pickle
# S42 words+lexical.pickle
# S42 acoustic+words.pickle
# S42 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S44_Alice-natives_sfreq-100_raw.fif/S44_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S44_Alice-natives_sfreq-100_raw.fif/S44_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S44_Alice-natives_sfreq-100_raw.fif/S44_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S44_Alice-natives_sfreq-100_raw.fif/S44_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S44_Alice-natives_sfreq-100_raw.fif/S44_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S44_Alice-natives_sfreq-100_raw.fif/S44_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S44_Alice-natives_sfreq-100_raw.fif/S44_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S44 envelope.pickle
# S44 envelope+onset.pickle
# S44 acoustic.pickle
# S44 words.pickle
# S44 words+lexical.pickle
# S44 acoustic+words.pickle
# S44 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S45_Alice-natives_sfreq-100_raw.fif/S45_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S45_Alice-natives_sfreq-100_raw.fif/S45_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S45_Alice-natives_sfreq-100_raw.fif/S45_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S45_Alice-natives_sfreq-100_raw.fif/S45_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S45_Alice-natives_sfreq-100_raw.fif/S45_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S45_Alice-natives_sfreq-100_raw.fif/S45_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S45_Alice-natives_sfreq-100_raw.fif/S45_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S45 envelope.pickle
# S45 envelope+onset.pickle
# S45 acoustic.pickle
# S45 words.pickle
# S45 words+lexical.pickle
# S45 acoustic+words.pickle
# S45 acoustic+words+lexical.pickle
# {'envelope': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S48_Alice-natives_sfreq-100_raw.fif/S48_Alice-natives_sfreq-100_raw.fif envelope.pickle'), 'envelope+onset': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S48_Alice-natives_sfreq-100_raw.fif/S48_Alice-natives_sfreq-100_raw.fif envelope+onset.pickle'), 'acoustic': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S48_Alice-natives_sfreq-100_raw.fif/S48_Alice-natives_sfreq-100_raw.fif acoustic.pickle'), 'words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S48_Alice-natives_sfreq-100_raw.fif/S48_Alice-natives_sfreq-100_raw.fif words.pickle'), 'words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S48_Alice-natives_sfreq-100_raw.fif/S48_Alice-natives_sfreq-100_raw.fif words+lexical.pickle'), 'acoustic+words': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S48_Alice-natives_sfreq-100_raw.fif/S48_Alice-natives_sfreq-100_raw.fif acoustic+words.pickle'), 'acoustic+words+lexical': PosixPath('/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results/TRFs_Natives/S48_Alice-natives_sfreq-100_raw.fif/S48_Alice-natives_sfreq-100_raw.fif acoustic+words+lexical.pickle')}
# S48 envelope.pickle
# S48 envelope+onset.pickle
# S48 acoustic.pickle
# S48 words.pickle
# S48 words+lexical.pickle
# S48 acoustic+words.pickle
# S48 acoustic+words+lexical.pickle

# %% [markdown]
# ## Natives Auditory TRFs

# %% [markdown]
# ##### Pre-define models here to have easier access during estimation. In the future, additional models could be added here and the script re-run to generate additional TRFs.
#     models = {
#         # Acoustic models
#         'envelope': [envelope],
#         'envelope+onset': [envelope, onset_envelope],
#         'acoustic': [gammatone, gammatone_onsets],
#
#         # Models with word-onsets and word-class
#         'words': [word_onsets],
#         'words+lexical': [word_onsets, word_lexical, word_nlexical],  # covariant model
#         'acoustic+words': [gammatone, gammatone_onsets, word_onsets],
#         'acoustic+words+lexical': [gammatone, gammatone_onsets, word_onsets, word_lexical, word_nlexical],
#
#         # Language Models
#         'Ngram': [word_Ngram, word_onsets, word_lexical, word_nlexical],
#         'CFG': [word_CFG, word_onsets, word_lexical, word_nlexical],
#         'Ngram-CFG_all': [word_Ngram, word_CFG, word_onsets, word_lexical, word_nlexical]
#     }
# m = covar
# m1 = covar + Ngram
# m2 = covar + CFG
# m3 = covar + Ngram + CFG

# %%
## TRF: envelope ##
n_rowsLIST = []
    
for subj in Native_SUBJECTS:
    n_subj = int(subj[1:3])
    trf = eelbrain.load.unpickle(TRF_DIR / Path('S%.2d/S%.2d envelope.pickle'%(int(subj[1:3]), int(subj[1:3]))))
    n_rowsLIST.append([n_subj, trf.proportion_explained, trf.h[0]])#.abs()])

data_env = eelbrain.Dataset.from_caselist(['subject', 'det', 'trf'], n_rowsLIST)
pprint(n_rowsLIST)
print(data_env)


#test that model predictive power on held-out data is > 0
test_envelope = eelbrain.testnd.TTestOneSample('det', ds=data_env, tail=1, pmin=0.05)
#p = eelbrain.plot.Topomap(test_envelope)
#cb = p.plot_colorbar(width=0.1)


# ## Envelope TRF
# Test the TRF with a one-sample *t*-test against 0. This tests the null-hypothesis that the electrical current direction at each time point was random across subjects. The systematic current directions shown below at anterior electrodes are typical of auditory responses. 
trf_envelope = eelbrain.testnd.TTestOneSample('trf', ds=data_env, pmin=0.05)
print(trf_envelope)  # print out the stats results
onesample_clus = trf_envelope.find_clusters(0.05)
print(onesample_clus) # print out the cluster result

p1 = eelbrain.plot.TopoArray(trf_envelope,t=[0.05, 0.15], clip='circle', cmap='xpolar', h=4, w=8) #, t=[0.08, 0.16, 0.22, 0.45]
cb = p1.plot_colorbar(width=0.1)

#p1.save(TRF_DIR / 'Natives_envelope-TRFs.png')

"""
# USELESS PIC
trf = eelbrain.load.unpickle(TRF_DIR / Path('S%.2d_Alice-natives_sfreq-100_raw.fif/S%.2d_Alice-natives_sfreq-100_raw.fif acoustic.pickle'%(subj, subj)))
trf_sensor = trf.proportion_explained
print(trf_sensor)
print(trf.h[0].shape)

#print(type(trf.h))
#plt.plot(trf.h[:,0,:])
p = eelbrain.plot.TopoButterfly(trf.h[0], w=6, h=5)

#p = eelbrain.plot.TopoButterfly(trf.h[0], w=10, h=4, sensors=trf_sensor)
#p.set_time(.180)
"""
# Out:
# [[13, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [14, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [12, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [15, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [11, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [16, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [17, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [18, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [19, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [20, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [21, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [1, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [3, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [4, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [5, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [6, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [8, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [10, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [22, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [25, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [26, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [34, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [35, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [36, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [37, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [38, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [39, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [40, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [41, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [42, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [44, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [45, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>],
#  [48, <NDVar '1': 59 sensor>, <NDVar 'envelope': 59 sensor, 114 time>]]
# subject
# -------
# 13
# 14
# 12
# 15
# 11
# 16
# 17
# 18
# 19
# 20
# 21
# 1
# 3
# 4
# 5
# 6
# 8
# 10
# 22
# 25
# 26
# 34
# 35
# 36
# 37
# 38
# 39
# 40
# 41
# 42
# 44
# 45
# 48
# -------
# NDVars: det, trf
# <TTestOneSample 'trf', samples=10000, pmin=0.05, 36 clusters, p < .001>
# id    n_sensors   tstart   tstop   duration   v         p        sig
# --------------------------------------------------------------------
# 1     44          -0.12    0.28    0.4        2461.6    0.0001   ***
# 106   55          0.19     1.02    0.83       -5496.3   0        ***
# "\n# USELESS PIC\ntrf = eelbrain.load.unpickle(TRF_DIR / Path('S%.2d_Alice-natives_sfreq-100_raw.fif/S%.2d_Alice-natives_sfreq-100_raw.fif acoustic.pickle'%(subj, subj)))\ntrf_sensor = trf.proportion_explained\nprint(trf_sensor)\nprint(trf.h[0].shape)\n\n#print(type(trf.h))\n#plt.plot(trf.h[:,0,:])\np = eelbrain.plot.TopoButterfly(trf.h[0], w=6, h=5)\n\n#p = eelbrain.plot.TopoButterfly(trf.h[0], w=10, h=4, sensors=trf_sensor)\n#p.set_time(.180)\n"

# %%
## TRF: envelope+onset ##
n_rowsLIST = []
    
for subj in Native_SUBJECTS:
    n_subj = int(subj[1:3])
    trf = eelbrain.load.unpickle(TRF_DIR / Path('S%.2d/S%.2d envelope+onset.pickle'%(int(subj[1:3]), int(subj[1:3]))))
    n_rowsLIST.append([subj[1:3], trf.proportion_explained, *trf.h])#.abs()])
    x_names = trf.x
data_onset = eelbrain.Dataset.from_caselist(['subject', 'det', *x_names], n_rowsLIST)
#pprint(n_rowsLIST)
#print(data_onset)
test_onset = eelbrain.testnd.TTestOneSample('det', ds=data_onset, tail=1, pmin=0.05)

# Paired t-test by specifying two measurement NDVars with matched cases
# Note that this presupposes that subjects are in the same order
# data_onset['det'], data_env['det'], tail=1 == 'envelope+onset': [envelope, onset_envelope] >/- 'envelope': [envelope]
test_onset_envelope = eelbrain.testnd.TTestRelated(data_onset['det'], data_env['det'], tail=1, pmin=0.05)
p2 = eelbrain.plot.Topomap(
    [test_onset.masked_difference(), test_onset_envelope.masked_difference()], 
    axtitle=[['Envelope + Onsets\n', test_onset], ['Envelope + Onsets > Envelope\n', test_onset_envelope]],
    ncol=2, clip='circle')
cb = p2.plot_colorbar(width=0.1)

p2.save(TRF_DIR / 'Natives_Envelope+onset-TRFs_topo.png')

# %%
rows = []
x_names = None

n_rowsLIST = []
    
for subj in Native_SUBJECTS:
    n_subj = int(subj[1:3])
    trf = eelbrain.load.unpickle(TRF_DIR / Path('S%.2d/S%.2d acoustic.pickle'%(int(subj[1:3]), int(subj[1:3]))))
    n_rowsLIST.append([n_subj, trf.proportion_explained, *trf.h])#.abs()])
    x_names = trf.x
data_acoustic = eelbrain.Dataset.from_caselist(['subject', 'det', *x_names], n_rowsLIST)
pprint(n_rowsLIST)
print(data_onset)

# Compare predictive power of the two models
test_acoustic = eelbrain.testnd.TTestOneSample('det', ds=data_acoustic, tail=1, pmin=0.05)

# Paired t-test by specifying two measurement NDVars with matched cases
# Note that this presupposes that subjects are in the same order
test_acoustic_onset = eelbrain.testnd.TTestRelated(data_acoustic['det'], data_onset['det'], tail=1, pmin=0.05)
p3 = eelbrain.plot.Topomap(
    [test_acoustic.masked_difference(), test_acoustic_onset.masked_difference()], 
    axtitle=[[['Spectrogram\n', test_acoustic], ], ['Spectrogram > Envelope\n', test_acoustic_onset]],
    ncol=2, clip='circle')
cb = p3.plot_colorbar(width=0.1)

#p3.save(TRF_DIR / 'Natives_acoustic-TRFs_topo.png')
# Out:
# [[13,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [14,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [12,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [15,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [11,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [16,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [17,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [18,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [19,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [20,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [21,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [1,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [3,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [4,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [5,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [6,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [8,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [10,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [22,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [25,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [26,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [34,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [35,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [36,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [37,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [38,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [39,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [40,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [41,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [42,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [44,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [45,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>],
#  [48,
#   <NDVar '1': 59 sensor>,
#   <NDVar 'gammatone': 59 sensor, 8 frequency, 114 time>,
#   <NDVar 'gammatone_on': 59 sensor, 8 frequency, 114 time>]]
# subject
# -------
# 13
# 14
# 12
# 15
# 11
# 16
# 17
# 18
# 19
# 20
# 21
# 01
# 03
# 04
# 05
# 06
# 08
# 10
# 22
# 25
# 26
# 34
# 35
# 36
# 37
# 38
# 39
# 40
# 41
# 42
# 44
# 45
# 48
# -------
# NDVars: det, envelope

# %%
### LATER ANALYSIS  ###
# ## TRFs
# Since these spectrogram mTRFs have a frequency dimension in addition to time and sensor we have to slice or aggregate them for visualization on a 2d plot. We take two approaches: 
#
#  1) Sum across the frequency, based on the assumtopn that TRFs are similar for different frequency bands
#  2) Average across a group of neighboring sensors, to verify this assumtopn 

trf_spectrogram = eelbrain.testnd.TTestOneSample("gammatone.sum('frequency')", ds=data_acoustic, pmin=0.05)
trf_onset_spectrogram = eelbrain.testnd.TTestOneSample("gammatone_on.sum('frequency')", ds=data_acoustic, pmin=0.05)

#p4 = eelbrain.plot.TopoArray([trf_spectrogram, trf_onset_spectrogram], t=[0.050, 0.100, 0.150, 0.450], xlim=(-0.050, 0.950))

# Manually define sensors that are sensitive to acoustic responses 
auditory_sensors = ['59', '20', '21', '7', '8', '9', '49', '19' ,'44', '45', '34' ,'35' ,'36' ,'10']
p5 = eelbrain.plot.SensorMap(data_acoustic['det'], h=2, mark=auditory_sensors)

#strf_spectrogram = data_acoustic['gammatone'].mean(sensor=auditory_sensors).smooth('frequency', window_samples=7, fix_edges=True)
print(type(data_acoustic['gammatone'].mean(sensor=auditory_sensors)))
#strf_onset_spectrogram = data_acoustic['gammatone_on'].mean(sensor=auditory_sensors)
#p6 = eelbrain.plot.Array([strf_spectrogram, strf_onset_spectrogram], ncol=2, xlim=(-0.050, 0.950))


#p4.save(TRF_DIR / 'Natives_acoustic-TRFs_topo.png')
#p5.save(TRF_DIR / 'Natives_acoustic-TRFs_topo.png')
#p6.save(TRF_DIR / 'Natives_acoustic-TRFs_topo.png')
# Out:
# <class 'eelbrain._data_obj.NDVar'>

# %%
# Load cross-validated preditive power of all models
models = ['envelope', 'envelope+onset', 'acoustic']
n_rowsLIST = []

for model in models:
    for subj in Native_SUBJECTS:
        n_subj = int(subj[1:3])
        trf = eelbrain.load.unpickle(TRF_DIR / Path('S%.2d/S%.2d %s.pickle'%(int(subj[1:3]), int(subj[1:3]), model)))
        n_rowsLIST.append([n_subj, model, trf.proportion_explained])
model_data = eelbrain.Dataset.from_caselist(['subject', 'model', 'det'], n_rowsLIST)
# For more interpretable numbers, express proportion explained in terms of the maximum explained variability by the full model
index = model_data['model'] == 'acoustic'
model_data['det'] *= 100 / model_data[index, 'det'].mean('case').max('sensor')

# Redo tests with adjusted predictive power 
test_envelope = eelbrain.testnd.TTestOneSample('det', sub="model == 'envelope'", ds=model_data, tail=1, pmin=0.05)
test_acoustic = eelbrain.testnd.TTestOneSample('det', sub="model == 'acoustic'", ds=model_data, tail=1, pmin=0.05)
test_onset_envelope = eelbrain.testnd.TTestRelated('det', 'model', 'envelope+onset', 'envelope', 'subject', ds=model_data, tail=1, pmin=0.05)
test_acoustic_onset = eelbrain.testnd.TTestRelated('det', 'model', 'acoustic', 'envelope+onset', 'subject', ds=model_data, tail=1, pmin=0.05)

t_envelope = [0.050, 0.150, 0.300]# old timepoint = [0.050, 0.100, 0.150, 0.400]
t_onset = [0.060, 0.190] # old timepoint = [0.060, 0.110, 0.180]

# T-test on Env+Onset TRF's "Env" part
trf_eo_envelope = eelbrain.testnd.TTestOneSample('envelope', ds=data_onset, pmin=0.05)
print(trf_eo_envelope)  # print out the stats results
onesample_eoEnv_clus = trf_eo_envelope.find_clusters(0.05)
print(onesample_eoEnv_clus) # print out the cluster result

# T-test on Env+Onset TRF's "Onset" part
trf_eo_onset = eelbrain.testnd.TTestOneSample('onset', ds=data_onset, pmin=0.05)
print(trf_eo_onset)  # print out the stats results
onesample_eoOnset_clus = trf_eo_onset.find_clusters(0.05)
print(onesample_eoOnset_clus) # print out the cluster result


#'Envelope TRF'
p7 = eelbrain.plot.TopoArray(trf_envelope, t=t_envelope) 
p7.plot_colorbar(width=0.1) #below=axes[1], **cbar_args, ticks=0, label='TRF (a.u.)')

#'Onset TRF' in envelope+onset
p8 = eelbrain.plot.TopoArray(trf_eo_onset, t=t_onset)
p8.plot_colorbar(width=0.1)
# 'Envelope TRF' in envelope+onset
p9 = eelbrain.plot.TopoArray(trf_eo_envelope, t=t_envelope)
p9.plot_colorbar(width=0.1)

"""
# 'Onset STRF (sum across frequency)'
p10 = eelbrain.plot.TopoArray(trf_onset_spectrogram, t=t_onset)
p10.plot_colorbar(width=0.1)
# 'Envelope STRF (sum across frequency)'
p11 = eelbrain.plot.TopoArray(trf_spectrogram, t=t_envelope)
p11.plot_colorbar(width=0.1)
"""

p7.save(TRF_DIR / 'Natives_Envelope TRF_envelop.png')
p8.save(TRF_DIR / 'Natives_Envelope+onset TRF_Onset TRF.png')
p9.save(TRF_DIR / 'Natives_Envelope+onset TRF_Envelope TRF.png')
#p10.save(TRF_DIR / 'Natives_Onset TRF_sum-of-freq.png')
#p11.save(TRF_DIR / 'Natives_Envelope TRF_sum-of-freq.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/h7/sdf5cvgx3qzf5rh744693x0r0000gn/T/ipykernel_59174/1736748440.py in <module>
#      23
#      24 # T-test on Env+Onset TRF's "Env" part
# ---> 25 trf_eo_envelope = eelbrain.testnd.TTestOneSample('envelope', ds=data_onset, pmin=0.05)
#      26 print(trf_eo_envelope)  # print out the stats results
#      27 onesample_eoEnv_clus = trf_eo_envelope.find_clusters(0.05)
#
# NameError: name 'data_onset' is not defined

# %% [markdown]
# ## Natives Word-class-acoustics TRFs

# %% [markdown]
# ##### Pre-define models here to have easier access during estimation. In the future, additional models could be added here and the script re-run to generate additional TRFs.
#     models = {
#         # Acoustic models
#         'envelope': [envelope],
#         'envelope+onset': [envelope, onset_envelope],
#         'acoustic': [gammatone, gammatone_onsets],
#
#         # Models with word-onsets and word-class
#         'words': [word_onsets],
#         'words+lexical': [word_onsets, word_lexical, word_nlexical],
#         'acoustic+words': [gammatone, gammatone_onsets, word_onsets],
#         'acoustic+words+lexical': [gammatone, gammatone_onsets, word_onsets, word_lexical, word_nlexical],
#
#         # Language Models
#         'Ngram': [word_Ngram, word_onsets, word_lexical, word_nlexical],
#         'CFG': [word_CFG, word_onsets, word_lexical, word_nlexical],
#         'Ngram-CFG_all': [word_Ngram, word_CFG, word_onsets, word_lexical, word_nlexical]
#     }
# m = covar
# m1 = covar + Ngram
# m2 = covar + CFG
# m3 = covar + Ngram + CFG

# %%
## NATIVES ##

STIMULI = [str(i) for i in range(1, 13)]
DATA_ROOT = Path("/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results")  #Path("~").expanduser() / 'Data' / 'Alice'
PREDICTOR_audio_DIR = DATA_ROOT / 'TRFs_pridictors/audio_predictors'
PREDICTOR_word_DIR = DATA_ROOT / 'TRFs_pridictors/word_predictors'
EEG_DIR = DATA_ROOT / 'EEG_Natives' / 'Alice_natives_ICAed_fif'
Native_SUBJECTS = [path.name for path in EEG_DIR.iterdir() if re.match(r'S\d*', path.name)]
# Define a target directory for TRF estimates and make sure the directory is created
TRF_DIR = DATA_ROOT / 'TRFs_Natives'
TRF_DIR.mkdir(exist_ok=True)
print(Native_SUBJECTS)
DST = TRF_DIR / 'Natives_figures'
DST.mkdir(exist_ok=True)
# Out:
# ['S13_Alice-natives_sfreq-100_raw.fif', 'S14_Alice-natives_sfreq-100_raw.fif', 'S12_Alice-natives_sfreq-100_raw.fif', 'S15_Alice-natives_sfreq-100_raw.fif', 'S11_Alice-natives_sfreq-100_raw.fif', 'S16_Alice-natives_sfreq-100_raw.fif', 'S17_Alice-natives_sfreq-100_raw.fif', 'S18_Alice-natives_sfreq-100_raw.fif', 'S19_Alice-natives_sfreq-100_raw.fif', 'S20_Alice-natives_sfreq-100_raw.fif', 'S21_Alice-natives_sfreq-100_raw.fif', 'S01_Alice-natives_sfreq-100_raw.fif', 'S03_Alice-natives_sfreq-100_raw.fif', 'S04_Alice-natives_sfreq-100_raw.fif', 'S05_Alice-natives_sfreq-100_raw.fif', 'S06_Alice-natives_sfreq-100_raw.fif', 'S08_Alice-natives_sfreq-100_raw.fif', 'S10_Alice-natives_sfreq-100_raw.fif', 'S22_Alice-natives_sfreq-100_raw.fif', 'S25_Alice-natives_sfreq-100_raw.fif', 'S26_Alice-natives_sfreq-100_raw.fif', 'S34_Alice-natives_sfreq-100_raw.fif', 'S35_Alice-natives_sfreq-100_raw.fif', 'S36_Alice-natives_sfreq-100_raw.fif', 'S37_Alice-natives_sfreq-100_raw.fif', 'S38_Alice-natives_sfreq-100_raw.fif', 'S39_Alice-natives_sfreq-100_raw.fif', 'S40_Alice-natives_sfreq-100_raw.fif', 'S41_Alice-natives_sfreq-100_raw.fif', 'S42_Alice-natives_sfreq-100_raw.fif', 'S44_Alice-natives_sfreq-100_raw.fif', 'S45_Alice-natives_sfreq-100_raw.fif', 'S48_Alice-natives_sfreq-100_raw.fif']

# %%
# # Do brain responses differ between word class?
# Test whether adding predcitors that distinguish function and content words improves the predictive power of the TRF models.

# Load predictive power of all models
models = ['words', 'words+lexical', 'acoustic+words', 'acoustic+words+lexical']
rows = []
for model in models:
    for subject in Native_SUBJECTS:
        n_subj = int(subject[1:3])
        trf = eelbrain.load.unpickle(TRF_DIR / subject[:3] / f'{subject[:3]} {model}.pickle')
        rows.append([n_subj, model, trf.proportion_explained])
#print(rows)
model_data = eelbrain.Dataset.from_caselist(['subject', 'model', 'det'], rows)
#print(model_data)

# For more interpretable numbers, express proportion explained in terms of the maximum explained variability of the most complete model
index = model_data['model'] == 'acoustic+words+lexical'
model_data['det'] *= 100 / model_data[index, 'det'].mean('case').max('sensor')
lexical_model_test = eelbrain.testnd.TTestRelated('det', 'model', 'words+lexical', 'words', match='subject', ds=model_data, tail=1, pmin=0.05)
print(lexical_model_test)
lexical_ttrelated_clus = lexical_model_test.find_clusters(0.05)
print(lexical_ttrelated_clus)

p12 = eelbrain.plot.Topomap(lexical_model_test, ncol=3, title=lexical_model_test, axh=2, clip='circle')
#p12.save(DST / 'Natives_acoustic+words+lexical_TRF_topo.png')
# Out:
# <TTestRelated 'det', 'model', 'words+lexical', 'words', 'subject' (n=33), tail=1, samples=10000, pmin=0.05, 1 clusters, p = .002>
# id   n_sensors   v        p        sig
# --------------------------------------
# 1    26          64.975   0.0015   **

# %%
# ## How do the responses differ?
# Compare the TRFs corresponding to content and function words.

# Load the TRFs:
# Keep `h_scaled` instead of `h` so that we can compare and add TRFs to different predictors
# Because each predictor gets normalized for estimation, the scale of the TRFs in `h` are all different
# The `h_scaled` attribute reverses that normalization, so that the TRFs are all in a common scale
rows = []
for subject in Native_SUBJECTS:
    n_subj = int(subject[1:3])
    trf = eelbrain.load.unpickle(TRF_DIR / subject[:3] / f'{subject[:3]} words+lexical.pickle')
    rows.append([n_subj, model, *trf.h_scaled])
    #print(model)
trfs = eelbrain.Dataset.from_caselist(['subject', 'model', *trf.x], rows)
#print(trfs)


# Each word has an impulse of the general word predictor, as well as one form the word-class specific predictor
# Accordingly, each word's response consists of the general word TRF and the word-class specific TRF
# To reconstruct the responses to the two kinds of words, we thus want to add the general word TRF and the word-class specific TRF:
word_difference = eelbrain.testnd.TTestRelated('non_lexical + word', 'lexical + word', ds=trfs, tail=1, tstart=0, pmin=0.05)
function_Onesamtest = eelbrain.testnd.TTestOneSample('non_lexical', match='subject', ds=trfs, tail=1, tstart=0, pmin=0.05)
content_Onesamtest = eelbrain.testnd.TTestOneSample('lexical', match='subject', ds=trfs, tail=1, tstart=0, pmin=0.05)

word_diff_clus = word_difference.find_clusters(0.05)
function_clus = function_Onesamtest.find_clusters(0.05)
content_clus = content_Onesamtest.find_clusters(0.05)

print(word_difference)
print(word_diff_clus)
print(function_Onesamtest)
print(function_clus)
print(content_Onesamtest)
print(content_clus)

p13 = eelbrain.plot.TopoArray(word_difference, axtitle=["Function word", "Content word", "Function - Content"], t=[0.220], clip='circle')  # t=[0.120, 0.220, 0.400]
p14 = eelbrain.plot.TopoArray(function_Onesamtest, title="Function word", t=[0.22], clip='circle')
p15 = eelbrain.plot.TopoArray(content_Onesamtest, title="Content word", t=[0.03, 0.31, 0.58], clip='circle')

p13.save(DST / 'Natives_Islexical_TRF.png')
p14.save(DST / 'Natives_Function_word_TRF.png')
p15.save(DST / 'Natives_Content_word_TRF.png')
# Out:
# <TTestRelated 'non_lexical', 'lexical' (n=33), tail=1, samples=10000, pmin=0.05, tstart=0, 30 clusters, p < .001>
# id   n_sensors   tstart   tstop   duration   v        p   sig
# -------------------------------------------------------------
# 1    59          0.06     0.98    0.92       5049.7   0   ***
# <TTestOneSample 'non_lexical', match='subject', tail=1, samples=10000, pmin=0.05, tstart=0, 22 clusters, p < .001>
# id   n_sensors   tstart        tstop   duration   v      p   sig
# ----------------------------------------------------------------
# 1    57          -1.3878e-17   0.52    0.52       4198   0   ***
# <TTestOneSample 'lexical', match='subject', tail=1, samples=10000, pmin=0.05, tstart=0, 16 clusters, p = .019>
# id   n_sensors   tstart        tstop   duration   v        p        sig
# -----------------------------------------------------------------------
# 1    43          -1.3878e-17   0.15    0.15       762.24   0.0186   *

# %% [markdown]
# ## Natives POS-Models TRFs

# %% [markdown]
# ##### Pre-define models here to have easier access during estimation. In the future, additional models could be added here and the script re-run to generate additional TRFs.
#     models = {
#         # Acoustic models
#         'envelope': [envelope],
#         'envelope+onset': [envelope, onset_envelope],
#         'acoustic': [gammatone, gammatone_onsets],
#
#         # Models with word-onsets and word-class
#         'words': [word_onsets],
#         'words+lexical': [word_onsets, word_lexical, word_nlexical],
#         'acoustic+words': [gammatone, gammatone_onsets, word_onsets],
#         'acoustic+words+lexical': [gammatone, gammatone_onsets, word_onsets, word_lexical, word_nlexical],
#
#         # Language Models
#         'words+lexical': [word_onsets, word_lexical, word_nlexical],  # = m(covar)
#         'Ngram': [word_Ngram, word_onsets, word_lexical, word_nlexical],  # = m1(covar + Ngram)
#         'CFG': [word_CFG, word_onsets, word_lexical, word_nlexical],  # = m2(covar + CFG)
#         'Ngram-CFG_all': [word_Ngram, word_CFG, word_onsets, word_lexical, word_nlexical]  # = m3(covar + CFG + Ngram)
#     }
# m = covar
# m1 = covar + Ngram
# m2 = covar + CFG
# m3 = covar + Ngram + CFG

# %%
## NATIVES ##

STIMULI = [str(i) for i in range(1, 13)]
DATA_ROOT = Path("/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results")  #Path("~").expanduser() / 'Data' / 'Alice'
PREDICTOR_audio_DIR = DATA_ROOT / 'TRFs_pridictors/audio_predictors'
PREDICTOR_word_DIR = DATA_ROOT / 'TRFs_pridictors/word_predictors'
EEG_DIR = DATA_ROOT / 'EEG_Natives' / 'Alice_natives_ICAed_fif'
Native_SUBJECTS = [path.name for path in EEG_DIR.iterdir() if re.match(r'S\d*', path.name)]
# Define a target directory for TRF estimates and make sure the directory is created
TRF_DIR = DATA_ROOT / 'TRFs_Natives'
TRF_DIR.mkdir(exist_ok=True)
print(Native_SUBJECTS)
DST = TRF_DIR / 'Natives_figures'
DST.mkdir(exist_ok=True)
# Out:
# ['S13_Alice-natives_sfreq-100_raw.fif', 'S14_Alice-natives_sfreq-100_raw.fif', 'S12_Alice-natives_sfreq-100_raw.fif', 'S15_Alice-natives_sfreq-100_raw.fif', 'S11_Alice-natives_sfreq-100_raw.fif', 'S16_Alice-natives_sfreq-100_raw.fif', 'S17_Alice-natives_sfreq-100_raw.fif', 'S18_Alice-natives_sfreq-100_raw.fif', 'S19_Alice-natives_sfreq-100_raw.fif', 'S20_Alice-natives_sfreq-100_raw.fif', 'S21_Alice-natives_sfreq-100_raw.fif', 'S01_Alice-natives_sfreq-100_raw.fif', 'S03_Alice-natives_sfreq-100_raw.fif', 'S04_Alice-natives_sfreq-100_raw.fif', 'S05_Alice-natives_sfreq-100_raw.fif', 'S06_Alice-natives_sfreq-100_raw.fif', 'S08_Alice-natives_sfreq-100_raw.fif', 'S10_Alice-natives_sfreq-100_raw.fif', 'S22_Alice-natives_sfreq-100_raw.fif', 'S25_Alice-natives_sfreq-100_raw.fif', 'S26_Alice-natives_sfreq-100_raw.fif', 'S34_Alice-natives_sfreq-100_raw.fif', 'S35_Alice-natives_sfreq-100_raw.fif', 'S36_Alice-natives_sfreq-100_raw.fif', 'S37_Alice-natives_sfreq-100_raw.fif', 'S38_Alice-natives_sfreq-100_raw.fif', 'S39_Alice-natives_sfreq-100_raw.fif', 'S40_Alice-natives_sfreq-100_raw.fif', 'S41_Alice-natives_sfreq-100_raw.fif', 'S42_Alice-natives_sfreq-100_raw.fif', 'S44_Alice-natives_sfreq-100_raw.fif', 'S45_Alice-natives_sfreq-100_raw.fif', 'S48_Alice-natives_sfreq-100_raw.fif']

# %%
# # Do brain responses differ between word class?
# Test whether adding predcitors that distinguish function and content words improves the predictive power of the TRF models.

# Load predictive power of all models
models = ['words+lexical', 'Ngram', 'CFG', 'Ngram-CFG_all']
rows = []
for model in models:
    for subject in Native_SUBJECTS:
        n_subj = int(subject[1:3])
        trf = eelbrain.load.unpickle(TRF_DIR / subject[:3] / f'{subject[:3]} {model}.pickle')
        trf.x = ['ngram', 'cfg', 'word', 'lexical', 'non_lexical']
        rows.append([n_subj, model, trf.proportion_explained])
model_data = eelbrain.Dataset.from_caselist(['subject', 'model', 'det'], rows)

# For more interpretable numbers, express proportion explained in terms of the maximum explained variability of the most complete model
index = model_data['model'] == 'Ngram-CFG_all'
model_data['det'] *= 100 / model_data[index, 'det'].mean('case').max('sensor')

 # OLD commands(Dich it for now)
Ngram_model_test = eelbrain.testnd.TTestRelated('det', 'model', 'Ngram', 'words+lexical', match='subject', ds=model_data, tail=1, pmin=0.05)
CFG_model_test = eelbrain.testnd.TTestRelated('det', 'model', 'CFG', 'words+lexical', match='subject', ds=model_data, tail=1, pmin=0.05)
NgramCFG_model_test = eelbrain.testnd.TTestRelated('det', 'model', 'Ngram', 'CFG', match='subject', ds=model_data, tail=1, pmin=0.05)

Ngram_ttrelated_clus = Ngram_model_test.find_clusters(0.05)
CFG_ttrelated_clus = CFG_model_test.find_clusters(0.05)
NgramCFG_ttrelated_clus = NgramCFG_model_test.find_clusters(0.05)

print(Ngram_model_test)
print(Ngram_ttrelated_clus)
print(CFG_model_test)
print(CFG_ttrelated_clus)
print(NgramCFG_model_test)
print(NgramCFG_ttrelated_clus)

p18 = eelbrain.plot.Topomap(Ngram_model_test, ncol=3, title=Ngram_model_test, axh=2, clip='circle')
p19 = eelbrain.plot.Topomap(CFG_model_test, ncol=3, title=CFG_model_test, axh=2, clip='circle')
p20 = eelbrain.plot.Topomap(NgramCFG_model_test, ncol=3, title=NgramCFG_model_test, axh=2, clip='circle')

""""""
p18.save(DST / 'Natives_Ngram_TRF_topo.png')
p19.save(DST / 'Natives_CFG_TRF_topo.png')
p20.save(DST / 'Natives_NgramCFG_TRF_topo.png')
# Out:
# Process ForkProcess-7:
# Process ForkProcess-9:
# Process ForkProcess-8:
# Process ForkProcess-6:
# Traceback (most recent call last):
# Process ForkProcess-10:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/eelbrain/_stats/testnd.py", line 3755, in distribution_worker
#     dist[i] = in_queue.get()
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/connection.py", line 221, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/eelbrain/_stats/testnd.py", line 3776, in permutation_worker
#     max_v = map_processor.max_stat(stat_map)
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/eelbrain/_stats/testnd.py", line 2769, in max_stat
#     cids = _label_clusters(stat_map, threshold, self.tail, self.connectivity,
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/eelbrain/_stats/testnd.py", line 3772, in permutation_worker
#     perm = in_queue.get()
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/eelbrain/_stats/testnd.py", line 2558, in _label_clusters
#     cids = _label_clusters_binary(bin_map_above, cmap, cmap_flat, conn,
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/eelbrain/_stats/testnd.py", line 2627, in _label_clusters_binary
#     n = ndimage.label(bin_map, connectivity.struct, cmap)
# KeyboardInterrupt
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/scipy/ndimage/_measurements.py", line 219, in label
#     max_label = _ni_label._label(input, structure, output)
#   File "_ni_label.pyx", line 202, in _ni_label._label
#   File "_ni_label.pyx", line 239, in _ni_label._label
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/eelbrain/_stats/testnd.py", line 3776, in permutation_worker
#     max_v = map_processor.max_stat(stat_map)
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/eelbrain/_stats/testnd.py", line 3772, in permutation_worker
#     perm = in_queue.get()
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/eelbrain/_stats/testnd.py", line 2769, in max_stat
#     cids = _label_clusters(stat_map, threshold, self.tail, self.connectivity,
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/eelbrain/_stats/testnd.py", line 2558, in _label_clusters
#     cids = _label_clusters_binary(bin_map_above, cmap, cmap_flat, conn,
# KeyboardInterrupt
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/eelbrain/_stats/testnd.py", line 2627, in _label_clusters_binary
#     n = ndimage.label(bin_map, connectivity.struct, cmap)
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/scipy/ndimage/_measurements.py", line 219, in label
#     max_label = _ni_label._label(input, structure, output)
#   File "_ni_label.pyx", line 202, in _ni_label._label
#   File "_ni_label.pyx", line 224, in _ni_label._label
#   File "<__array_function__ internals>", line 180, in all
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 2489, in all
#     return _wrapreduction(a, np.logical_and, 'all', axis, None, out,
#   File "/Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 86, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [20], line 21
#      19  # OLD commands(Dich it for now)
#      20 Ngram_model_test = eelbrain.testnd.TTestRelated('det', 'model', 'Ngram', 'words+lexical', match='subject', ds=model_data, tail=1, pmin=0.05)
# ---> 21 CFG_model_test = eelbrain.testnd.TTestRelated('det', 'model', 'CFG', 'words+lexical', match='subject', ds=model_data, tail=1, pmin=0.05)
#      22 NgramCFG_model_test = eelbrain.testnd.TTestRelated('det', 'model', 'Ngram', 'CFG', match='subject', ds=model_data, tail=1, pmin=0.05)
#      24 Ngram_ttrelated_clus = Ngram_model_test.find_clusters(0.05)
#
# File /Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File /Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/eelbrain/_stats/testnd.py:1416, in TTestRelated.__init__(self, y, x, c1, c0, match, sub, ds, tail, samples, pmin, tmin, tfce, tstart, tstop, parc, force_permutation, **criteria)
#    1414     if cdist.do_permutation:
#    1415         iterator = permute_sign_flip(n, samples)
# -> 1416         run_permutation(opt.t_1samp_perm, cdist, iterator)
#    1418 # NDVar map of t-values
#    1419 info = _info.for_stat_map('t', threshold, tail=tail, old=y1.info)
#
# File /Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/eelbrain/_stats/testnd.py:3786, in run_permutation(test_func, dist, iterator, *args)
#    3784 try:
#    3785     for perm in iterator:
# -> 3786         out_queue.put(perm)
#    3788     for _ in range(len(workers) - 1):
#    3789         out_queue.put(None)
#
# File /Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/queues.py:377, in SimpleQueue.put(self, obj)
#     375 else:
#     376     with self._wlock:
# --> 377         self._writer.send_bytes(obj)
#
# File /Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/connection.py:205, in _ConnectionBase.send_bytes(self, buf, offset, size)
#     203 elif offset + size > n:
#     204     raise ValueError("buffer length < offset + size")
# --> 205 self._send_bytes(m[offset:offset + size])
#
# File /Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/connection.py:416, in Connection._send_bytes(self, buf)
#     410     self._send(buf)
#     411 else:
#     412     # Issue #20540: concatenate before sending, to avoid delays due
#     413     # to Nagle's algorithm on a TCP socket.
#     414     # Also note we want to avoid sending a 0-length buffer separately,
#     415     # to avoid "broken pipe" errors if the other end closed the pipe.
# --> 416     self._send(header + buf)
#
# File /Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/multiprocessing/connection.py:373, in Connection._send(self, buf, write)
#     371 remaining = len(buf)
#     372 while True:
# --> 373     n = write(self._handle, buf)
#     374     remaining -= n
#     375     if remaining == 0:
#
# KeyboardInterrupt:

# %%
# ## How do the responses differ?
# Compare the TRFs corresponding to Ngram, CFG , and combined(Ngram+CFG).

# Load the TRFs:
# Keep `h_scaled` instead of `h` so that we can compare and add TRFs to different predictors
# Because each predictor gets normalized for estimation, the scale of the TRFs in `h` are all different
# The `h_scaled` attribute reverses that normalization, so that the TRFs are all in a common scale
rows = []
for subject in Native_SUBJECTS:
    n_subj = int(subject[1:3])
    trf = eelbrain.load.unpickle(TRF_DIR / subject[:3] / f'{subject[:3]} Ngram-CFG_all.pickle')
    trf.x = ['ngram', 'cfg', 'word', 'lexical', 'non_lexical'] #rename the n-gram model
    rows.append([n_subj, model, *trf.h_scaled])
trfs = eelbrain.Dataset.from_caselist(['subject', 'model', *trf.x], rows)
#pprint(rows)

# redo the t-test (use one-sample to see effects from Ngram & CFG, because it is m1/m2 - m >>)
Ngram_Onesamtest = eelbrain.testnd.TTestOneSample('ngram', match='subject', ds=trfs, tail=1, tstart=0, pmin=0.05)
CFG_Onesamtest = eelbrain.testnd.TTestOneSample('cfg', match='subject', ds=trfs, tail=1, tstart=0, pmin=0.05)
NgramCFG_pairedttest = eelbrain.testnd.TTestRelated('ngram', 'cfg', ds=trfs, tail=1, tstart=0, pmin=0.05)  #, match='subject'
# Tail >> set 0(two-tailed) or 1 (upper_one-tailed)?  ; Why we close the "subject", then it's ok >> match = None??

# Find the sig clusters
Ngram_Onesamtest_clus =Ngram_Onesamtest.find_clusters(0.05)
CFG_Onesamtest_clus =CFG_Onesamtest.find_clusters(0.05)
NgramCFG_pairedttest_clus =NgramCFG_pairedttest.find_clusters(0.05)

# Print out the Stats and its clusters
print(Ngram_Onesamtest)
print(Ngram_Onesamtest_clus)
print(CFG_Onesamtest)
print(CFG_Onesamtest_clus)
print(NgramCFG_pairedttest)
print(NgramCFG_pairedttest_clus)

# Plot the topoarray of model
p21_Ngram = eelbrain.plot.TopoArray(Ngram_Onesamtest, t=[0.21], clip='circle') 
p21_Ngram.plot_colorbar(width=0.1)
p22_CFG = eelbrain.plot.TopoArray(CFG_Onesamtest, t=[0.21], clip='circle') 
p22_CFG.plot_colorbar(width=0.1)
p23_ALL = eelbrain.plot.TopoArray(NgramCFG_pairedttest, t=[0.21], clip='circle') 
p23_ALL.plot_colorbar(width=0.1)

p21_Ngram.save(DST / 'Natives_Ngram_TRF.png')
p22_CFG.save(DST / 'Natives_CFG_TRF.png')
p23_ALL.save(DST / 'Natives_NgramCFG_TRF.png')

# %% [markdown]
# ## Natives IF TRFs (all six IMFs)
#
# ##### Pre-define models here to have easier access during estimation. In the future, additional models could be added here and the script re-run to generate additional TRFs.
#     models = {
#         # Acoustic models
#         'envelope': [envelope],
#         'envelope+onset': [envelope, onset_envelope],
#         'acoustic': [gammatone, gammatone_onsets],
#
#         # Models with word-onsets and word-class
#         'words': [word_onsets],
#         'words+lexical': [word_onsets, word_lexical, word_nlexical],
#         'acoustic+words': [gammatone, gammatone_onsets, word_onsets],
#         'acoustic+words+lexical': [gammatone, gammatone_onsets, word_onsets, word_lexical, word_nlexical],
#
#         # Language Models
#         'words+lexical': [word_onsets, word_lexical, word_nlexical],  # = m(covar)
#         'Ngram': [word_Ngram, word_onsets, word_lexical, word_nlexical],  # = m1(covar + Ngram)
#         'CFG': [word_CFG, word_onsets, word_lexical, word_nlexical],  # = m2(covar + CFG)
#         'Ngram-CFG_all': [word_Ngram, word_CFG, word_onsets, word_lexical, word_nlexical]  # = m3(covar + CFG + Ngram)
#
#         # IFs
#         'IMF_1':[imf_1],
#         'IMF_2':[imf_2],
#         'IMF_3':[imf_3],
#         'IMF_4':[imf_4],
#         'IMF_5':[imf_5],
#         'IMF_6':[imf_6]
#         'IMF_All':[imf_1, imf_2, imf_3, imf_4, imf_5, imf_6],
#
#         # All auditory features model
#         'All_Aud_model':[envelope, onset_envelope, word_onsets, word_lexical, word_nlexical, imf_1, imf_2, imf_3, imf_4, imf_5, imf_6]
#
#         # All model
#         'All_model':[envelope, onset_envelope, word_onsets, word_lexical, word_nlexical, word_CFG, word_Ngramm, imf_1, imf_2, imf_3, imf_4, imf_5, imf_6]
#     }
# m = covar
# m1 = covar + Ngram
# m2 = covar + CFG
# m3 = covar + Ngram + CFG

# %%
## NATIVES ##
STIMULI = [str(i) for i in range(1, 13)]
DATA_ROOT = Path("/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results")  #Path("~").expanduser() / 'Data' / 'Alice'
PREDICTOR_audio_DIR = DATA_ROOT / 'TRFs_pridictors/audio_predictors'
PREDICTOR_word_DIR = DATA_ROOT / 'TRFs_pridictors/word_predictors'
EEG_DIR = DATA_ROOT / 'EEG_Natives' / 'Alice_natives_ICAed_fif'
IMF_DIR = DATA_ROOT/ "TRFs_pridictors/IF_predictors"
IMFsLIST = [path.name for path in IMF_DIR.iterdir() if re.match(r'Alice_IF_IMF_*', path.name)] 
Native_SUBJECTS = [path.name for path in EEG_DIR.iterdir() if re.match(r'S\d*', path.name)]
# Define a target directory for TRF estimates and make sure the directory is created
TRF_DIR = DATA_ROOT / 'TRFs_Natives'
TRF_DIR.mkdir(exist_ok=True)
print(Native_SUBJECTS)
print(IMFsLIST)
DST = TRF_DIR / 'Natives_figures'
DST.mkdir(exist_ok=True)
# Out:
# ['S13_Alice-natives_sfreq-100_raw.fif', 'S14_Alice-natives_sfreq-100_raw.fif', 'S12_Alice-natives_sfreq-100_raw.fif', 'S15_Alice-natives_sfreq-100_raw.fif', 'S11_Alice-natives_sfreq-100_raw.fif', 'S16_Alice-natives_sfreq-100_raw.fif', 'S17_Alice-natives_sfreq-100_raw.fif', 'S18_Alice-natives_sfreq-100_raw.fif', 'S19_Alice-natives_sfreq-100_raw.fif', 'S20_Alice-natives_sfreq-100_raw.fif', 'S21_Alice-natives_sfreq-100_raw.fif', 'S01_Alice-natives_sfreq-100_raw.fif', 'S03_Alice-natives_sfreq-100_raw.fif', 'S04_Alice-natives_sfreq-100_raw.fif', 'S05_Alice-natives_sfreq-100_raw.fif', 'S06_Alice-natives_sfreq-100_raw.fif', 'S08_Alice-natives_sfreq-100_raw.fif', 'S10_Alice-natives_sfreq-100_raw.fif', 'S22_Alice-natives_sfreq-100_raw.fif', 'S25_Alice-natives_sfreq-100_raw.fif', 'S26_Alice-natives_sfreq-100_raw.fif', 'S34_Alice-natives_sfreq-100_raw.fif', 'S35_Alice-natives_sfreq-100_raw.fif', 'S36_Alice-natives_sfreq-100_raw.fif', 'S37_Alice-natives_sfreq-100_raw.fif', 'S38_Alice-natives_sfreq-100_raw.fif', 'S39_Alice-natives_sfreq-100_raw.fif', 'S40_Alice-natives_sfreq-100_raw.fif', 'S41_Alice-natives_sfreq-100_raw.fif', 'S42_Alice-natives_sfreq-100_raw.fif', 'S44_Alice-natives_sfreq-100_raw.fif', 'S45_Alice-natives_sfreq-100_raw.fif', 'S48_Alice-natives_sfreq-100_raw.fif']
# ['Alice_IF_IMF_1.pickle', 'Alice_IF_IMF_2.pickle', 'Alice_IF_IMF_3.pickle', 'Alice_IF_IMF_4.pickle', 'Alice_IF_IMF_5.pickle', 'Alice_IF_IMF_6.pickle']

# %%
# ## How do the responses differ?
# Compare the TRFs corresponding to all individual IMFs, and combined(IMF_ALL).

# Build the model_data['model']
models = ['IMF_1', 'IMF_2', 'IMF_3', 'IMF_4', 'IMF_5', 'IMF_6', 'IMF_All']
rows = []
for model in models:
    for subject in Native_SUBJECTS:
        n_subj = int(subject[1:3])
        trf = eelbrain.load.unpickle(TRF_DIR / subject[:3] / f'{subject[:3]} {model}.pickle')
        trf.x = ['imf1', 'imf2', 'imf3', 'imf4', 'imf5', 'imf6', 'imfall'] #rename the model (no punctuation)
        #rows.append([n_subj, model, *trf.h_scaled])
        rows.append([n_subj, model, trf.proportion_explained])
model_data = eelbrain.Dataset.from_caselist(['subject', 'model', 'det'], rows)
#pprint(rows)

# For more interpretable numbers, express proportion explained in terms of the maximum explained variability of the most complete model
index = model_data['model'] == 'IMFAll'
model_data['det'] *= 100 / model_data[index, 'det'].mean('case').max('sensor')

# %%
# Load the TRFs:
# Keep `h_scaled` instead of `h` so that we can compare and add TRFs to different predictors
# Because each predictor gets normalized for estimation, the scale of the TRFs in `h` are all different
# The `h_scaled` attribute reverses that normalization, so that the TRFs are all in a common scale
n_rows = []
for model in models:
    for subject in Native_SUBJECTS:
        n_subj = int(subject[1:3])
        trf = eelbrain.load.unpickle(TRF_DIR / subject[:3] / f'{subject[:3]} IMF_ALL.pickle')
        trf.x = ['imf1', 'imf2', 'imf3', 'imf4', 'imf5', 'imf6'] #, 'imfall'] #rename the model (no punctuation)
        n_rows.append([n_subj, model, *trf.h_scaled])
        #rows.append([n_subj, model, trf.proportion_explained])
trfs = eelbrain.Dataset.from_caselist(['subject', 'model'], rows) #, *trf.x


"""
# redo the t-test (use one-sample to see effects from Ngram & CFG, because it is m1/m2 - m >>)
IMF_1_Onesamtest = eelbrain.testnd.TTestOneSample('IMF1', match='subject', ds=trfs, tail=1, tstart=0, pmin=0.05)
IMF_2_Onesamtest = eelbrain.testnd.TTestOneSample('IMF2', match='subject', ds=trfs, tail=1, tstart=0, pmin=0.05)
IMF_3_Onesamtest = eelbrain.testnd.TTestOneSample('IMF3', match='subject', ds=trfs, tail=1, tstart=0, pmin=0.05)
IMF_4_Onesamtest = eelbrain.testnd.TTestOneSample('IMF4', match='subject', ds=trfs, tail=1, tstart=0, pmin=0.05)
IMF_5_Onesamtest = eelbrain.testnd.TTestOneSample('IMF5', match='subject', ds=trfs, tail=1, tstart=0, pmin=0.05)
IMF_6_Onesamtest = eelbrain.testnd.TTestOneSample('IMF6', match='subject', ds=trfs, tail=1, tstart=0, pmin=0.05)

IMF_all_pairedttest = eelbrain.testnd.TTestRelated('IMF1', 'IMF2', 'IMF3', 'IMF4', 'IMF5', 'IMF6', ds=trfs, tail=1, tstart=0, pmin=0.05)  #, match='subject'
# Tail >> set 0(two-tailed) or 1 (upper_one-tailed)?  ; Why we close the "subject", then it's ok >> match = None??

# Find the sig clusters
IMF_1_Onesamtest_clus =IMF_1_Onesamtest.find_clusters(0.05)
IMF_2_Onesamtest_clus =IMF_2_Onesamtest.find_clusters(0.05)
IMF_3_Onesamtest_clus =IMF_3_Onesamtest.find_clusters(0.05)
IMF_4_Onesamtest_clus =IMF_4_Onesamtest.find_clusters(0.05)
IMF_5_Onesamtest_clus =IMF_5_Onesamtest.find_clusters(0.05)
IMF_6_Onesamtest_clus =IMF_6_Onesamtest.find_clusters(0.05)

IMF_all_pairedttest_clus =IMF_all_pairedttest.find_clusters(0.05)

# Print out the Stats and its clusters
print(IMF_1_Onesamtest)
print(IMF_1_Onesamtest_clus)
print(IMF_2_Onesamtest)
print(IMF_2_Onesamtest_clus)
print(IMF_3_Onesamtest)
print(IMF_3_Onesamtest_clus)
print(IMF_4_Onesamtest)
print(IMF_4_Onesamtest_clus)
print(IMF_5_Onesamtest)
print(IMF_5_Onesamtest_clus)
print(IMF_6_Onesamtest)
print(IMF_6_Onesamtest_clus)

print(IMF_all_pairedttest)
print(IMF_all_pairedttest_clus)



# Plot the topoarray of model
print("IMF_1")
p24_IMF_1 = eelbrain.plot.TopoArray(IMF_1_Onesamtest, t=[0.21], clip='circle') 
p24_IMF_1.plot_colorbar(width=0.1)
print("IMF_2")
p25_IMF_2 = eelbrain.plot.TopoArray(IMF_2_Onesamtest, t=[0.21], clip='circle') 
p25_IMF_2.plot_colorbar(width=0.1)
print("IMF_3")
p26_IMF_3 = eelbrain.plot.TopoArray(IMF_3_Onesamtest, t=[0.21], clip='circle') 
p26_IMF_3.plot_colorbar(width=0.1)
print("IMF_4")
p27_IMF_4 = eelbrain.plot.TopoArray(IMF_4_Onesamtest, t=[0.21], clip='circle') 
p27_IMF_4.plot_colorbar(width=0.1)
print("IMF_5")
p28_IMF_5 = eelbrain.plot.TopoArray(IMF_5_Onesamtest, t=[0.21], clip='circle') 
p28_IMF_5.plot_colorbar(width=0.1)
print("IMF_6")
p29_IMF_6 = eelbrain.plot.TopoArray(IMF_6_Onesamtest, t=[0.21], clip='circle') 
p29_IMF_6.plot_colorbar(width=0.1)


p30_ALL = eelbrain.plot.TopoArray(IMF_all_pairedttest, t=[0.21], clip='circle') 
p30_ALL.plot_colorbar(width=0.1)
"""
"""
p21_Ngram.save(DST / 'Natives_Ngram_TRF.png')
p22_CFG.save(DST / 'Natives_CFG_TRF.png')
p23_ALL.save(DST / 'Natives_NgramCFG_TRF.png')
"""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [19], line 13
#      11         n_rows.append([n_subj, model, *trf.h_scaled])
#      12         #rows.append([n_subj, model, trf.proportion_explained])
# ---> 13 trfs = eelbrain.Dataset.from_caselist(['subject', 'model'], rows) #, *trf.x
#      16 """
#      17 # redo the t-test (use one-sample to see effects from Ngram & CFG, because it is m1/m2 - m >>)
#      18 IMF_1_Onesamtest = eelbrain.testnd.TTestOneSample('IMF1', match='subject', ds=trfs, tail=1, tstart=0, pmin=0.05)
#    (...)
#      79 p30_ALL.plot_colorbar(width=0.1)
#      80 """
#      81 """
#      82 p21_Ngram.save(DST / 'Natives_Ngram_TRF.png')
#      83 p22_CFG.save(DST / 'Natives_CFG_TRF.png')
#      84 p23_ALL.save(DST / 'Natives_NgramCFG_TRF.png')
#      85 """
#
# File /Applications/anaconda3/envs/eelbrain_0_36/lib/python3.10/site-packages/eelbrain/_data_obj.py:6350, in Dataset.from_caselist(cls, names, cases, name, caption, info, random, check_dims, dim_intersection, to_list)
#    6348 n_cases = n_cases.pop()
#    6349 if len(names) != n_cases:
# -> 6350     raise ValueError(f'{names=}: {len(names)} names but {n_cases} cases')
#    6351 items = {key: combine([case[i] for case in cases], check_dims=check_dims, dim_intersection=dim_intersection, to_list=to_list) for i, key in enumerate(names)}
#    6352 for key in random:
#
# ValueError: names=['subject', 'model']: 2 names but 3 cases
