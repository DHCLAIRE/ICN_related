# %%
# %matplotlib
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
#from PyEMD import EMD
from scipy.signal import hilbert, medfilt

from pathlib import Path
import re
from pprint import pprint

import numpy as np
from scipy import signal, ndimage
import matplotlib.pyplot as plt
from matplotlib import pyplot
import pandas as pd

import emd
import eelbrain
import mne
# Out:
# /Users/neuroling/anaconda3/envs/eelbrain/lib/python3.11/site-packages/eelbrain/mne_fixes/_interpolation.py:13: FutureWarning: mne.io.pick.pick_types is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
#   from mne.io.pick import pick_types, pick_channels
# /Users/neuroling/anaconda3/envs/eelbrain/lib/python3.11/site-packages/eelbrain/mne_fixes/_interpolation.py:13: FutureWarning: mne.io.pick.pick_channels is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
#   from mne.io.pick import pick_types, pick_channels

# %%
### (OLD FUNCTION)
# ==========================================
# 2. HELPER FUNCTIONS
# ==========================================
def get_inst_freq_amp(signal, fs):
    """
    Calculates instantaneous amplitude (envelope) and frequency 
    using the Hilbert Transform.
    """
    analytic_signal = hilbert(signal)
    amplitude = np.abs(analytic_signal)
    instantaneous_phase = np.unwrap(np.angle(analytic_signal))
    
    # Calculate Instantaneous Frequency (derivative of phase)
    # factor of 1/(2*pi) converts rad/s to Hz
    inst_freq = np.diff(instantaneous_phase) / (2.0 * np.pi) * fs
    
    # Append last sample to match array length
    inst_freq = np.append(inst_freq, inst_freq[-1])
    
    return amplitude, inst_freq

def load_trf_data(filename):
    """
    Loads TRF data from pickle. Handles simplified data structures.
    """
    with open(filename, 'rb') as f:
        data = pickle.load(f)
    
    # LOGIC to handle different pickle structures:
    if isinstance(data, np.ndarray):
        trf = data
    elif isinstance(data, dict):
        # Checks for common keys, user might need to adjust this
        keys = [k for k in data.keys() if 'trf' in k.lower() or 'data' in k.lower()]
        if keys:
            trf = data[keys[0]]
            print(f"Loaded key '{keys[0]}' from dictionary.")
        else:
            raise ValueError(f"Could not find data in dictionary keys: {data.keys()}")
    else:
        raise ValueError("Pickle file must contain a numpy array or a dictionary.")

    # Ensure 1D array (if 2D, takes the first channel/dimension)
    if trf.ndim > 1:
        print(f"Data shape is {trf.shape}. Taking the first channel/vector.")
        trf = trf.flatten() if trf.shape[0] == 1 or trf.shape[1] == 1 else trf[0,:]
        
    return trf

# ==========================================
# 3. HHSA MAIN ALGORITHM
# ==========================================
def run_hhsa(signal, fs):
    """
    Performs Two-Layer EMD (Holo-Hilbert Spectral Analysis).
    """
    emd = EMD()
    emd.emd(signal)
    imfs_layer1 = emd.get_imfs_and_residue()[0]
    
    holo_points = [] # To store (Carrier_Freq, AM_Freq, Power) triplets

    print(f"Layer 1 Decomposition: Found {imfs_layer1.shape[0]} Carrier IMFs.")
    
    # --- LAYER 1 LOOP (Carrier Frequencies) ---
    for i, imf_c in enumerate(imfs_layer1):
        # 1. Get Carrier Envelope and Frequency
        env_c, freq_c = get_inst_freq_amp(imf_c, fs)
        
        # Filter negative/noise frequencies
        valid_mask_c = (freq_c > 0) & (freq_c < fs/2)
        
        # --- LAYER 2 LOOP (Amplitude Modulation) ---
        # Decompose the ENVELOPE of the carrier
        if np.sum(np.abs(env_c)) < 1e-10: continue # Skip empty IMFs
        
        try:
            imfs_layer2 = emd(env_c)
        except:
            continue # Skip if EMD fails on noise
            
        for j, imf_am in enumerate(imfs_layer2):
            # 2. Get AM Frequency
            _, freq_am = get_inst_freq_amp(imf_am, fs)
            
            # 3. Calculate Power (Instantaneous Energy)
            # Power is the square of the AM component amplitude
            power_am = imf_am**2
            
            # 4. Collect Triplet Points [fc, fam, power]
            # We iterate through time points to map instantaneous relationships
            mask_am = (freq_am > 0) & (freq_am < fs/2)
            combined_mask = valid_mask_c & mask_am
            
            # Add valid points to list
            # We downsample slightly if data is huge to save memory, or take all points
            idx = np.where(combined_mask)[0]
            
            if len(idx) > 0:
                # Stack: Col 0 = Carrier Freq, Col 1 = AM Freq, Col 2 = Power
                points = np.vstack((freq_c[idx], freq_am[idx], power_am[idx])).T
                holo_points.append(points)

    if not holo_points:
        return None

    # Concatenate all points from all modes
    return np.vstack(holo_points)

# %%
if __name__ == "__main__":

    ## ESLs ##
    #STIMULI = [str(i) for i in range(1, 13)]
    #DATA_ROOT = Path("/Volumes/Neurolang_1/Master Program/New_Thesis_topic/Experiments_Results")  #Path("~").expanduser() / 'Data' / 'Alice'
    DATA_ROOT = Path("/Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results")
    #PREDICTOR_audio_DIR = DATA_ROOT / 'TRFs_pridictors/audio_predictors'
    #PREDICTOR_word_DIR = DATA_ROOT / 'TRFs_pridictors/word_predictors'
    EEG_DIR = DATA_ROOT / 'EEG_ESLs' / 'Alice_ESL_ICAed_fif'
    IMF_DIR = DATA_ROOT/ "TRFs_pridictors/IF_predictors"
    F0_DIR = DATA_ROOT/ "TRFs_pridictors/F0_predictors"
    IMFsLIST = [path.name for path in IMF_DIR.iterdir() if re.match(r'Alice_IF_IMF_*', path.name)] 
    ESL_SUBJECTS = [path.name for path in EEG_DIR.iterdir() if re.match(r'n_2_S\d*', path.name)]  #S01_alice-raw.fif
    
    # Define a target directory for TRF estimates and make sure the directory is created
    TRF_DIR = DATA_ROOT / 'TRFs_ESLs'
    TRF_DIR.mkdir(exist_ok=True)
    print(ESL_SUBJECTS)
    print(len(ESL_SUBJECTS))  # 26
    DST = TRF_DIR / 'ESLs_figures'
    DST.mkdir(exist_ok=True)
# Out:
# ['n_2_S030_ICAed_raw.fif', 'n_2_S027_ICAed_raw.fif', 'n_2_S023_ICAed_raw.fif', 'n_2_S034_ICAed_raw.fif', 'n_2_S024_ICAed_raw.fif', 'n_2_S019_ICAed_raw.fif', 'n_2_S020_ICAed_raw.fif', 'n_2_S013_ICAed_raw.fif', 'n_2_S017_ICAed_raw.fif', 'n_2_S039_ICAed_raw.fif', 'n_2_S010_ICAed_raw.fif', 'n_2_S029_ICAed_raw.fif', 'n_2_S015_ICAed_raw.fif', 'n_2_S028_ICAed_raw.fif', 'n_2_S011_ICAed_raw.fif', 'n_2_S038_ICAed_raw.fif', 'n_2_S016_ICAed_raw.fif', 'n_2_S012_ICAed_raw.fif', 'n_2_S021_ICAed_raw.fif', 'n_2_S036_ICAed_raw.fif', 'n_2_S032_ICAed_raw.fif', 'n_2_S025_ICAed_raw.fif', 'n_2_S035_ICAed_raw.fif', 'n_2_S022_ICAed_raw.fif', 'n_2_S026_ICAed_raw.fif', 'n_2_S031_ICAed_raw.fif']
# 26

# %%
# Load in the TRF .pickle file (I choose F0 & En & EnOnset)

# Compare the TRFs corresponding to F0 and Envelopes.
# Build the model_data['model']
models = ['Fzero', 'Fzero+envelope', 'Fzero+envelope+env_onset'] # Change the description
rows = []
for model in models:
    print(model)
    for subject in ESL_SUBJECTS:
        trf = eelbrain.load.unpickle(TRF_DIR / subject[4:8] / f'{subject[4:8]} {model}.pickle')
        #print(trf)
        trf.x = ['f0', 'f0env', 'f0envenvon'] #rename the model (no punctuation)
        rows.append([subject, model, *trf.h_scaled])
        #rows.append([subject, model, *trf.h])
        #rows.append([subject, model, trf.proportion_explained])
model_data = eelbrain.Dataset.from_caselist(['subject', 'model', *trf.x], rows)
#model_data = eelbrain.Dataset.from_caselist(['subject', 'model', 'det'], rows)
#pprint(rows)
print(model_data)
# Out:
# Fzero
# Fzero+envelope
# Fzero+envelope+env_onset
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/dt/yj00f34n5x52_p314tnwfjkw0000gn/T/ipykernel_17706/3838627270.py in ?()
#      12         trf.x = ['f0', 'f0env', 'f0envenvon'] #rename the model (no punctuation)
#      13         rows.append([subject, model, *trf.h_scaled])
#      14         #rows.append([subject, model, *trf.h])
#      15         #rows.append([subject, model, trf.proportion_explained])
# ---> 16 model_data = eelbrain.Dataset.from_caselist(['subject', 'model', *trf.x], rows)
#      17 #model_data = eelbrain.Dataset.from_caselist(['subject', 'model', 'det'], rows)
#      18 #pprint(rows)
#      19 print(model_data)
#
# ~/anaconda3/envs/eelbrain/lib/python3.11/site-packages/eelbrain/_data_obj.py in ?(cls, names, cases, name, caption, info, random, check_dims, dim_intersection, to_list)
#    6368         elif random is None:
#    6369             random = []
#    6370         n_cases = set(map(len, cases))
#    6371         if len(n_cases) > 1:
# -> 6372             raise ValueError('not all cases have same length')
#    6373         n_cases = n_cases.pop()
#    6374         if len(names) != n_cases:
#    6375             raise ValueError(f'{names=}: {len(names)} names but {n_cases} cases')
#
# ValueError: not all cases have same length

# %%
"""
import numpy as np
import matplotlib.pyplot as plt
import eelbrain
from pathlib import Path
import re
from PyEMD import EMD
from scipy.signal import hilbert
"""

# Version 1 of HHSA & TRF

# ==========================================
# 1. HHSA CORE FUNCTIONS
# ==========================================
def get_inst_freq_amp(signal, fs):
    """
    Calculates instantaneous amplitude (envelope) and frequency
    using the Hilbert Transform.
    """
    analytic_signal = hilbert(signal)
    amplitude = np.abs(analytic_signal)
    instantaneous_phase = np.unwrap(np.angle(analytic_signal))
    
    # Instantaneous Frequency (derivative of phase)
    inst_freq = np.diff(instantaneous_phase) / (2.0 * np.pi) * fs
    # Pad to match length
    inst_freq = np.append(inst_freq, inst_freq[-1])
    
    return amplitude, inst_freq

def run_hhsa(signal, fs):
    """
    Performs Two-Layer EMD (Holo-Hilbert Spectral Analysis).
    """
    # Standardize signal shape to 1D array
    if signal.ndim > 1: signal = signal.flatten()
    
    emd = EMD()
    # Layer 1: Carrier Decomposition
    try:
        imfs_layer1 = emd(signal)
    except:
        return None # Skip if EMD fails (e.g. signal too short/flat)
        
    holo_points = []
    
    for imf_c in imfs_layer1:
        # Layer 1 Analysis
        env_c, freq_c = get_inst_freq_amp(imf_c, fs)
        
        # Skip empty/flat IMFs
        if np.sum(np.abs(env_c)) < 1e-10: continue

        # Layer 2: Amplitude Modulation Decomposition
        try:
            imfs_layer2 = emd(env_c)
        except:
            continue
            
        for imf_am in imfs_layer2:
            # Layer 2 Analysis
            _, freq_am = get_inst_freq_amp(imf_am, fs)
            power_am = imf_am**2 # Energy
            
            # Filter for valid positive frequencies
            mask = (freq_c > 0) & (freq_c < fs/2) & (freq_am > 0) & (freq_am < fs/2)
            idx = np.where(mask)[0]
            
            if len(idx) > 0:
                # Store [Carrier_Freq, AM_Freq, Power]
                points = np.vstack((freq_c[idx], freq_am[idx], power_am[idx])).T
                holo_points.append(points)
                
    if not holo_points: return None
    return np.vstack(holo_points)

# ==========================================
# 2. YOUR EXPERIMENT SETUP
# ==========================================

# -- Path Configuration --
DATA_ROOT = Path("/Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results")
EEG_DIR = DATA_ROOT / 'EEG_ESLs' / 'Alice_ESL_ICAed_fif'
TRF_DIR = DATA_ROOT / 'TRFs_ESLs'

# -- Subject List --
# Extracts subject IDs from filenames like 'n_2_S01...'
ESL_SUBJECTS = [path.name for path in EEG_DIR.iterdir() if re.match(r'n_2_S\d*', path.name)]
print(f"Found {len(ESL_SUBJECTS)} subjects.")

# -- Analysis Configuration --
TARGET_MODEL = 'Fzero+envelope'  # Which .pickle file to load
TARGET_PREDICTOR = 'envelope'    # Which part of the TRF to analyze ('envelope', 'f0', etc.)
LIMIT_CARRIER = 40 # Hz (Max X-axis frequency to plot)
LIMIT_AM = 20      # Hz (Max Y-axis frequency to plot)
NBINS = 100        # Resolution of the heatmap

# -- Group Accumulators --
group_spectrum_sum = None
n_subjects_processed = 0

# ==========================================
# 3. MAIN LOOP: LOAD -> HHSA -> ACCUMULATE
# ==========================================

print(f"Starting Group HHSA on Model: {TARGET_MODEL} | Predictor: {TARGET_PREDICTOR}")

for subject in ESL_SUBJECTS:
    subject_id_short = subject[4:8] # e.g., 'S01_'
    # Construct file path: TRF_DIR / S01_ / S01_ Fzero+envelope.pickle
    file_path = TRF_DIR / subject_id_short / f'{subject_id_short} {TARGET_MODEL}.pickle'
    
    if not file_path.exists():
        print(f"  [Skipped] File not found: {file_path}")
        continue

    try:
        # A. LOAD EELBRAIN OBJECT
        trf_obj = eelbrain.load.unpickle(file_path)
        
        # B. EXTRACT TRF VECTOR
        # 1. Determine which variable holds the data (.h or .h_scaled)
        if hasattr(trf_obj, 'h_scaled'):
            data_ndvar = trf_obj.h_scaled
        else:
            data_ndvar = trf_obj.h
            
        # 2. Select Predictor and Average Sensors
        #    Check if predictor exists in this model
        if TARGET_PREDICTOR in data_ndvar.xnames:
            # Extract just the target predictor and average over sensors
            trf_ndvar = data_ndvar.sub(name=TARGET_PREDICTOR).mean('sensor')
        else:
            print(f"  [Skipped] Predictor '{TARGET_PREDICTOR}' not found in {subject}")
            continue

        # 3. Get Raw Vector and Sampling Rate
        trf_vector = trf_ndvar.x
        fs = 1.0 / trf_ndvar.time.tstep
        
        # C. RUN HHSA
        # print(f"  Processing {subject_id_short}...")
        holo_data = run_hhsa(trf_vector, fs)
        
        if holo_data is None: 
            print(f"  [Warning] No valid HHSA modes for {subject_id_short}")
            continue

        # D. BIN INTO HEATMAP (for Group Average)
        fc = holo_data[:, 0]
        fam = holo_data[:, 1]
        power = holo_data[:, 2]
        
        # Create 2D Histogram for this subject
        H_subj, xedges, yedges = np.histogram2d(fc, fam, bins=NBINS, weights=power,
                                           range=[[0, LIMIT_CARRIER], [0, LIMIT_AM]])
        
        # Add to Group Sum
        if group_spectrum_sum is None:
            group_spectrum_sum = H_subj
        else:
            group_spectrum_sum += H_subj
            
        n_subjects_processed += 1
        
    except Exception as e:
        print(f"  [Error] Failed on {subject}: {e}")
        continue

# ==========================================
# 4. PLOT GRAND AVERAGE
# ==========================================
if n_subjects_processed > 0:
    # Compute Mean
    group_avg_spectrum = group_spectrum_sum / n_subjects_processed
    
    # Plot
    plt.figure(figsize=(10, 8))
    # Note: .T (transpose) is usually needed because histogram2d returns x,y but imshow expects row,col
    plt.imshow(group_avg_spectrum.T, origin='lower', cmap='jet', aspect='auto',
               extent=[0, LIMIT_CARRIER, 0, LIMIT_AM], interpolation='gaussian')
    
    plt.colorbar(label='Modulation Power (a.u.)')
    plt.xlabel('Carrier Frequency (Hz)')
    plt.ylabel('AM Frequency (Hz)')
    plt.title(f'Group HHSA: {TARGET_MODEL} [{TARGET_PREDICTOR}] (N={n_subjects_processed})')
    
    # Add diagonal line (where AM freq == Carrier freq)
    plt.plot([0, LIMIT_AM], [0, LIMIT_AM], 'w--', alpha=0.5)
    
    plt.show()
    print("Group Analysis Complete.")
else:
    print("No subjects were successfully processed.")
# Out:
# Found 26 subjects.
# Starting Group HHSA on Model: Fzero+envelope | Predictor: envelope
#   [Error] Failed on n_2_S030_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S027_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S023_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S034_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S024_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S019_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S020_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S013_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S017_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S039_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S010_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S029_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S015_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S028_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S011_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S038_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S016_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S012_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S021_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S036_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S032_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S025_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S035_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S022_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S026_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
#   [Error] Failed on n_2_S031_ICAed_raw.fif: 'tuple' object has no attribute 'xnames'
# No subjects were successfully processed.

# %%
"""
import numpy as np
import matplotlib.pyplot as plt
import eelbrain
from pathlib import Path
import re
from PyEMD import EMD
from scipy.signal import hilbert
"""
# Version 2 of HHSA & TRF

# ==========================================
# 1. HHSA CORE FUNCTIONS (Keep this part)
# ==========================================
def get_inst_freq_amp(signal, fs):
    analytic_signal = hilbert(signal)
    amplitude = np.abs(analytic_signal)
    instantaneous_phase = np.unwrap(np.angle(analytic_signal))
    inst_freq = np.diff(instantaneous_phase) / (2.0 * np.pi) * fs
    inst_freq = np.append(inst_freq, inst_freq[-1])
    return amplitude, inst_freq

def run_hhsa(signal, fs):
    if signal.ndim > 1: signal = signal.flatten()
    emd = EMD()
    try:
        imfs_layer1 = emd(signal)
    except:
        return None
        
    holo_points = []
    for imf_c in imfs_layer1:
        env_c, freq_c = get_inst_freq_amp(imf_c, fs)
        if np.sum(np.abs(env_c)) < 1e-10: continue
        try:
            imfs_layer2 = emd(env_c)
        except:
            continue  
        for imf_am in imfs_layer2:
            _, freq_am = get_inst_freq_amp(imf_am, fs)
            power_am = imf_am**2
            mask = (freq_c > 0) & (freq_c < fs/2) & (freq_am > 0) & (freq_am < fs/2)
            idx = np.where(mask)[0]
            if len(idx) > 0:
                points = np.vstack((freq_c[idx], freq_am[idx], power_am[idx])).T
                holo_points.append(points)
    if not holo_points: return None
    return np.vstack(holo_points)

# ==========================================
# 2. YOUR EXPERIMENT SETUP
# ==========================================
DATA_ROOT = Path("/Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results")
EEG_DIR = DATA_ROOT / 'EEG_ESLs' / 'Alice_ESL_ICAed_fif'
TRF_DIR = DATA_ROOT / 'TRFs_ESLs'

# Extract subject IDs
ESL_SUBJECTS = [path.name for path in EEG_DIR.iterdir() if re.match(r'n_2_S\d*', path.name)]
print(f"Found {len(ESL_SUBJECTS)} subjects.")
print(ESL_SUBJECTS)

# Settings
TARGET_MODEL = 'envelope' #'Fzero+envelope'
TARGET_PREDICTOR = 'envelope'
LIMIT_CARRIER = 30 
LIMIT_AM = 15      
NBINS = 100        

group_spectrum_sum = None
n_subjects_processed = 0

# ==========================================
# 3. MAIN LOOP (With FIX for Tuple Error)
# ==========================================
print(f"Starting Group HHSA on Model: {TARGET_MODEL} | Predictor: {TARGET_PREDICTOR}")

for subject in ESL_SUBJECTS:
    subject_id_short = subject[4:8] # Extract 'S030' from filename
    file_path = TRF_DIR / subject_id_short / f'{subject_id_short} {TARGET_MODEL}.pickle'
    
    if not file_path.exists():
        print(f"  [Skipped] File not found: {file_path}")
        continue

    try:
        trf_obj = eelbrain.load.unpickle(file_path)
        
        # 1. Get the Data Object (Check h_scaled vs h)
        if hasattr(trf_obj, 'h_scaled'):
            data_ndvar = trf_obj.h_scaled
        else:
            data_ndvar = trf_obj.h

        # --- FIX STARTS HERE ---
        # If the result is a tuple (e.g. multiple partitions), take the first one.
        if isinstance(data_ndvar, tuple):
            # print(f"  [Info] Unpacking tuple for {subject_id_short}...")
            data_ndvar = data_ndvar[0]
        # --- FIX ENDS HERE ---

        # 2. Select Predictor and Average Sensors
        if hasattr(data_ndvar, 'xnames'):
            if TARGET_PREDICTOR in data_ndvar.xnames:
                # Extract predictor and average across sensors
                trf_ndvar = data_ndvar.sub(name=TARGET_PREDICTOR).mean('sensor')
            else:
                print(f"  [Skipped] '{TARGET_PREDICTOR}' not in {data_ndvar.xnames}")
                continue
        else:
            print(f"  [Error] Object is still not an NDVar: {type(data_ndvar)}")
            continue

        # 3. Get Vector and Fs
        trf_vector = trf_ndvar.x
        fs = 1.0 / trf_ndvar.time.tstep
        
        # 4. Run HHSA
        holo_data = run_hhsa(trf_vector, fs)
        
        if holo_data is None: 
            # print(f"  [Warning] No valid HHSA modes for {subject_id_short}")
            continue

        # 5. Bin Data
        fc = holo_data[:, 0]
        fam = holo_data[:, 1]
        power = holo_data[:, 2]
        H_subj, xedges, yedges = np.histogram2d(fc, fam, bins=NBINS, weights=power,
                                           range=[[0, LIMIT_CARRIER], [0, LIMIT_AM]])
        
        if group_spectrum_sum is None:
            group_spectrum_sum = H_subj
        else:
            group_spectrum_sum += H_subj
            
        n_subjects_processed += 1
        
    except Exception as e:
        print(f"  [Error] Failed on {subject}: {e}")
        continue

# ==========================================
# 4. PLOT GRAND AVERAGE
# ==========================================
if n_subjects_processed > 0:
    group_avg_spectrum = group_spectrum_sum / n_subjects_processed
    
    plt.figure(figsize=(10, 8))
    plt.imshow(group_avg_spectrum.T, origin='lower', cmap='jet', aspect='auto',
               extent=[0, LIMIT_CARRIER, 0, LIMIT_AM], interpolation='gaussian')
    plt.colorbar(label='Modulation Power (a.u.)')
    plt.xlabel('Carrier Frequency (Hz)')
    plt.ylabel('AM Frequency (Hz)')
    plt.title(f'Group HHSA: {TARGET_MODEL} [{TARGET_PREDICTOR}] (N={n_subjects_processed})')
    plt.plot([0, LIMIT_AM], [0, LIMIT_AM], 'w--', alpha=0.5)
    plt.show()
    print("Group Analysis Complete.")
else:
    print("No subjects were successfully processed.")
# Out:
# Found 26 subjects.
# ['n_2_S030_ICAed_raw.fif', 'n_2_S027_ICAed_raw.fif', 'n_2_S023_ICAed_raw.fif', 'n_2_S034_ICAed_raw.fif', 'n_2_S024_ICAed_raw.fif', 'n_2_S019_ICAed_raw.fif', 'n_2_S020_ICAed_raw.fif', 'n_2_S013_ICAed_raw.fif', 'n_2_S017_ICAed_raw.fif', 'n_2_S039_ICAed_raw.fif', 'n_2_S010_ICAed_raw.fif', 'n_2_S029_ICAed_raw.fif', 'n_2_S015_ICAed_raw.fif', 'n_2_S028_ICAed_raw.fif', 'n_2_S011_ICAed_raw.fif', 'n_2_S038_ICAed_raw.fif', 'n_2_S016_ICAed_raw.fif', 'n_2_S012_ICAed_raw.fif', 'n_2_S021_ICAed_raw.fif', 'n_2_S036_ICAed_raw.fif', 'n_2_S032_ICAed_raw.fif', 'n_2_S025_ICAed_raw.fif', 'n_2_S035_ICAed_raw.fif', 'n_2_S022_ICAed_raw.fif', 'n_2_S026_ICAed_raw.fif', 'n_2_S031_ICAed_raw.fif']
# Starting Group HHSA on Model: envelope | Predictor: envelope
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
#   [Error] Object is still not an NDVar: <class 'eelbrain._data_obj.NDVar'>
# No subjects were successfully processed.

# %%
"""
import numpy as np
import matplotlib.pyplot as plt
import eelbrain
from pathlib import Path
import re
from PyEMD import EMD
from scipy.signal import hilbert
"""

# Version 3 of HHSA & TRF

# ==========================================
# 1. HHSA CORE FUNCTIONS (Unchanged)
# ==========================================
def get_inst_freq_amp(signal, fs):
    analytic_signal = hilbert(signal)
    amplitude = np.abs(analytic_signal)
    instantaneous_phase = np.unwrap(np.angle(analytic_signal))
    inst_freq = np.diff(instantaneous_phase) / (2.0 * np.pi) * fs
    inst_freq = np.append(inst_freq, inst_freq[-1])
    return amplitude, inst_freq

def run_hhsa(signal, fs):
    if signal.ndim > 1: signal = signal.flatten()
    emd = EMD()
    try:
        imfs_layer1 = emd(signal)
    except:
        return None
        
    holo_points = []
    for imf_c in imfs_layer1:
        env_c, freq_c = get_inst_freq_amp(imf_c, fs)
        if np.sum(np.abs(env_c)) < 1e-10: continue
        try:
            imfs_layer2 = emd(env_c)
        except:
            continue
        for imf_am in imfs_layer2:
            _, freq_am = get_inst_freq_amp(imf_am, fs)
            power_am = imf_am**2
            mask = (freq_c > 0) & (freq_c < fs/2) & (freq_am > 0) & (freq_am < fs/2)
            idx = np.where(mask)[0]
            if len(idx) > 0:
                points = np.vstack((freq_c[idx], freq_am[idx], power_am[idx])).T
                holo_points.append(points)
    if not holo_points: return None
    return np.vstack(holo_points)

# ==========================================
# 2. SETUP
# ==========================================
DATA_ROOT = Path("/Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results")
EEG_DIR = DATA_ROOT / 'EEG_ESLs' / 'Alice_ESL_ICAed_fif'
TRF_DIR = DATA_ROOT / 'TRFs_ESLs'

ESL_SUBJECTS = [path.name for path in EEG_DIR.iterdir() if re.match(r'n_2_S\d*', path.name)]
print(f"Found {len(ESL_SUBJECTS)} subjects.")

# Settings
TARGET_MODEL = 'envelope'#'Fzero+envelope'
TARGET_PREDICTOR = 'envelope'
LIMIT_CARRIER = 30 
LIMIT_AM = 15      
NBINS = 100        

group_spectrum_sum = None
n_subjects_processed = 0

# ==========================================
# 3. MAIN LOOP (Fixed Extraction Logic)
# ==========================================
print(f"Starting Group HHSA on Model: {TARGET_MODEL} | Predictor: {TARGET_PREDICTOR}")

for subject in ESL_SUBJECTS:
    subject_id_short = subject[4:8] # Extract 'S030'
    file_path = TRF_DIR / subject_id_short / f'{subject_id_short} {TARGET_MODEL}.pickle'
    
    if not file_path.exists():
        print(f"  [Skipped] File not found: {file_path}")
        continue

    try:
        trf_obj = eelbrain.load.unpickle(file_path)
        
        # 1. Get the NDVar
        if hasattr(trf_obj, 'h_scaled'):
            data_ndvar = trf_obj.h_scaled
        else:
            data_ndvar = trf_obj.h
            
        # Unpack tuple if necessary
        if isinstance(data_ndvar, tuple):
            data_ndvar = data_ndvar[0]
            
        # 2. Select Predictor and Average Sensors
        # FIX: Directly attempt to access the predictor instead of checking xnames
        try:
            # Try 1: Direct indexing (Standard for NDVar with categorical dimension)
            trf_predictor = data_ndvar[TARGET_PREDICTOR]
        except:
            try:
                # Try 2: Maybe it's called 'f0env' like in your previous code?
                # If TARGET_PREDICTOR fails, try a fallback or print available keys
                # print(f"  [Info] Keys found: {data_ndvar.keys()}")
                trf_predictor = data_ndvar['f0env'] # Fallback based on your snippet
            except:
                # print(f"  [Skipped] Could not find '{TARGET_PREDICTOR}' in {subject_id_short}")
                continue

        # Average across sensors (if sensor dimension exists)
        if 'sensor' in trf_predictor.dimnames:
            trf_final = trf_predictor.mean('sensor')
        else:
            trf_final = trf_predictor

        # 3. Get Data and Fs
        trf_vector = trf_final.x
        fs = 1.0 / trf_final.time.tstep
        
        # 4. Run HHSA
        holo_data = run_hhsa(trf_vector, fs)
        
        if holo_data is None: continue

        # 5. Bin Data
        fc = holo_data[:, 0]
        fam = holo_data[:, 1]
        power = holo_data[:, 2]
        H_subj, xedges, yedges = np.histogram2d(fc, fam, bins=NBINS, weights=power,
                                           range=[[0, LIMIT_CARRIER], [0, LIMIT_AM]])
        
        if group_spectrum_sum is None:
            group_spectrum_sum = H_subj
        else:
            group_spectrum_sum += H_subj
            
        n_subjects_processed += 1
        
    except Exception as e:
        print(f"  [Error] Failed on {subject}: {e}")
        continue

# ==========================================
# 4. PLOT GRAND AVERAGE
# ==========================================
if n_subjects_processed > 0:
    group_avg_spectrum = group_spectrum_sum / n_subjects_processed
    
    plt.figure(figsize=(10, 8))
    plt.imshow(group_avg_spectrum.T, origin='lower', cmap='jet', aspect='auto',
               extent=[0, LIMIT_CARRIER, 0, LIMIT_AM], interpolation='gaussian')
    plt.colorbar(label='Modulation Power (a.u.)')
    plt.xlabel('Carrier Frequency (Hz)')
    plt.ylabel('AM Frequency (Hz)')
    plt.title(f'Group HHSA: {TARGET_MODEL} [{TARGET_PREDICTOR}] (N={n_subjects_processed})')
    plt.plot([0, LIMIT_AM], [0, LIMIT_AM], 'w--', alpha=0.5)
    
    plt.show()
    print("Group Analysis Complete.")
else:
    print("No subjects were successfully processed.")
# Out:
# Found 26 subjects.
# Starting Group HHSA on Model: envelope | Predictor: envelope
# No subjects were successfully processed.

# %%
#import eelbrain
#from pathlib import Path

# --- CONFIGURATION ---
# Use the same paths as before
DATA_ROOT = Path("/Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results")
TRF_DIR = DATA_ROOT / 'TRFs_ESLs'
TARGET_MODEL = 'Fzero+envelope' 

# Pick one subject ID that you know exists (e.g., S01)
TEST_SUBJECT = 'S010'  
#Original path: /Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results/TRFs_ESLs/S010/S010 Fzero+envelope.pickle

print(f"--- DIAGNOSTIC FOR {TEST_SUBJECT} ---")
file_path = TRF_DIR / TEST_SUBJECT / f'{TEST_SUBJECT} {TARGET_MODEL}.pickle'

if file_path.exists():
    try:
        # 1. Load the object
        trf_obj = eelbrain.load.unpickle(file_path)
        print(f"1. Object Type: {type(trf_obj)}")
        
        # 2. Inspect attributes
        print(f"2. Attributes: {dir(trf_obj)}")
        
        # 3. Check for 'h' or 'h_scaled'
        if hasattr(trf_obj, 'h_scaled'):
            data = trf_obj.h_scaled
            print("3. Found 'h_scaled'")
        elif hasattr(trf_obj, 'h'):
            data = trf_obj.h
            print("3. Found 'h'")
        else:
            print("3. NO 'h' or 'h_scaled' found!")
            data = None
            
        # 4. If data exists, inspect dimensions
        if data is not None:
            # Handle tuple case
            if isinstance(data, tuple):
                print("   (Data is a tuple, taking first element)")
                data = data[0]
                
            print(f"4. Data Type: {type(data)}")
            
            if hasattr(data, 'dimnames'):
                print(f"5. Dimensions: {data.dimnames}")
            
            if hasattr(data, 'x'):
                print(f"6. Shape of .x: {data.x.shape}")
                
            # Check for categorical keys (Predictor names)
            # Try to print the keys of the first dimension
            try:
                first_dim = data.get_dim(data.dimnames[0])
                print(f"7. Keys in first dimension ('{data.dimnames[0]}'): {first_dim.values}")
            except:
                print("7. Could not read keys of first dimension.")

    except Exception as e:
        print(f"CRITICAL ERROR: {e}")
else:
    print(f"File not found: {file_path}")
# Out:
# --- DIAGNOSTIC FOR S010 ---
# /Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results/TRFs_ESLs/S010/S010 Fzero+envelope.pickle
# 1. Object Type: <class 'eelbrain._trf._boosting.BoostingResult'>
# 2. Attributes: ['__annotations__', '__class__', '__dataclass_fields__', '__dataclass_params__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__match_args__', '__module__', '__ne__', '__new__', '__post_init__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_apply_ndvar_transform', '_eelbrain_concatenate', '_h', '_isnan', '_morph', '_set_connectivity', '_set_parc', '_variability', '_x_mean_array', '_x_scale_array', '_y_dims', '_y_info', 'algorithm_version', 'basis', 'basis_window', 'cross_predict', 'delta', 'error', 'fit', 'h', 'h_scaled', 'h_source', 'h_time', 'i_test', 'mindelta', 'n_samples', 'partition_result_data', 'partition_results', 'partitions', 'prefit', 'proportion_explained', 'r', 'r_l1', 'r_rank', 'residual', 'scale_data', 'selective_stopping', 'splits', 't_run', 'tstart', 'tstop', 'version', 'x', 'x_mean', 'x_scale', 'y', 'y_mean', 'y_pred', 'y_scale']
# 3. Found 'h_scaled'
#    (Data is a tuple, taking first element)
# 4. Data Type: <class 'eelbrain._data_obj.NDVar'>
# 5. Dimensions: ('sensor', 'time')
# 6. Shape of .x: (57, 114)
# 7. Keys in first dimension ('sensor'): ['FP1', 'FPZ', 'FP2', 'AF3', 'AF4', 'F7', 'F5', 'F3', 'F1', 'FZ', 'F2', 'F4', 'F6', 'F8', 'FT7', 'FC5', 'FC3', 'FC1', 'FCZ', 'FC2', 'FC4', 'FC6', 'FT8', 'T7', 'C5', 'C3', 'C1', 'CZ', 'C2', 'C4', 'C6', 'T8', 'TP7', 'CP5', 'CP3', 'CP1', 'CPZ', 'CP2', 'CP4', 'CP6', 'TP8', 'P7', 'P5', 'P3', 'P1', 'PZ', 'P2', 'P4', 'P6', 'P8', 'PO7', 'PO5', 'PO3', 'POZ', 'PO4', 'PO6', 'PO8']

# %%
"""
import numpy as np
import matplotlib.pyplot as plt
import eelbrain
from pathlib import Path
import re
from PyEMD import EMD
from scipy.signal import hilbert
"""
# version 4 of HHSA & TRF

# ==========================================
# 1. HHSA CORE FUNCTIONS
# ==========================================
def get_inst_freq_amp(signal, fs):
    analytic_signal = hilbert(signal)
    amplitude = np.abs(analytic_signal)
    instantaneous_phase = np.unwrap(np.angle(analytic_signal))
    inst_freq = np.diff(instantaneous_phase) / (2.0 * np.pi) * fs
    inst_freq = np.append(inst_freq, inst_freq[-1])
    return amplitude, inst_freq

# Version 3 of the hhsa
#import numpy as np
#import emd # Ensure you have: pip install EMD-signal

def run_hhsa(signal, fs):
    # 1. Standardize input
    if signal.ndim > 1: signal = signal.flatten()
    
    n_samples = len(signal)
    
    # 2. Safety Check: If signal is extremely short, skip it
    if n_samples < 20: 
        return None

    # 3. MIRROR PADDING (The Fix)
    # We add 114 points to the left and 114 to the right. 
    # New length = 342, which is enough for EMD to run without crashing.
    pad_width = n_samples  
    padded_signal = np.pad(signal, pad_width, mode='reflect')
    
    # 4. Run Sift on PADDED signal
    # We lower max_imfs to 5, which is realistic for TRF data.
    try:
        imfs_layer1 = emd.sift.sift(padded_signal, max_imfs=5)
        # Transpose to shape (N_IMFs, N_Samples)
        imfs_layer1 = imfs_layer1.T 
    except Exception:
        return None

    holo_points = []
    
    # Layer 1 Loop (Carrier)
    for imf_c in imfs_layer1:
        # A. Un-pad: Extract the center part (the real data)
        imf_c_real = imf_c[pad_width : pad_width + n_samples]
        
        # B. Get Frequency & Envelope of the REAL section
        env_c, freq_c = get_inst_freq_amp(imf_c_real, fs)
        
        if np.sum(np.abs(env_c)) < 1e-10: continue

        # Layer 2 Loop (Amplitude Modulation)
        # We pad the ENVELOPE too, because it is also 114 points long
        padded_env = np.pad(env_c, pad_width, mode='reflect')
        
        try:
            imfs_layer2 = emd.sift.sift(padded_env, max_imfs=5)
            imfs_layer2 = imfs_layer2.T
        except:
            continue
            
        for imf_am in imfs_layer2:
            # Un-pad the AM result
            imf_am_real = imf_am[pad_width : pad_width + n_samples]
            
            _, freq_am = get_inst_freq_amp(imf_am_real, fs)
            power_am = imf_am_real**2
            
            # Filter valid frequencies
            mask = (freq_c > 0) & (freq_c < fs/2) & (freq_am > 0) & (freq_am < fs/2)
            idx = np.where(mask)[0]
            
            if len(idx) > 0:
                points = np.vstack((freq_c[idx], freq_am[idx], power_am[idx])).T
                holo_points.append(points)
                
    if not holo_points: return None
    return np.vstack(holo_points)

"""
# Version 2 of the hhsa
# --- UPDATE IMPORTS ---
#import emd  # The library you linked
# from PyEMD import EMD  <-- DELETE THIS LINE

def run_hhsa(signal, fs):
    # Ensure 1D array
    if signal.ndim > 1: signal = signal.flatten()
    
    # --- CHANGE 1: Use emd.sift.sift instead of EMD() ---
    try:
        # The 'max_imfs' argument is optional but helps speed up if data is noisy
        imfs_layer1 = emd.sift.sift(signal, max_imfs=10)
        
        # --- CHANGE 2: Transpose (.T) to match (N_IMFs, N_Samples) format ---
        imfs_layer1 = imfs_layer1.T
    except Exception as e:
        # print(f"Sifting failed: {e}")
        return None
        
    holo_points = []
    
    # Layer 1 (Carrier)
    for imf_c in imfs_layer1:
        env_c, freq_c = get_inst_freq_amp(imf_c, fs)
        if np.sum(np.abs(env_c)) < 1e-10: continue

        # Layer 2 (Amplitude Modulation)
        try:
            # Sift the envelope
            imfs_layer2 = emd.sift.sift(env_c, max_imfs=10)
            imfs_layer2 = imfs_layer2.T  # Transpose again
        except:
            continue
            
        for imf_am in imfs_layer2:
            _, freq_am = get_inst_freq_amp(imf_am, fs)
            power_am = imf_am**2
            
            # Filter valid frequencies
            mask = (freq_c > 0) & (freq_c < fs/2) & (freq_am > 0) & (freq_am < fs/2)
            idx = np.where(mask)[0]
            
            if len(idx) > 0:
                points = np.vstack((freq_c[idx], freq_am[idx], power_am[idx])).T
                holo_points.append(points)
                
    if not holo_points: return None
    return np.vstack(holo_points)
"""
    
"""
# The code if you are using PyEMD #
def run_hhsa(signal, fs):
    # Ensure 1D array
    if signal.ndim > 1: signal = signal.flatten()
    
    #emd = EMD()
    try:
        imfs_layer1 = emd(signal)
    except:
        return None
        
    holo_points = []
    
    # Layer 1 (Carrier)
    for imf_c in imfs_layer1:
        env_c, freq_c = get_inst_freq_amp(imf_c, fs)
        if np.sum(np.abs(env_c)) < 1e-10: continue

        # Layer 2 (Amplitude Modulation)
        try:
            imfs_layer2 = emd(env_c)
        except:
            continue
            
        for imf_am in imfs_layer2:
            _, freq_am = get_inst_freq_amp(imf_am, fs)
            power_am = imf_am**2
            
            # Filter valid frequencies
            mask = (freq_c > 0) & (freq_c < fs/2) & (freq_am > 0) & (freq_am < fs/2)
            idx = np.where(mask)[0]
            
            if len(idx) > 0:
                points = np.vstack((freq_c[idx], freq_am[idx], power_am[idx])).T
                holo_points.append(points)
                
    if not holo_points: return None
    return np.vstack(holo_points)
"""

# ==========================================
# 2. EXPERIMENT SETUP
# ==========================================
DATA_ROOT = Path("/Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results")
EEG_DIR = DATA_ROOT / 'EEG_ESLs' / 'Alice_ESL_ICAed_fif'
TRF_DIR = DATA_ROOT / 'TRFs_ESLs'

# Get Subject List
ESL_SUBJECTS = [path.name for path in EEG_DIR.iterdir() if re.match(r'n_2_S\d*', path.name)]
print(f"Found {len(ESL_SUBJECTS)} subjects.")

# Analysis Settings
TARGET_MODEL = 'Fzero' #+envelope+env_onset'
LIMIT_CARRIER = 10  # Hz
LIMIT_AM = 10       # Hz
NBINS = 100

group_spectrum_sum = None
n_subjects_processed = 0

# ==========================================
# 3. MAIN PROCESSING LOOP
# ==========================================
print(f"Starting Group HHSA on Model: {TARGET_MODEL}")

for subject in ESL_SUBJECTS:
    subject_id_short = subject[4:8] # e.g., 'S010'
    file_path = TRF_DIR / subject_id_short / f'{subject_id_short} {TARGET_MODEL}.pickle'
    
    if not file_path.exists():
        continue

    try:
        # A. LOAD DATA
        trf_obj = eelbrain.load.unpickle(file_path)
        
        # Get the NDVar (Handle 'h_scaled' or 'h')
        if hasattr(trf_obj, 'h_scaled'):
            data_ndvar = trf_obj.h_scaled
        else:
            data_ndvar = trf_obj.h

        # Handle Tuple (Partitioned results)
        if isinstance(data_ndvar, tuple):
            data_ndvar = data_ndvar[0]

        # B. SELECT PREDICTOR (F0 vs Envelope)
        # We need to find which dimension contains the predictors.
        # Usually dims are ('time',) or ('sensor', 'time') or ('predictor', 'sensor', 'time')
        
        trf_final = None
        
        # Strategy 1: Attempt to grab 'envelope' by name if possible
        try:
            # If the object works like a dict (Categorical Dimension)
            trf_final = data_ndvar['envelope']
        except:
            # Strategy 2: Grab by Index
            # If Strategy 1 fails, we assume the structure is [F0, Envelope]
            # so Envelope is at index 1.
            # We look for the dimension that is NOT 'time' and NOT 'sensor'
            dims = data_ndvar.dimnames
            non_time_dims = [d for d in dims if d != 'time' and d != 'sensor']
            
            if len(non_time_dims) > 0:
                predictor_dim_name = non_time_dims[0]
                # print(f"  [Info] Assuming predictors are in dim: {predictor_dim_name}")
                
                # Take the 2nd item (Index 1) which is usually Envelope in 'F0+envelope'
                # If you want F0, change 1 to 0.
                trf_final = data_ndvar.sub(**{predictor_dim_name: 1}) 
            else:
                # If no predictor dimension, maybe it's already just the envelope?
                trf_final = data_ndvar

        # C. AVERAGE SENSORS & EXTRACT VECTOR
        if 'sensor' in trf_final.dimnames:
            trf_final = trf_final.mean('sensor')
            
        trf_vector = trf_final.x
        fs = 1.0 / trf_final.time.tstep
        
        # D. RUN HHSA
        # print(f"  Processing {subject_id_short}...")
        holo_data = run_hhsa(trf_vector, fs)
        
        if holo_data is None: continue

        # E. BIN DATA (Create Image)
        fc = holo_data[:, 0]
        fam = holo_data[:, 1]
        power = holo_data[:, 2]
        
        H_subj, xedges, yedges = np.histogram2d(fc, fam, bins=NBINS, weights=power,
                                           range=[[0, LIMIT_CARRIER], [0, LIMIT_AM]])
        
        if group_spectrum_sum is None:
            group_spectrum_sum = H_subj
        else:
            group_spectrum_sum += H_subj
            
        n_subjects_processed += 1
        
    except Exception as e:
        print(f"  [Error] Failed on {subject_id_short}: {e}")
        continue

# ==========================================
# 4. PLOT
# ==========================================
if n_subjects_processed > 0:
    group_avg_spectrum = group_spectrum_sum / n_subjects_processed
    
    plt.figure(figsize=(10, 8))
    plt.imshow(group_avg_spectrum.T, origin='lower', cmap='jet', aspect='auto',
               extent=[0, LIMIT_CARRIER, 0, LIMIT_AM], interpolation='gaussian')
    plt.colorbar(label='Modulation Power')
    plt.xlabel('Carrier Frequency (Hz)')
    plt.ylabel('AM Frequency (Hz)')
    plt.title(f'Group HHSA: {TARGET_MODEL} (N={n_subjects_processed})')
    plt.plot([0, LIMIT_AM], [0, LIMIT_AM], 'w--', alpha=0.5)
    plt.show()
else:
    print("No subjects processed. Check paths and pickle content.")
# Out:
# Found 26 subjects.
# Starting Group HHSA on Model: Fzero

# %%
import numpy as np
import matplotlib.pyplot as plt
import eelbrain
from pathlib import Path
import re
import emd  # Ensure you ran: pip install EMD-signal
from scipy.signal import hilbert

# ==========================================
# 1. CORE ANALYSIS FUNCTIONS
# ==========================================
def get_inst_freq_amp(signal, fs):
    """
    Calculates instantaneous amplitude and frequency using Hilbert Transform.
    """
    analytic_signal = hilbert(signal)
    amplitude = np.abs(analytic_signal)
    instantaneous_phase = np.unwrap(np.angle(analytic_signal))
    
    # Derivative of phase for frequency
    inst_freq = np.diff(instantaneous_phase) / (2.0 * np.pi) * fs
    # Pad last point to match length
    inst_freq = np.append(inst_freq, inst_freq[-1])
    
    return amplitude, inst_freq

def run_hhsa(signal, fs):
    """
    Performs Two-Layer EMD with Mirror Padding for short signals.
    """
    if signal.ndim > 1: signal = signal.flatten()
    
    n_samples = len(signal)
    
    # Safety Check for empty/tiny signals
    if n_samples < 10: return None

    # --- A. MIRROR PADDING (Crucial for 114-point TRFs) ---
    # We reflect the signal to make it 3x longer so EMD works
    pad_width = n_samples
    padded_signal = np.pad(signal, pad_width, mode='reflect')
    
    # --- B. LAYER 1: CARRIER DECOMPOSITION ---
    try:
        # Use emd.sift.sift (Quinn library)
        # max_imfs=5 is enough for a simple TRF response
        imfs_layer1 = emd.sift.sift(padded_signal, max_imfs=5)
        imfs_layer1 = imfs_layer1.T  # Transpose to (N_IMFs, N_Time)
    except Exception:
        return None
        
    holo_points = []
    
    for imf_c in imfs_layer1:
        # Un-pad: Extract the middle 'real' part
        imf_c_real = imf_c[pad_width : pad_width + n_samples]
        
        # Get Carrier Frequency & Envelope
        env_c, freq_c = get_inst_freq_amp(imf_c_real, fs)
        
        # Skip flat/empty IMFs
        if np.sum(np.abs(env_c)) < 1e-10: continue

        # --- C. LAYER 2: AM DECOMPOSITION ---
        # Pad the envelope before sifting
        padded_env = np.pad(env_c, pad_width, mode='reflect')
        
        try:
            imfs_layer2 = emd.sift.sift(padded_env, max_imfs=5)
            imfs_layer2 = imfs_layer2.T
        except:
            continue
            
        for imf_am in imfs_layer2:
            # Un-pad AM result
            imf_am_real = imf_am[pad_width : pad_width + n_samples]
            
            _, freq_am = get_inst_freq_amp(imf_am_real, fs)
            power_am = imf_am_real**2
            
            # Filter for valid graph range
            mask = (freq_c > 0) & (freq_c < fs/2) & (freq_am > 0) & (freq_am < fs/2)
            idx = np.where(mask)[0]
            
            if len(idx) > 0:
                # Store [Carrier_Freq, AM_Freq, Power]
                points = np.vstack((freq_c[idx], freq_am[idx], power_am[idx])).T
                holo_points.append(points)
                
    if not holo_points: return None
    return np.vstack(holo_points)

# ==========================================
# 2. EXPERIMENT CONFIGURATION
# ==========================================
DATA_ROOT = Path("/Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results")
EEG_DIR = DATA_ROOT / 'EEG_ESLs' / 'Alice_ESL_ICAed_fif'
TRF_DIR = DATA_ROOT / 'TRFs_ESLs'

# Extract Subjects
ESL_SUBJECTS = [path.name for path in EEG_DIR.iterdir() if re.match(r'n_2_S\d*', path.name)]
print(f"Found {len(ESL_SUBJECTS)} subjects.")

# Settings
TARGET_MODEL = 'Fzero'
LIMIT_CARRIER = 5  # Hz
LIMIT_AM = 5       # Hz
NBINS = 50

group_spectrum_sum = None
n_subjects_processed = 0

# ==========================================
# 3. MAIN LOOP
# ==========================================
print(f"Starting Group HHSA on Model: {TARGET_MODEL}")

for subject in ESL_SUBJECTS:
    subject_id_short = subject[4:8] # 'S010'
    file_path = TRF_DIR / subject_id_short / f'{subject_id_short} {TARGET_MODEL}.pickle'
    
    if not file_path.exists():
        continue

    try:
        # --- LOAD DATA ---
        trf_obj = eelbrain.load.unpickle(file_path)
        
        # Handle h vs h_scaled
        if hasattr(trf_obj, 'h_scaled'):
            data_ndvar = trf_obj.h_scaled
        else:
            data_ndvar = trf_obj.h

        # Handle Tuple (Partitioned Data)
        if isinstance(data_ndvar, tuple):
            data_ndvar = data_ndvar[0]

        # --- EXTRACT PREDICTOR ---
        trf_final = None
        
        # Strategy 1: Try name 'envelope'
        try:
            trf_final = data_ndvar['Fzero']
        except:
            # Strategy 2: Try Index
            # If dims are [predictor, time], we grab the 2nd predictor (index 1)
            # Assuming the order is [F0, Envelope]
            dims = data_ndvar.dimnames
            non_time_dims = [d for d in dims if d != 'time' and d != 'sensor']
            
            if len(non_time_dims) > 0:
                dim_name = non_time_dims[0]
                # Index 1 = Envelope. Change to 0 if you want F0.
                trf_final = data_ndvar.sub(**{dim_name: 1}) 
            else:
                trf_final = data_ndvar

        # Average Sensors
        if 'sensor' in trf_final.dimnames:
            trf_final = trf_final.mean('sensor')
            
        trf_vector = trf_final.x
        fs = 1.0 / trf_final.time.tstep
        
        # --- RUN HHSA ---
        # print(f"  Processing {subject_id_short}...")
        holo_data = run_hhsa(trf_vector, fs)
        
        if holo_data is None: 
            continue
            
        # --- DEBUG PRINT ---
        # Print the average frequencies found for this subject
        avg_fc = np.mean(holo_data[:, 0])
        avg_fam = np.mean(holo_data[:, 1])
        print(f"  Subject {subject_id_short}: Avg Carrier={avg_fc:.2f}Hz, Avg AM={avg_fam:.2f}Hz")
        # -------------------
        

        # --- BIN RESULTS ---
        fc = holo_data[:, 0]
        fam = holo_data[:, 1]
        power = holo_data[:, 2]
        
        H_subj, xedges, yedges = np.histogram2d(fc, fam, bins=NBINS, weights=power,
                                           range=[[0, LIMIT_CARRIER], [0, LIMIT_AM]])
        
        if group_spectrum_sum is None:
            group_spectrum_sum = H_subj
        else:
            group_spectrum_sum += H_subj
            
        n_subjects_processed += 1
        
    except Exception as e:
        print(f"  [Error] Failed on {subject_id_short}: {e}")
        continue

# ==========================================
# 4. PLOT FINAL RESULT
# ==========================================
if n_subjects_processed > 0:
    group_avg_spectrum = group_spectrum_sum / n_subjects_processed
    
    plt.figure(figsize=(10, 8))
    # Note: .T is used because imshow expects [rows, cols] = [y, x]
    plt.imshow(group_avg_spectrum.T, origin='lower', cmap='jet', aspect='auto',
               extent=[0, LIMIT_CARRIER, 0, LIMIT_AM], interpolation='gaussian')
    
    plt.colorbar(label='Modulation Power (a.u.)')
    plt.xlabel('Carrier Frequency (Hz)')
    plt.ylabel('AM Frequency (Hz)')
    plt.title(f'Group HHSA (N={n_subjects_processed})\nModel: {TARGET_MODEL} | Predictor: Envelope')
    
    # Diagonal line (1:1 coupling)
    plt.plot([0, LIMIT_AM], [0, LIMIT_AM], 'w--', alpha=0.5)
    plt.savefig(TRF_DIR / 'ESLs_Fzero_HHSA_TRF.png')
    plt.show()
    print("Success!")
else:
    print("No subjects processed. Please check if pickle files contain the expected data structure.")
# Out:
# Found 26 subjects.
# Starting Group HHSA on Model: Fzero
#   Subject S030: Avg Carrier=5.32Hz, Avg AM=5.62Hz
#   Subject S027: Avg Carrier=7.06Hz, Avg AM=5.83Hz
#   Subject S023: Avg Carrier=4.93Hz, Avg AM=6.60Hz
#   Subject S034: Avg Carrier=6.12Hz, Avg AM=5.93Hz
#   Subject S024: Avg Carrier=4.92Hz, Avg AM=4.62Hz
#   Subject S019: Avg Carrier=6.43Hz, Avg AM=5.12Hz
#   Subject S020: Avg Carrier=7.16Hz, Avg AM=5.98Hz
#   Subject S013: Avg Carrier=7.53Hz, Avg AM=5.16Hz
#   Subject S017: Avg Carrier=5.61Hz, Avg AM=5.95Hz
#   Subject S039: Avg Carrier=6.54Hz, Avg AM=5.36Hz
#   Subject S010: Avg Carrier=5.75Hz, Avg AM=5.81Hz
#   Subject S029: Avg Carrier=6.45Hz, Avg AM=5.66Hz
#   Subject S015: Avg Carrier=4.94Hz, Avg AM=4.47Hz
#   Subject S028: Avg Carrier=6.06Hz, Avg AM=4.57Hz
#   Subject S011: Avg Carrier=5.29Hz, Avg AM=5.60Hz
#   Subject S038: Avg Carrier=4.55Hz, Avg AM=5.28Hz
#   Subject S016: Avg Carrier=7.36Hz, Avg AM=6.01Hz
#   Subject S012: Avg Carrier=7.14Hz, Avg AM=5.20Hz
#   Subject S021: Avg Carrier=7.64Hz, Avg AM=4.20Hz
#   Subject S036: Avg Carrier=6.28Hz, Avg AM=7.19Hz
#   Subject S032: Avg Carrier=5.89Hz, Avg AM=6.34Hz
#   Subject S025: Avg Carrier=6.82Hz, Avg AM=5.04Hz
#   Subject S035: Avg Carrier=6.25Hz, Avg AM=6.35Hz
#   Subject S022: Avg Carrier=5.07Hz, Avg AM=6.15Hz
#   Subject S026: Avg Carrier=4.17Hz, Avg AM=6.76Hz
#   Subject S031: Avg Carrier=7.14Hz, Avg AM=4.85Hz
# Success!

# %%
"""
import numpy as np
import matplotlib.pyplot as plt
import eelbrain
from pathlib import Path
import emd
from scipy.signal import hilbert
"""
# Version 1 of IMFs in each layers

# ==========================================
# 1. CONFIGURATION
# ==========================================
DATA_ROOT = Path("/Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results")
TRF_DIR = DATA_ROOT / 'TRFs_ESLs'
TARGET_MODEL = 'Fzero+envelope'
TARGET_SUBJECT = 'S010'  # <--- Change this to look at different subjects

# Which Layer 1 IMF do you want to decompose further?
# 0 = First IMF (Fastest/Highest Freq), 1 = Second IMF, etc.
TARGET_IMF_INDEX = 1 

# ==========================================
# 2. LOAD DATA (Robust Loading)
# ==========================================
file_path = TRF_DIR / TARGET_SUBJECT / f'{TARGET_SUBJECT} {TARGET_MODEL}.pickle'
print(f"Loading {TARGET_SUBJECT}...")

try:
    trf_obj = eelbrain.load.unpickle(file_path)
    
    # Handle h vs h_scaled
    if hasattr(trf_obj, 'h_scaled'):
        data_ndvar = trf_obj.h_scaled
    else:
        data_ndvar = trf_obj.h
        
    # Handle Tuple
    if isinstance(data_ndvar, tuple):
        data_ndvar = data_ndvar[0]

    # Extract Predictor (Strategy: Index)
    # Assumes order is [F0, Envelope] -> Index 1 is Envelope
    # If your model is just 'envelope', it might be Index 0.
    try:
        # Try finding 'envelope' by name
        trf_final = data_ndvar['envelope']
        pred_name = "Envelope"
    except:
        # Fallback to Index 1
        dims = data_ndvar.dimnames
        non_time_dims = [d for d in dims if d != 'time' and d != 'sensor']
        if len(non_time_dims) > 0:
            trf_final = data_ndvar.sub(**{non_time_dims[0]: 1})
            pred_name = "Predictor (Index 1)"
        else:
            trf_final = data_ndvar
            pred_name = "Predictor"

    # Average Sensors
    if 'sensor' in trf_final.dimnames:
        trf_final = trf_final.mean('sensor')
        
    signal = trf_final.x
    times = trf_final.time.times
    fs = 1.0 / trf_final.time.tstep

    if signal.ndim > 1: signal = signal.flatten()
    print(f"Data Loaded: {len(signal)} samples")

except Exception as e:
    print(f"Error loading: {e}")
    exit()

# ==========================================
# 3. PROCESSING (With Mirror Padding)
# ==========================================

# --- A. Layer 1 Decomposition ---
pad_width = len(signal)
padded_signal = np.pad(signal, pad_width, mode='reflect')

# Run EMD (Sift)
imfs_layer1_padded = emd.sift.sift(padded_signal, max_imfs=5)

# Un-pad Layer 1
# Note: emd output is (Samples, IMFs)
imfs_layer1 = imfs_layer1_padded[pad_width : pad_width + len(signal), :]
n_imfs1 = imfs_layer1.shape[1]

# --- B. Layer 2 Decomposition (Target IMF) ---
# Extract the target IMF (e.g., IMF 0)
target_imf_padded = imfs_layer1_padded[:, TARGET_IMF_INDEX]

# Get Envelope (using Hilbert)
analytic = hilbert(target_imf_padded)
envelope_padded = np.abs(analytic)

# Run EMD on Envelope
imfs_layer2_padded = emd.sift.sift(envelope_padded, max_imfs=4)

# Un-pad Layer 2
envelope_real = envelope_padded[pad_width : pad_width + len(signal)]
imfs_layer2 = imfs_layer2_padded[pad_width : pad_width + len(signal), :]
n_imfs2 = imfs_layer2.shape[1]

# ==========================================
# 4. PLOTTING
# ==========================================

# --- FIGURE 1: LAYER 1 (Carrier) ---
fig1, axes1 = plt.subplots(n_imfs1 + 1, 1, figsize=(10, 8), sharex=True)
fig1.suptitle(f"Layer 1: Carrier Decomposition ({TARGET_SUBJECT})", fontsize=14)

# Plot Original Signal
axes1[0].plot(times, signal, 'k', label='Original TRF')
axes1[0].set_title(f"Original Signal: {pred_name}")
axes1[0].legend(loc='upper right')

# Plot IMFs
for i in range(n_imfs1):
    ax = axes1[i + 1]
    ax.plot(times, imfs_layer1[:, i], 'b')
    ax.set_ylabel(f"IMF {i+1}")
    ax.grid(True, alpha=0.3)

axes1[-1].set_xlabel("Time (s)")
plt.tight_layout()
#plt.savefig(TRF_DIR / 'ESLs_S010_layer1-IMFs_HHSA_TRF.png')
plt.show()


# --- FIGURE 2: LAYER 2 (Amplitude Modulation) ---
fig2, axes2 = plt.subplots(n_imfs2 + 1, 1, figsize=(10, 8), sharex=True)
fig2.suptitle(f"Layer 2: AM Decomposition of Carrier IMF {TARGET_IMF_INDEX+1}", fontsize=14)

# Plot Envelope
axes2[0].plot(times, envelope_real, 'r', label=f'Envelope of IMF {TARGET_IMF_INDEX+1}')
axes2[0].set_title("Amplitude Envelope (Input to Layer 2)")
axes2[0].legend(loc='upper right')

# Plot AM IMFs
for i in range(n_imfs2):
    ax = axes2[i + 1]
    ax.plot(times, imfs_layer2[:, i], 'g')
    ax.set_ylabel(f"AM IMF {i+1}")
    ax.grid(True, alpha=0.3)

axes2[-1].set_xlabel("Time (s)")
plt.tight_layout()
plt.savefig(TRF_DIR / 'ESLs_S010_layer2-IMF2_HHSA_TRF.png')
plt.show()
# Out:
# Loading S010...
# Data Loaded: 114 samples

# %%
"""
import numpy as np
import matplotlib.pyplot as plt
import eelbrain
from pathlib import Path
import emd
from scipy.signal import hilbert
"""
# Version 2 of IMFs in each layer
# ==========================================
# 1. SETUP & CONFIGURATION
# ==========================================
DATA_ROOT = Path("/Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results")
TRF_DIR = DATA_ROOT / 'TRFs_ESLs'
TARGET_MODEL = 'Fzero+envelope'
TARGET_SUBJECT = 'S010'  # Change this to any subject ID you want to inspect

# ==========================================
# 2. LOAD DATA
# ==========================================
file_path = TRF_DIR / TARGET_SUBJECT / f'{TARGET_SUBJECT} {TARGET_MODEL}.pickle'
print(f"Loading {file_path}...")

try:
    trf_obj = eelbrain.load.unpickle(file_path)
    
    # Extract Data (Handle tuples and h_scaled)
    if hasattr(trf_obj, 'h_scaled'):
        data_ndvar = trf_obj.h_scaled
    else:
        data_ndvar = trf_obj.h
        
    if isinstance(data_ndvar, tuple):
        data_ndvar = data_ndvar[0]

    # Extract Predictor (Strategy: Index 1 for Envelope)
    # Assumes structure [F0, Envelope]
    dims = data_ndvar.dimnames
    non_time_dims = [d for d in dims if d != 'time' and d != 'sensor']
    
    if len(non_time_dims) > 0:
        dim_name = non_time_dims[0]
        # Index 1 = Envelope. Change to 0 if you want F0.
        trf_final = data_ndvar.sub(**{dim_name: 1}) 
        predictor_name = "Envelope"
    else:
        trf_final = data_ndvar
        predictor_name = "Single Predictor"

    # Average Sensors
    if 'sensor' in trf_final.dimnames:
        trf_final = trf_final.mean('sensor')
        
    signal = trf_final.x
    fs = 1.0 / trf_final.time.tstep
    time_axis = trf_final.time.times

    # Ensure 1D
    if signal.ndim > 1: signal = signal.flatten()

    print(f"Data Loaded: {len(signal)} samples, Fs={fs:.1f}Hz")

except Exception as e:
    print(f"Error loading data: {e}")
    exit()

# ==========================================
# 3. RUN EMD & PLOT
# ==========================================

# --- A. MIRROR PADDING (Crucial for TRF) ---
pad_width = len(signal)
padded_signal = np.pad(signal, pad_width, mode='reflect')

# --- B. LAYER 1: CARRIER DECOMPOSITION ---
# Run Sift
imfs_layer1 = emd.sift.sift(padded_signal, max_imfs=5)

# Un-pad results for plotting
imfs_layer1_real = imfs_layer1[pad_width : pad_width + len(signal), :]
n_imfs1 = imfs_layer1_real.shape[1]

# --- PLOT 1: CARRIER IMFs ---
plt.figure(figsize=(10, 8))
plt.subplot(n_imfs1 + 1, 1, 1)
plt.plot(time_axis, signal, 'k')
plt.title(f"Original TRF Signal ({predictor_name})")
plt.grid(True)

for i in range(n_imfs1):
    plt.subplot(n_imfs1 + 1, 1, i + 2)
    plt.plot(time_axis, imfs_layer1_real[:, i])
    plt.ylabel(f"IMF {i+1}")
    plt.grid(True)

plt.xlabel("Time (s)")
plt.suptitle(f"Layer 1: Carrier Decomposition ({TARGET_SUBJECT})")
plt.tight_layout()
plt.show()

# --- C. LAYER 2: AM DECOMPOSITION (Example on IMF 1) ---
# We usually analyze the envelope of the first or second IMF
target_imf_idx = 0 # Let's look at the first IMF's envelope
imf_c = imfs_layer1[:, target_imf_idx] # Use PADDED version for calc

# Get Envelope
analytic = hilbert(imf_c)
envelope = np.abs(analytic)

# Run Sift on Envelope
imfs_layer2 = emd.sift.sift(envelope, max_imfs=4)

# Un-pad results
envelope_real = envelope[pad_width : pad_width + len(signal)]
imfs_layer2_real = imfs_layer2[pad_width : pad_width + len(signal), :]
n_imfs2 = imfs_layer2_real.shape[1]

# --- PLOT 2: AM IMFs ---
plt.figure(figsize=(10, 8))
plt.subplot(n_imfs2 + 1, 1, 1)
plt.plot(time_axis, envelope_real, 'r')
plt.title(f"Amplitude Envelope of Carrier IMF {target_imf_idx+1}")
plt.grid(True)

for i in range(n_imfs2):
    plt.subplot(n_imfs2 + 1, 1, i + 2)
    plt.plot(time_axis, imfs_layer2_real[:, i], 'g')
    plt.ylabel(f"AM IMF {i+1}")
    plt.grid(True)

plt.xlabel("Time (s)")
plt.suptitle(f"Layer 2: AM Decomposition of IMF {target_imf_idx+1}")
plt.tight_layout()
plt.show()
# Out:
# Loading /Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results/TRFs_ESLs/S010/S010 Fzero+envelope.pickle...
# Data Loaded: 114 samples, Fs=100.0Hz

# %%
# Version 3 of subject's IMFs in each layers
import numpy as np
import matplotlib.pyplot as plt
import eelbrain
from pathlib import Path
import emd
from scipy.signal import hilbert

# ==========================================
# 1. SETUP
# ==========================================
DATA_ROOT = Path("/Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results")
TRF_DIR = DATA_ROOT / 'TRFs_ESLs'
TARGET_MODEL = 'Fzero+envelope'
SUBJECT_ID = 'S010'  # <--- We focus only on S010

# ==========================================
# 2. LOAD DATA (S010)
# ==========================================
file_path = TRF_DIR / SUBJECT_ID / f'{SUBJECT_ID} {TARGET_MODEL}.pickle'
print(f"Loading {SUBJECT_ID} from {file_path}...")

try:
    # Load Object
    trf_obj = eelbrain.load.unpickle(file_path)
    data_ndvar = trf_obj.h_scaled if hasattr(trf_obj, 'h_scaled') else trf_obj.h
    if isinstance(data_ndvar, tuple): data_ndvar = data_ndvar[0]

    # Extract Envelope Predictor
    try:
        trf_final = data_ndvar['envelope']
    except:
        # Fallback to Index 1 (Standard for F0+Env models)
        dims = data_ndvar.dimnames
        non_time = [d for d in dims if d != 'time' and d != 'sensor']
        if non_time: trf_final = data_ndvar.sub(**{non_time[0]: 1})
        else: trf_final = data_ndvar

    # Average Sensors
    if 'sensor' in trf_final.dimnames: trf_final = trf_final.mean('sensor')
    
    # Get raw signal
    signal = trf_final.x
    fs = 1.0 / trf_final.time.tstep
    
    # Ensure 1D
    if signal.ndim > 1: signal = signal.flatten()
    print(f"Data Loaded! Length: {len(signal)} samples")

except Exception as e:
    print(f"Error: {e}")
    exit()

# ==========================================
# 3. DECOMPOSE (With Padding)
# ==========================================

# --- A. Layer 1 (Carrier) ---
pad_width = len(signal)
padded_signal = np.pad(signal, pad_width, mode='reflect')

# Run Sift
imfs_layer1_padded = emd.sift.sift(padded_signal, max_imfs=5)

# Un-pad Layer 1
# emd returns (Samples, IMFs)
imfs_layer1 = imfs_layer1_padded[pad_width : pad_width + len(signal), :]

# --- B. Layer 2 (AM of IMF 1) ---
# Select the FIRST Carrier IMF (Index 0) to analyze its modulation
TARGET_IMF_IDX = 0 
target_imf_padded = imfs_layer1_padded[:, TARGET_IMF_IDX]

# Get Envelope (Amplitude)
envelope_padded = np.abs(hilbert(target_imf_padded))

# Run Sift on Envelope
imfs_layer2_padded = emd.sift.sift(envelope_padded, max_imfs=5)

# Un-pad Layer 2
envelope_real = envelope_padded[pad_width : pad_width + len(signal)]
imfs_layer2 = imfs_layer2_padded[pad_width : pad_width + len(signal), :]

# ==========================================
# 4. PLOT USING emd.plotting.plot_imfs
# ==========================================

# --- FIGURE 1: LAYER 1 IMFS ---
plt.figure(figsize=(10, 8))

# Combine Original Signal + IMFs for the stack
# np.newaxis converts 1D array to 2D column
data_L1 = np.hstack((signal[:, np.newaxis], imfs_layer1))

print("Plotting Layer 1...")
# Note: sharey=False allows each IMF to have its own y-axis scale
emd.plotting.plot_imfs(data_L1, sample_rate=fs, sharey=False)

plt.suptitle(f"{SUBJECT_ID}: Layer 1 Decompostion (Carrier)", fontsize=15)
plt.subplots_adjust(top=0.92) # Make space for title
plt.show()


# --- FIGURE 2: LAYER 2 IMFS ---
plt.figure(figsize=(10, 8))

# Combine Envelope + AM IMFs for the stack
data_L2 = np.hstack((envelope_real[:, np.newaxis], imfs_layer2))

print("Plotting Layer 2...")
emd.plotting.plot_imfs(data_L2, sample_rate=fs, sharey=False)

plt.suptitle(f"{SUBJECT_ID}: Layer 2 Decomposition (AM of IMF {TARGET_IMF_IDX+1})", fontsize=15)
plt.subplots_adjust(top=0.92)
plt.show()
# Out:
# Loading S010 from /Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results/TRFs_ESLs/S010/S010 Fzero+envelope.pickle...
# Data Loaded! Length: 114 samples
# Plotting Layer 1...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[107], line 97
#      95 print("Plotting Layer 1...")
#      96 # Note: sharey=False allows each IMF to have its own y-axis scale
# ---> 97 emd.plotting.plot_imfs(data_L1, sample_rate=fs, sharey=False)
#      99 plt.suptitle(f"{SUBJECT_ID}: Layer 1 Decompostion (Carrier)", fontsize=15)
#     100 plt.subplots_adjust(top=0.92) # Make space for title
#
# File ~/anaconda3/envs/eelbrain/lib/python3.11/site-packages/emd/plotting.py:162, in plot_imfs(imfs, time_vect, X, step, sample_rate, sharey, scale_y, cmap, fig, fig_args, ax, xlabel, ylabel_args, ylabel_xoffset, tick_params)
#     160 # Set y-axis for full time-series
#     161 lim = np.round(1.5 * X.std(), 2)
# --> 162 yticks_imf = _get_sensible_ticks(lim)
#     163 ytickpos = yticks_imf / X.std()
#     165 yticks.extend(first_step+ytickpos)
#
# File ~/anaconda3/envs/eelbrain/lib/python3.11/site-packages/emd/plotting.py:221, in _get_sensible_ticks(lim, nbins)
#     214 """Return sensibly rounded tick positions based on a plotting range.
#     215
#     216 Based on code in matplotlib.ticker
#     217 Assuming symmetrical axes and 3 ticks for the moment
#     218
#     219 """
#     220 from matplotlib import ticker
# --> 221 scale, offset = ticker.scale_range(-lim, lim)
#     222 if lim/scale > 0.5:
#     223     scale = scale / 2
#
# File ~/anaconda3/envs/eelbrain/lib/python3.11/site-packages/matplotlib/ticker.py:1988, in scale_range(vmin, vmax, n, threshold)
#    1986     offset = 0
#    1987 else:
# -> 1988     offset = math.copysign(10 ** (math.log10(abs(meanv)) // 1), meanv)
#    1989 scale = 10 ** (math.log10(dv / n) // 1)
#    1990 return scale, offset
#
# ValueError: math domain error

# %%
"""
import numpy as np
import matplotlib.pyplot as plt
import eelbrain
from pathlib import Path
import re
import emd  # pip install EMD-signal
from scipy.signal import hilbert
"""
# ==========================================
# 1. CORE FUNCTIONS (IF & AF Calculation)
# ==========================================
def get_inst_freq_amp(signal, fs):
    """ Calculates Envelope (Amplitude) and Instantaneous Frequency (IF) """
    analytic_signal = hilbert(signal)
    amplitude = np.abs(analytic_signal)
    instantaneous_phase = np.unwrap(np.angle(analytic_signal))
    
    # Calculate IF
    inst_freq = np.diff(instantaneous_phase) / (2.0 * np.pi) * fs
    inst_freq = np.append(inst_freq, inst_freq[-1])
    
    return amplitude, inst_freq

def run_hhsa(signal, fs, selected_imfs=None):
    """
    selected_imfs: List of indices to analyze. 
                   e.g., [1, 2] will only analyze the 2nd and 3rd IMFs.
                   If None, analyzes ALL IMFs.
    """
    if signal.ndim > 1: signal = signal.flatten()
    n_samples = len(signal)
    
    if n_samples < 10: return None

    # Mirror Padding
    pad_width = n_samples
    padded_signal = np.pad(signal, pad_width, mode='reflect')
    
    # Layer 1 Decomposition
    try:
        imfs_layer1 = emd.sift.sift(padded_signal, max_imfs=5).T
    except:
        return None
        
    holo_points = []
    
    # --- SELECTION LOGIC ---
    # If user didn't specify, use all. Otherwise, filter.
    if selected_imfs is None:
        target_indices = range(imfs_layer1.shape[0])
    else:
        # Filter to only existing IMFs (prevent index out of bounds)
        target_indices = [i for i in selected_imfs if i < imfs_layer1.shape[0]]

    # Loop only through SELECTED IMFs
    for i in target_indices:
        imf_c = imfs_layer1[i] # Get specific IMF
        
        # Un-pad
        imf_c_real = imf_c[pad_width : pad_width + n_samples]
        
        # Get Carrier Frequency
        env_c, freq_c = get_inst_freq_amp(imf_c_real, fs)
        
        if np.sum(np.abs(env_c)) < 1e-10: continue

        # Layer 2 Decomposition
        padded_env = np.pad(env_c, pad_width, mode='reflect')
        try:
            imfs_layer2 = emd.sift.sift(padded_env, max_imfs=5).T
        except:
            continue
            
        for imf_am in imfs_layer2:
            imf_am_real = imf_am[pad_width : pad_width + n_samples]
            _, freq_am = get_inst_freq_amp(imf_am_real, fs)
            power_am = imf_am_real**2
            
            mask = (freq_c > 0) & (freq_c < fs/2) & (freq_am > 0) & (freq_am < fs/2)
            idx = np.where(mask)[0]
            
            if len(idx) > 0:
                points = np.vstack((freq_c[idx], freq_am[idx], power_am[idx])).T
                holo_points.append(points)
                
    if not holo_points: return None
    return np.vstack(holo_points)
"""
(Old version using all IMFs for AF-IF)
    def run_hhsa(signal, fs):
    ''' 
    Performs Two-Layer Decomposition to find IF and AF.
    Layer 1 -> IF (Carrier)
    Layer 2 -> AF (Modulation)
    '''
    if signal.ndim > 1: signal = signal.flatten()
    n_samples = len(signal)
    
    # Safety Check
    if n_samples < 10: return None

    # --- MIRROR PADDING (Crucial for short TRFs) ---
    pad_width = n_samples
    padded_signal = np.pad(signal, pad_width, mode='reflect')
    
    # --- LAYER 1: GET IF (Carrier) ---
    try:
        imfs_layer1 = emd.sift.sift(padded_signal, max_imfs=5).T
    except:
        return None
        
    holo_points = []
    
    for imf_c in imfs_layer1:
        # Un-pad
        imf_c_real = imf_c[pad_width : pad_width + n_samples]
        
        # Calculate IF
        env_c, freq_c = get_inst_freq_amp(imf_c_real, fs)
        
        if np.sum(np.abs(env_c)) < 1e-10: continue

        # --- LAYER 2: GET AF (Modulation) ---
        padded_env = np.pad(env_c, pad_width, mode='reflect')
        
        try:
            imfs_layer2 = emd.sift.sift(padded_env, max_imfs=5).T
        except:
            continue
            
        for imf_am in imfs_layer2:
            imf_am_real = imf_am[pad_width : pad_width + n_samples]
            
            # Calculate AF
            _, freq_am = get_inst_freq_amp(imf_am_real, fs)
            power_am = imf_am_real**2
            
            # Store [IF, AF, Power]
            # Filter valid ranges (positive freq, below Nyquist)
            mask = (freq_c > 0) & (freq_c < fs/2) & (freq_am > 0) & (freq_am < fs/2)
            idx = np.where(mask)[0]
            
            if len(idx) > 0:
                points = np.vstack((freq_c[idx], freq_am[idx], power_am[idx])).T
                holo_points.append(points)
                
    if not holo_points: return None
    return np.vstack(holo_points)
"""

# ==========================================
# 2. EXPERIMENT SETUP
# ==========================================
DATA_ROOT = Path("/Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results")
EEG_DIR = DATA_ROOT / 'EEG_ESLs' / 'Alice_ESL_ICAed_fif'
TRF_DIR = DATA_ROOT / 'TRFs_ESLs'

ESL_SUBJECTS = [path.name for path in EEG_DIR.iterdir() if re.match(r'n_2_S\d*', path.name)]
print(f"Found {len(ESL_SUBJECTS)} subjects.")

# --- SETTINGS ---
TARGET_MODEL = 'Fzero+envelope'
LIMIT_IF = 12   # Zoom in on Carrier (X-axis)
LIMIT_AF = 6    # Zoom in on Modulation (Y-axis)
NBINS = 60      # Resolution

group_spectrum_sum = None
n_subjects_processed = 0

# ==========================================
# 3. MAIN LOOP
# ==========================================
print(f"Generating Group AF-IF Plot for {TARGET_MODEL}...")

for subject in ESL_SUBJECTS:
    subject_id_short = subject[4:8]
    file_path = TRF_DIR / subject_id_short / f'{subject_id_short} {TARGET_MODEL}.pickle'
    
    if not file_path.exists(): continue

    try:
        # Load & Extract Data
        trf_obj = eelbrain.load.unpickle(file_path)
        data_ndvar = trf_obj.h_scaled if hasattr(trf_obj, 'h_scaled') else trf_obj.h
        if isinstance(data_ndvar, tuple): data_ndvar = data_ndvar[0]

        # Extract 'Envelope' Predictor
        try:
            trf_final = data_ndvar['envelope']
        except:
            # Fallback to Index 1
            dims = data_ndvar.dimnames
            non_time = [d for d in dims if d != 'time' and d != 'sensor']
            if non_time: trf_final = data_ndvar.sub(**{non_time[0]: 1})
            else: trf_final = data_ndvar

        if 'sensor' in trf_final.dimnames: trf_final = trf_final.mean('sensor')
        
        # Run HHSA
        trf_vector = trf_final.x
        fs = 1.0 / trf_final.time.tstep
        #holo_data = run_hhsa(trf_vector, fs)
        holo_data = run_hhsa(trf_vector, fs, selected_imfs=[0]) #selected_imfs=None
        
        if holo_data is None: continue

        # Bin Data for Heatmap
        # Col 0 = IF, Col 1 = AF, Col 2 = Power
        IF_vals = holo_data[:, 0]
        AF_vals = holo_data[:, 1]
        power   = holo_data[:, 2]
        
        H_subj, xedges, yedges = np.histogram2d(IF_vals, AF_vals, bins=NBINS, weights=power,
                                           range=[[0, LIMIT_IF], [0, LIMIT_AF]])
        
        if group_spectrum_sum is None:
            group_spectrum_sum = H_subj
        else:
            group_spectrum_sum += H_subj
            
        n_subjects_processed += 1
        
    except Exception as e:
        print(f"Error on {subject_id_short}: {e}")
        continue

# ==========================================
# 4. PLOT & SAVE
# ==========================================
if n_subjects_processed > 0:
    group_avg = group_spectrum_sum / n_subjects_processed
    
    plt.figure(figsize=(10, 8))
    # 
    plt.imshow(group_avg.T, origin='lower', cmap='jet', aspect='auto',
               extent=[0, LIMIT_IF, 0, LIMIT_AF], interpolation='gaussian')
    
    plt.colorbar(label='Power (Energy)')
    plt.xlabel('Instantaneous Frequency (IF) [Hz]')   # X-AXIS
    plt.ylabel('Amplitude Frequency (AF) [Hz]')       # Y-AXIS
    plt.title(f'Group AF-IF Spectrum (N={n_subjects_processed}), IMF 1')
    
    # Diagonal Line (AF cannot be > IF)
    plt.plot([0, LIMIT_AF], [0, LIMIT_AF], 'w--', alpha=0.5, label='1:1 Line')
    plt.legend()
    
    # SAVE FIGURE
    plt.savefig(TRF_DIR / 'ESLs_HHSA_IMF1.png', dpi=300, bbox_inches='tight')
    plt.show()
    print("Plot saved as 'ESLs_HHSA_IMF1.png'.")
else:
    print("No subjects processed.")
# Out:
# Found 26 subjects.
# Generating Group AF-IF Plot for Fzero+envelope...
# Plot saved as 'ESLs_HHSA_IMF1.png'.

# %%
"""
import numpy as np
import matplotlib.pyplot as plt
import eelbrain
from pathlib import Path
import re
import emd
from scipy.signal import hilbert
"""
from scipy.stats import sem # Standard Error of Mean

# Group level of Layer 1 and Layer2 of IMFs
# ==========================================
# 1. SETUP
# ==========================================
DATA_ROOT = Path("/Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results")
TRF_DIR = DATA_ROOT / 'TRFs_ESLs'
EEG_DIR = DATA_ROOT / 'EEG_ESLs' / 'Alice_ESL_ICAed_fif'

ESL_SUBJECTS = [path.name for path in EEG_DIR.iterdir() if re.match(r'n_2_S\d*', path.name)]
print(f"Found {len(ESL_SUBJECTS)} subjects.")

# SETTINGS
TARGET_MODEL = 'Fzero+envelope'
MAX_IMFS = 4    # How many IMFs to plot (usually 3-4 is enough for TRF)
TARGET_L1_IMF = 0 # Which Layer 1 IMF to decompose for Layer 2 (0=Fastest/Theta)

# Storage for Group Data
# Shape: Lists that will hold arrays of shape [Time_Points]
layer1_storage = {i: [] for i in range(MAX_IMFS)} 
layer2_storage = {i: [] for i in range(MAX_IMFS)}
time_axis = None

# ==========================================
# 2. MAIN LOOP
# ==========================================
print("Extracting IMFs from all subjects...")

for subject in ESL_SUBJECTS:
    subject_id_short = subject[4:8]
    file_path = TRF_DIR / subject_id_short / f'{subject_id_short} {TARGET_MODEL}.pickle'
    
    if not file_path.exists(): continue

    try:
        # --- LOAD DATA ---
        trf_obj = eelbrain.load.unpickle(file_path)
        data_ndvar = trf_obj.h_scaled if hasattr(trf_obj, 'h_scaled') else trf_obj.h
        if isinstance(data_ndvar, tuple): data_ndvar = data_ndvar[0]

        # Extract 'Envelope' Predictor
        try:
            trf_final = data_ndvar['envelope']
        except:
            # Fallback Index
            dims = data_ndvar.dimnames
            non_time = [d for d in dims if d != 'time' and d != 'sensor']
            if non_time: trf_final = data_ndvar.sub(**{non_time[0]: 1})
            else: trf_final = data_ndvar

        if 'sensor' in trf_final.dimnames: trf_final = trf_final.mean('sensor')
        
        signal = trf_final.x
        if signal.ndim > 1: signal = signal.flatten()
        
        # Capture time axis from the first valid subject
        if time_axis is None:
            time_axis = trf_final.time.times

        # --- PROCESS: LAYER 1 ---
        # Mirror Pad
        pad_width = len(signal)
        padded_signal = np.pad(signal, pad_width, mode='reflect')
        
        # Run EMD
        imfs1_padded = emd.sift.sift(padded_signal, max_imfs=MAX_IMFS)
        
        # Un-pad and Store
        # Handle cases where EMD returns fewer IMFs than MAX_IMFS
        n_found = imfs1_padded.shape[1]
        for i in range(MAX_IMFS):
            if i < n_found:
                imf = imfs1_padded[pad_width : pad_width + len(signal), i]
                layer1_storage[i].append(imf)
            else:
                # If this subject doesn't have IMF 4, append zeros or skip
                # Appending zeros keeps the average valid but lowers magnitude
                layer1_storage[i].append(np.zeros_like(signal))

        # --- PROCESS: LAYER 2 (on Target IMF) ---
        if TARGET_L1_IMF < n_found:
            target_imf = imfs1_padded[:, TARGET_L1_IMF]
            
            # Envelope
            analytic = hilbert(target_imf)
            envelope = np.abs(analytic)
            
            # EMD on Envelope
            imfs2_padded = emd.sift.sift(envelope, max_imfs=MAX_IMFS)
            
            # Un-pad and Store
            n_found_2 = imfs2_padded.shape[1]
            for i in range(MAX_IMFS):
                if i < n_found_2:
                    imf = imfs2_padded[pad_width : pad_width + len(signal), i]
                    layer2_storage[i].append(imf)
                else:
                    layer2_storage[i].append(np.zeros_like(signal))

    except Exception as e:
        continue

# ==========================================
# 3. PLOTTING FUNCTION
# ==========================================
def plot_group_imfs(storage_dict, title, color_code):
    plt.figure(figsize=(10, 8))
    n_imfs = len(storage_dict)
    
    for i in range(n_imfs):
        # Convert list of arrays to matrix: [N_Subjects x N_Time]
        data_matrix = np.array(storage_dict[i])
        
        # Skip if empty
        if data_matrix.shape[0] == 0: continue
            
        # Stats
        mean_sig = np.mean(data_matrix, axis=0)
        sem_sig = sem(data_matrix, axis=0) # Standard Error
        
        # Plot
        ax = plt.subplot(n_imfs, 1, i + 1)
        ax.plot(time_axis, mean_sig, color=color_code, linewidth=2, label=f'Mean IMF {i+1}')
        
        # Shaded Error Bar
        ax.fill_between(time_axis, mean_sig - sem_sig, mean_sig + sem_sig, 
                        color=color_code, alpha=0.3, label='Standard Error')
        
        ax.set_ylabel(f"IMF {i+1}")
        ax.grid(True, alpha=0.3)
        if i == 0: ax.legend(loc='upper right')

    plt.xlabel("Time (s)")
    plt.suptitle(title, fontsize=14)
    plt.tight_layout()
    plt.show()

# ==========================================
# 4. GENERATE PLOTS
# ==========================================

# Plot Layer 1 (Carrier) - Blue
plot_group_imfs(layer1_storage, 
                f"Group Layer 1: Carrier IMFs (N={len(layer1_storage[0])})", 
                'b')

# Plot Layer 2 (AM) - Green
plot_group_imfs(layer2_storage, 
                f"Group Layer 2: AM Decomposition of Carrier IMF {TARGET_L1_IMF+1}", 
                'g')
# Out:
# Found 26 subjects.
# Extracting IMFs from all subjects...

# %%
# version 2 of the group level for layer 1 & layer 2 IMFs
"""
import numpy as np
import matplotlib.pyplot as plt
import eelbrain
from pathlib import Path
import re
import emd
from scipy.signal import hilbert
"""

# ==========================================
# 1. SETUP & CONFIGURATION
# ==========================================
DATA_ROOT = Path("/Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results")
TRF_DIR = DATA_ROOT / 'TRFs_ESLs'
EEG_DIR = DATA_ROOT / 'EEG_ESLs' / 'Alice_ESL_ICAed_fif'

ESL_SUBJECTS = [path.name for path in EEG_DIR.iterdir() if re.match(r'n_2_S\d*', path.name)]
TARGET_MODEL = 'Fzero+envelope'

print(f"Found {len(ESL_SUBJECTS)} subjects. Starting Grand Average calculation...")

# ==========================================
# 2. LOAD & ACCUMULATE TRFs
# ==========================================
trf_vectors = []
fs = None

for subject in ESL_SUBJECTS:
    subject_id_short = subject[4:8]
    file_path = TRF_DIR / subject_id_short / f'{subject_id_short} {TARGET_MODEL}.pickle'
    
    if not file_path.exists(): continue

    try:
        # Load the object
        trf_obj = eelbrain.load.unpickle(file_path)
        data_ndvar = trf_obj.h_scaled if hasattr(trf_obj, 'h_scaled') else trf_obj.h
        if isinstance(data_ndvar, tuple): data_ndvar = data_ndvar[0]

        # Extract 'envelope' predictor
        try:
            trf_final = data_ndvar['envelope']
        except:
            # Fallback: Index 1
            dims = data_ndvar.dimnames
            non_time = [d for d in dims if d != 'time' and d != 'sensor']
            if non_time: trf_final = data_ndvar.sub(**{non_time[0]: 1})
            else: trf_final = data_ndvar

        # Average Sensors
        if 'sensor' in trf_final.dimnames: trf_final = trf_final.mean('sensor')
        
        # Collect the 1D vector
        trf_vectors.append(trf_final.x)
        
        # Get Sample Rate (once)
        if fs is None: fs = 1.0 / trf_final.time.tstep

    except Exception as e:
        print(f"Skipping {subject_id_short}: {e}")
        continue

# --- CALCULATE GRAND AVERAGE ---
if len(trf_vectors) == 0:
    print("No data found.")
    exit()

# Stack and Mean -> Shape: (114,)
grand_avg_trf = np.mean(trf_vectors, axis=0) 
if grand_avg_trf.ndim > 1: grand_avg_trf = grand_avg_trf.flatten()

print(f"Grand Average Computed! Length: {len(grand_avg_trf)}, Fs: {fs:.1f}Hz")

# ==========================================
# 3. DECOMPOSE (With Mirror Padding)
# ==========================================

# --- A. Prepare Signal ---
# We still need padding because the Grand Average is also short (114 points)
pad_width = len(grand_avg_trf)
padded_signal = np.pad(grand_avg_trf, pad_width, mode='reflect')

# --- B. Layer 1: Carrier (Sift) ---
imfs_layer1_padded = emd.sift.sift(padded_signal, max_imfs=5)

# Un-pad Layer 1
# Note: EMD output is (Samples, IMFs)
imfs_layer1 = imfs_layer1_padded[pad_width : pad_width + len(grand_avg_trf), :]

# --- C. Layer 2: AM (Sift on Envelope) ---
# Let's decompose the FIRST IMF (Index 0) as it's usually the main response
target_imf_idx = 0 
target_imf_padded = imfs_layer1_padded[:, target_imf_idx]

# Get Envelope
envelope_padded = np.abs(hilbert(target_imf_padded))

# Sift Envelope
imfs_layer2_padded = emd.sift.sift(envelope_padded, max_imfs=4)

# Un-pad Layer 2
envelope_real = envelope_padded[pad_width : pad_width + len(grand_avg_trf)]
imfs_layer2 = imfs_layer2_padded[pad_width : pad_width + len(grand_avg_trf), :]

# ==========================================
# 4. PLOT RESULTS (Stacked Graphs)
# ==========================================

# --- PLOT 1: CARRIER DECOMPOSITION ---
plt.figure(figsize=(10, 8))

print("Displaying Layer 1 (Carrier)...")
# FIX: Removed 'title=' argument
emd.plotting.plot_imfs(imfs_layer1, sample_rate=fs, sharey=False)

# ADD TITLE MANUALLY HERE
plt.suptitle("Group Grand Average: Layer 1 (Carrier IMFs)", fontsize=14)
plt.subplots_adjust(top=0.92) # Adjust layout so title fits
plt.show()

# --- PLOT 2: AM DECOMPOSITION ---
plt.figure(figsize=(10, 8))

print("Displaying Layer 2 (Modulation)...")
# FIX: Removed 'title=' argument
emd.plotting.plot_imfs(imfs_layer2, sample_rate=fs, sharey=False)

# ADD TITLE MANUALLY HERE
plt.suptitle(f"Group Grand Average: Layer 2 (AM of IMF {target_imf_idx+1})", fontsize=14)
plt.subplots_adjust(top=0.92)
plt.show()

"""
(Old Codes)
# ==========================================
# 4. PLOT RESULTS (Stacked Graphs)
# ==========================================

# --- PLOT 1: CARRIER DECOMPOSITION ---
plt.figure(figsize=(10, 8))
# Combine Original + IMFs for the plot function
# emd.plotting.plot_imfs expects columns of data
data_to_plot_L1 = np.hstack((grand_avg_trf[:, np.newaxis], imfs_layer1))

print("Displaying Layer 1 (Carrier)...")
# Note: 'scale_y=True' makes it look nicer by normalizing heights
emd.plotting.plot_imfs(imfs_layer1, sample_rate=fs, title="Group Grand Average: Layer 1 (Carrier IMFs)", sharey=False)
plt.show()

# --- PLOT 2: AM DECOMPOSITION ---
plt.figure(figsize=(10, 8))
# Combine Envelope + AM IMFs
data_to_plot_L2 = np.hstack((envelope_real[:, np.newaxis], imfs_layer2))

print("Displaying Layer 2 (Modulation)...")
emd.plotting.plot_imfs(imfs_layer2, sample_rate=fs, title=f"Group Grand Average: Layer 2 (AM of IMF {target_imf_idx+1})", sharey=False)
plt.show()
"""
# Out:
# Found 26 subjects. Starting Grand Average calculation...
# Grand Average Computed! Length: 114, Fs: 100.0Hz
# Displaying Layer 1 (Carrier)...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 116
#     114 print("Displaying Layer 1 (Carrier)...")
#     115 # FIX: Removed 'title=' argument
# --> 116 emd.plotting.plot_imfs(imfs_layer1, sample_rate=fs, sharey=False)
#     118 # ADD TITLE MANUALLY HERE
#     119 plt.suptitle("Group Grand Average: Layer 1 (Carrier IMFs)", fontsize=14)
#
# File ~/anaconda3/envs/eelbrain/lib/python3.11/site-packages/emd/plotting.py:162, in plot_imfs(imfs, time_vect, X, step, sample_rate, sharey, scale_y, cmap, fig, fig_args, ax, xlabel, ylabel_args, ylabel_xoffset, tick_params)
#     160 # Set y-axis for full time-series
#     161 lim = np.round(1.5 * X.std(), 2)
# --> 162 yticks_imf = _get_sensible_ticks(lim)
#     163 ytickpos = yticks_imf / X.std()
#     165 yticks.extend(first_step+ytickpos)
#
# File ~/anaconda3/envs/eelbrain/lib/python3.11/site-packages/emd/plotting.py:221, in _get_sensible_ticks(lim, nbins)
#     214 """Return sensibly rounded tick positions based on a plotting range.
#     215
#     216 Based on code in matplotlib.ticker
#     217 Assuming symmetrical axes and 3 ticks for the moment
#     218
#     219 """
#     220 from matplotlib import ticker
# --> 221 scale, offset = ticker.scale_range(-lim, lim)
#     222 if lim/scale > 0.5:
#     223     scale = scale / 2
#
# File ~/anaconda3/envs/eelbrain/lib/python3.11/site-packages/matplotlib/ticker.py:1988, in scale_range(vmin, vmax, n, threshold)
#    1986     offset = 0
#    1987 else:
# -> 1988     offset = math.copysign(10 ** (math.log10(abs(meanv)) // 1), meanv)
#    1989 scale = 10 ** (math.log10(dv / n) // 1)
#    1990 return scale, offset
#
# ValueError: math domain error

# %%
import numpy as np
import matplotlib.pyplot as plt
import eelbrain
from pathlib import Path
import re
import emd
from scipy.signal import hilbert
import os

# ==========================================
# 1. SETUP
# ==========================================
DATA_ROOT = Path("/Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results")
TRF_DIR = DATA_ROOT / 'TRFs_ESLs'
EEG_DIR = DATA_ROOT / 'EEG_ESLs' / 'Alice_ESL_ICAed_fif'
OUTPUT_DIR = DATA_ROOT / 'Subject_IMF_Plots'

# Create output folder if it doesn't exist
os.makedirs(OUTPUT_DIR, exist_ok=True)

ESL_SUBJECTS = [path.name for path in EEG_DIR.iterdir() if re.match(r'n_2_S\d*', path.name)]
TARGET_MODEL = 'Fzero+envelope'
TARGET_IMF_IDX = 0  # Which IMF to analyze in Layer 2 (0 = First/Fastest)

print(f"Found {len(ESL_SUBJECTS)} subjects. Saving plots to {OUTPUT_DIR}...")

# ==========================================
# 2. MAIN LOOP
# ==========================================
for subject in ESL_SUBJECTS:
    subject_id_short = subject[4:8] # Extract 'S010'
    file_path = TRF_DIR / subject_id_short / f'{subject_id_short} {TARGET_MODEL}.pickle'
    
    if not file_path.exists(): continue

    try:
        print(f"Processing {subject_id_short}...")

        # --- LOAD DATA ---
        trf_obj = eelbrain.load.unpickle(file_path)
        data_ndvar = trf_obj.h_scaled if hasattr(trf_obj, 'h_scaled') else trf_obj.h
        if isinstance(data_ndvar, tuple): data_ndvar = data_ndvar[0]

        # Extract Envelope Predictor
        try:
            trf_final = data_ndvar['envelope']
        except:
            dims = data_ndvar.dimnames
            non_time = [d for d in dims if d != 'time' and d != 'sensor']
            if non_time: trf_final = data_ndvar.sub(**{non_time[0]: 1})
            else: trf_final = data_ndvar

        if 'sensor' in trf_final.dimnames: trf_final = trf_final.mean('sensor')
        
        signal = trf_final.x
        fs = 1.0 / trf_final.time.tstep
        
        # --- DECOMPOSE (With Mirror Padding) ---
        pad_width = len(signal)
        padded_signal = np.pad(signal, pad_width, mode='reflect')

        # Layer 1
        imfs_layer1_padded = emd.sift.sift(padded_signal, max_imfs=5)
        # Un-pad
        imfs_layer1 = imfs_layer1_padded[pad_width : pad_width + len(signal), :]

        # Layer 2 (On specific IMF)
        target_imf_padded = imfs_layer1_padded[:, TARGET_IMF_IDX]
        envelope_padded = np.abs(hilbert(target_imf_padded))
        imfs_layer2_padded = emd.sift.sift(envelope_padded, max_imfs=4)
        # Un-pad
        imfs_layer2 = imfs_layer2_padded[pad_width : pad_width + len(signal), :]
        
        # ==========================================
        # 3. PLOT & SAVE
        # ==========================================

        # --- PLOT 1: LAYER 1 (Carrier) ---
        plt.figure(figsize=(10, 8))
        emd.plotting.plot_imfs(imfs_layer1, sample_rate=fs, sharey=False)
        plt.suptitle(f"{subject_id_short}: Layer 1 (Carrier IMFs)", fontsize=14)
        plt.subplots_adjust(top=0.92)
        
        # Save
        save_name_L1 = OUTPUT_DIR / f"{subject_id_short}_Layer1.png"
        plt.savefig(save_name_L1)
        plt.close() # Close to free memory

        # --- PLOT 2: LAYER 2 (AM) ---
        plt.figure(figsize=(10, 8))
        emd.plotting.plot_imfs(imfs_layer2, sample_rate=fs, sharey=False)
        plt.suptitle(f"{subject_id_short}: Layer 2 (AM of IMF {TARGET_IMF_IDX+1})", fontsize=14)
        plt.subplots_adjust(top=0.92)
        
        # Save
        save_name_L2 = OUTPUT_DIR / f"{subject_id_short}_Layer2.png"
        plt.savefig(save_name_L2)
        plt.close() 

    except Exception as e:
        print(f"  Error on {subject_id_short}: {e}")
        continue

print("Done! Check the 'Subject_IMF_Plots' folder.")
# Out:
# Found 26 subjects. Saving plots to /Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results/Subject_IMF_Plots...
# Processing S030...
#   Error on S030: math domain error
# Processing S027...
#   Error on S027: math domain error
# Processing S023...
#   Error on S023: math domain error
# Processing S034...
#   Error on S034: math domain error
# Processing S024...
#   Error on S024: math domain error
# Processing S019...
#   Error on S019: math domain error
# Processing S020...
#   Error on S020: math domain error
# Processing S013...
#   Error on S013: math domain error
# Processing S017...
#   Error on S017: math domain error
# Processing S039...
#   Error on S039: math domain error
# Processing S010...
#   Error on S010: math domain error
# Processing S029...
#   Error on S029: math domain error
# Processing S015...
#   Error on S015: math domain error
# Processing S028...
#   Error on S028: math domain error
# Processing S011...
#   Error on S011: math domain error
# Processing S038...
# /var/folders/dt/yj00f34n5x52_p314tnwfjkw0000gn/T/ipykernel_17706/1633103672.py:79: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10, 8))
#   Error on S038: math domain error
# Processing S016...
#   Error on S016: math domain error
# Processing S012...
#   Error on S012: math domain error
# Processing S021...
#   Error on S021: math domain error
# Processing S036...
#   Error on S036: math domain error
# Processing S032...
#   Error on S032: math domain error
# Processing S025...
#   Error on S025: math domain error
# Processing S035...
#   Error on S035: math domain error
# Processing S022...
#   Error on S022: math domain error
# Processing S026...
#   Error on S026: math domain error
# Processing S031...
#   Error on S031: math domain error
# Done! Check the 'Subject_IMF_Plots' folder.

# %%
import numpy as np
import matplotlib.pyplot as plt
import eelbrain
from pathlib import Path
import emd
from scipy.signal import hilbert

# ==========================================
# 1. CONFIGURATION
# ==========================================
DATA_ROOT = Path("/Users/neuroling/Downloads/DINGHSIN_Results/Alice_Experiments_Results")
TRF_DIR = DATA_ROOT / 'TRFs_ESLs'
TARGET_MODEL = 'Fzero+envelope'
TARGET_SUBJECT = 'S010'

# Which Layer 1 IMF do you want to decompose further?
# 0 = First IMF (Fastest/Highest Freq)
TARGET_IMF_INDEX = 0 

# ==========================================
# 2. LOAD DATA (Same as your code)
# ==========================================
file_path = TRF_DIR / TARGET_SUBJECT / f'{TARGET_SUBJECT} {TARGET_MODEL}.pickle'
print(f"Loading {TARGET_SUBJECT}...")

try:
    trf_obj = eelbrain.load.unpickle(file_path)
    
    if hasattr(trf_obj, 'h_scaled'):
        data_ndvar = trf_obj.h_scaled
    else:
        data_ndvar = trf_obj.h
        
    if isinstance(data_ndvar, tuple):
        data_ndvar = data_ndvar[0]

    try:
        trf_final = data_ndvar['envelope']
        pred_name = "Envelope"
    except:
        dims = data_ndvar.dimnames
        non_time_dims = [d for d in dims if d != 'time' and d != 'sensor']
        if len(non_time_dims) > 0:
            trf_final = data_ndvar.sub(**{non_time_dims[0]: 1})
            pred_name = "Predictor (Index 1)"
        else:
            trf_final = data_ndvar
            pred_name = "Predictor"

    if 'sensor' in trf_final.dimnames:
        trf_final = trf_final.mean('sensor')
        
    signal = trf_final.x
    fs = 1.0 / trf_final.time.tstep

    if signal.ndim > 1: signal = signal.flatten()
    print(f"Data Loaded: {len(signal)} samples, Fs={fs:.1f}Hz")

except Exception as e:
    print(f"Error loading: {e}")
    exit()

# ==========================================
# 3. PROCESSING (Same as your code)
# ==========================================

# --- A. Layer 1 Decomposition ---
pad_width = len(signal)
padded_signal = np.pad(signal, pad_width, mode='reflect')

# Run EMD (Sift)
imfs_layer1_padded = emd.sift.sift(padded_signal, max_imfs=5)

# Un-pad Layer 1
imfs_layer1 = imfs_layer1_padded[pad_width : pad_width + len(signal), :]

# --- B. Layer 2 Decomposition (Target IMF) ---
target_imf_padded = imfs_layer1_padded[:, TARGET_IMF_INDEX]

# Get Envelope
envelope_padded = np.abs(hilbert(target_imf_padded))

# Run EMD on Envelope
imfs_layer2_padded = emd.sift.sift(envelope_padded, max_imfs=4)

# Un-pad Layer 2
envelope_real = envelope_padded[pad_width : pad_width + len(signal)]
imfs_layer2 = imfs_layer2_padded[pad_width : pad_width + len(signal), :]

# ==========================================
# 4. PLOTTING (Using emd.plotting.plot_imfs)
# ==========================================

# --- FIGURE 1: LAYER 1 (Carrier) ---
plt.figure(figsize=(10, 8))

# Combine [Raw Signal + IMFs] so the raw signal appears at the top
data_to_plot_L1 = np.hstack((signal[:, np.newaxis], imfs_layer1))

# Plot
# sharey=False is important so the small IMFs don't look flat compared to the big raw signal
emd.plotting.plot_imfs(data_to_plot_L1, sample_rate=fs, sharey=False)

# Add Title Manually
plt.suptitle(f"Layer 1: Carrier Decomposition ({TARGET_SUBJECT})\nTop: Original Signal | Below: IMFs", fontsize=14)
plt.subplots_adjust(top=0.90) # Adjust layout
plt.show()


# --- FIGURE 2: LAYER 2 (Amplitude Modulation) ---
plt.figure(figsize=(10, 8))

# Combine [Envelope + AM IMFs] so the Envelope appears at the top
data_to_plot_L2 = np.hstack((envelope_real[:, np.newaxis], imfs_layer2))

# Plot
emd.plotting.plot_imfs(data_to_plot_L2, sample_rate=fs, sharey=False)

# Add Title Manually
plt.suptitle(f"Layer 2: AM Decomposition of IMF {TARGET_IMF_INDEX+1}\nTop: Amplitude Envelope | Below: AM IMFs", fontsize=14)
plt.subplots_adjust(top=0.90)

# Save
save_path = TRF_DIR / f'ESLs_{TARGET_SUBJECT}_Layer2-IMF{TARGET_IMF_INDEX+1}_HHSA_TRF.png'
plt.savefig(save_path)
print(f"Saved Figure 2 to: {save_path}")

plt.show()
# Out:
# Loading S010...
# Data Loaded: 114 samples, Fs=100.0Hz
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[110], line 102
#      98 data_to_plot_L1 = np.hstack((signal[:, np.newaxis], imfs_layer1))
#     100 # Plot
#     101 # sharey=False is important so the small IMFs don't look flat compared to the big raw signal
# --> 102 emd.plotting.plot_imfs(data_to_plot_L1, sample_rate=fs, sharey=False)
#     104 # Add Title Manually
#     105 plt.suptitle(f"Layer 1: Carrier Decomposition ({TARGET_SUBJECT})\nTop: Original Signal | Below: IMFs", fontsize=14)
#
# File ~/anaconda3/envs/eelbrain/lib/python3.11/site-packages/emd/plotting.py:162, in plot_imfs(imfs, time_vect, X, step, sample_rate, sharey, scale_y, cmap, fig, fig_args, ax, xlabel, ylabel_args, ylabel_xoffset, tick_params)
#     160 # Set y-axis for full time-series
#     161 lim = np.round(1.5 * X.std(), 2)
# --> 162 yticks_imf = _get_sensible_ticks(lim)
#     163 ytickpos = yticks_imf / X.std()
#     165 yticks.extend(first_step+ytickpos)
#
# File ~/anaconda3/envs/eelbrain/lib/python3.11/site-packages/emd/plotting.py:221, in _get_sensible_ticks(lim, nbins)
#     214 """Return sensibly rounded tick positions based on a plotting range.
#     215
#     216 Based on code in matplotlib.ticker
#     217 Assuming symmetrical axes and 3 ticks for the moment
#     218
#     219 """
#     220 from matplotlib import ticker
# --> 221 scale, offset = ticker.scale_range(-lim, lim)
#     222 if lim/scale > 0.5:
#     223     scale = scale / 2
#
# File ~/anaconda3/envs/eelbrain/lib/python3.11/site-packages/matplotlib/ticker.py:1988, in scale_range(vmin, vmax, n, threshold)
#    1986     offset = 0
#    1987 else:
# -> 1988     offset = math.copysign(10 ** (math.log10(abs(meanv)) // 1), meanv)
#    1989 scale = 10 ** (math.log10(dv / n) // 1)
#    1990 return scale, offset
#
# ValueError: math domain error
